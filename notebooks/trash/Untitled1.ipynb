# %%
import pandas as pd

# %%
pd.read_csv('https://s3.amazonaws.com/wri-projects/Aqueduct30/processData/Y2017M09D14_RH_merge_EE_GDBD_results_V02/output/mergedZonalStatsEE_GDBD_V14.csv')
# Out:
#        GDBD_ID_GDBD  count_GDBD  mean_GDBD  count_area_30s_m2  \
# 0                -1     9518883       -1.0            9518883
# 1                 1        2829        1.0               2829
# 2                 2        3232        2.0               3232
# 3                 3        2032        3.0               2032
# 4                 4        5570        4.0               5570
# 5                 5        6014        5.0               6014
# 6                 6        3790        6.0               3790
# 7                 7        1721        7.0               1721
# 8                 8        1390        8.0               1390
# 9                 9        4102        9.0               4102
# 10               10        2785       10.0               2785
# 11               11        7248       11.0               7248
# 12               12        1943       12.0               1943
# 13               13        2054       13.0               2054
# ...

# %%
pd.read_pickle('https://s3.amazonaws.com/wri-projects/Aqueduct30/processData/Y2017M09D14_RH_merge_EE_GDBD_results_V02/output/mergedZonalStatsEE_GDBD_V14.pkl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      82         try:
# ---> 83             return read_wrapper(lambda f: pkl.load(f))
#      84         except Exception:
#
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/pandas/io/pickle.py in read_wrapper(func)
#      65                             compression=inferred_compression,
# ---> 66                             is_text=False)
#      67         try:
#
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     387             # Python 3 and binary mode
# --> 388             f = open(path_or_buf, mode)
#     389         handles.append(f)
#
# ...
