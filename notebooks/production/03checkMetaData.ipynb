# %% [markdown]
# Have you downloaded all files in the previous steps?

# %% [markdown]
# ## PURPOSE
#
#     Read University of Utrecht files and store as geotiff
#     this project use a virtual environment with the following pip installs:
#     netcdf4, https://pythongisandstuff.wordpress.com/2016/04/13/installing-gdal-ogr-for-python-on-windows/
#
# ## PROGRAMMER(S)
#     Rutger Hofste
#     Chris Slocum
# ## REVISION HISTORY
#     20170203 -- GDAL part added
#     20161202 -- Rutger changes to work with UU data
#     20140320 -- Initial version created and posted online
#     20140722 -- Added basic error handling to ncdump
#                 Thanks to K.-Michael Aye for highlighting the issue
# ## REFERENCES
#     netcdf4-python -- http://code.google.com/p/netcdf4-python/
#     colormap -- http://matplotlib.org/examples/pylab_examples/custom_cmap.html
#     GDAL -- https://pythongisandstuff.wordpress.com/2016/04/13/installing-gdal-ogr-for-python-on-windows/
#
# ## CAVEATS
#     I did not use a robust way to find the filename without extension. Filepath cannot contain periods. No error module built    in.

# %%
try:
    from osgeo import ogr, osr, gdal
except:
    sys.exit('ERROR: cannot find GDAL/OGR modules')

# %%
gdal.UseExceptions()
import datetime as dt
import numpy as np
from netCDF4 import Dataset
import os
import datetime
import math

# %%
NETCDFINPUTPATH = "/volumes/data/PCRGlobWB20V01/waterdemand"
# you can also get the metadata for other folders. You can use the SSH terminal to list the folders. 


PRINT_METADATA = True

# %% [markdown]
# Add Definitions (functions) to the environment

# %%
def ncdump(nc_fid, verb=True):
    '''
    ncdump outputs dimensions, variables and their attribute information.
    The information is similar to that of NCAR's ncdump utility.
    ncdump requires a valid instance of Dataset.

    Parameters
    ----------
    nc_fid : netCDF4.Dataset
        A netCDF4 dateset object
    verb : Boolean
        whether or not nc_attrs, nc_dims, and nc_vars are printed

    Returns
    -------
    nc_attrs : list
        A Python list of the NetCDF file global attributes
    nc_dims : list
        A Python list of the NetCDF file dimensions
    nc_vars : list
        A Python list of the NetCDF file variables
    '''
    def print_ncattr(key):
        """
        Prints the NetCDF file attributes for a given key

        Parameters
        ----------
        key : unicode
            a valid netCDF4.Dataset.variables key
        """
        try:
            print "\t\ttype:", repr(nc_fid.variables[key].dtype)
            for ncattr in nc_fid.variables[key].ncattrs():
                print '\t\t%s:' % ncattr,\
                      repr(nc_fid.variables[key].getncattr(ncattr))
        except KeyError:
            print "\t\tWARNING: %s does not contain variable attributes" % key
            
    # NetCDF global attributes
    nc_attrs = nc_fid.ncattrs()
    if verb:
        print "NetCDF Global Attributes:"
        for nc_attr in nc_attrs:
            print '\t%s:' % nc_attr, repr(nc_fid.getncattr(nc_attr))
    nc_dims = [dim for dim in nc_fid.dimensions]  # list of nc dimensions
    # Dimension shape information.
    if verb:
        print "NetCDF dimension information:"
        for dim in nc_dims:
            print "\tName:", dim
            print "\t\tsize:", len(nc_fid.dimensions[dim])
            print_ncattr(dim)
    # Variable information.
    nc_vars = [var for var in nc_fid.variables]  # list of nc variables
    if verb:
        print "NetCDF variable information:"
        for var in nc_vars:
            if var not in nc_dims:
                print '\tName:', var
                print "\t\tdimensions:", nc_fid.variables[var].dimensions
                print "\t\tsize:", nc_fid.variables[var].size
                print_ncattr(var)
    return nc_attrs, nc_dims, nc_vars

# %%
def normalizeTime(time):
    timeNormal =[]
    for i in range(0, len(time)):
        fullDate = days_since_jan_1_1900_to_datetime(time[i])
        timeNormal.append(fullDate)
    return timeNormal

# %%
def days_since_jan_1_1900_to_datetime(d):
    return datetime.datetime(1900,1,1) + \
        datetime.timedelta(days=d)

# %%
files = os.listdir(NETCDFINPUTPATH)

# %%
print "number of files: " +str(len(files))
# Out:
# number of files: 14

# %%
for oneFile in files:
    netCDFInputFileName = oneFile
    print oneFile
    netCDFInputBaseName = netCDFInputFileName.split('.')[0]

    nc_f = os.path.join(NETCDFINPUTPATH,netCDFInputFileName)
    nc_fid = Dataset(nc_f, 'r')  # Dataset is the class behavior to open the file
         # and create an instance of the ncCDF4 class
    nc_attrs, nc_dims, nc_vars = ncdump(nc_fid, PRINT_METADATA)
    parameter = nc_vars[3]

    lats = nc_fid.variables['latitude'][:]  # extract/copy the data
    lons = nc_fid.variables['longitude'][:]
    time = nc_fid.variables['time'][:]
    timeNormal = normalizeTime(time)

    print "Time Minimum: ", min(timeNormal), "Days since start (1901 or 1900)", min(time)
    print "Time Maximum: ", max(timeNormal), "Days since start (1901 or 1900)", max(time)
    print "Number of layers", len(timeNormal)
    
    print min(lats)
    print max(lats)
    print min(lons)
    print max(lons)
# Out:
# global_historical_PIrrWW_month_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly irrigation water requirements at 5min'
# 	source: u'Monthly irrigation water requirements have been calulated with WATCH ERA-Interim cliamte forcing and 5min irrigated areas by AQURA Water Resources Assessment model over the period 1960-2014, netCDF created using netCDF4 Classic in python'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	history: u'Created on 2016-07-19 05:55:24.603000'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# NetCDF dimension information:
# 	Name: time
# 		size: 660
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'Days since 1900-01-01'
# 		calendar: u'standard'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'Latitude'
# 		long_name: u'Latitude cell centres'
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'Longitude'
# 		long_name: u'Longitude cell centres'
# NetCDF variable information:
# 	Name: PIrrWW
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 6158592000
# 		type: dtype('float32')
# 		_FillValue: -9999.9004
# 		units: u'million cubic meter per month'
# 		long_name: u'Irrigation water withdrawal'
# 		standard_name: u'igcr'
# Time Minimum:  1960-01-01 00:00:00 Days since start (1901 or 1900) 21914.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 660
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PIrrWN_month_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly irrigation water requirements at 5min'
# 	source: u'Monthly irrigation water requirements have been calulated with WATCH ERA-Interim cliamte forcing and 5min irrigated areas by AQURA Water Resources Assessment model over the period 1960-2014, netCDF created using netCDF4 Classic in python'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	history: u'Created on 2016-07-19 05:55:24.603000'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# NetCDF dimension information:
# 	Name: time
# 		size: 660
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'Days since 1900-01-01'
# 		calendar: u'standard'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'Latitude'
# 		long_name: u'Latitude cell centres'
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'Longitude'
# 		long_name: u'Longitude cell centres'
# NetCDF variable information:
# 	Name: PIrrWN
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 6158592000
# 		type: dtype('float32')
# 		_FillValue: -9999.9004
# 		units: u'million cubic meter per month'
# 		long_name: u'Irrigation water consumption'
# 		standard_name: u'incr'
# Time Minimum:  1960-01-01 00:00:00 Days since start (1901 or 1900) 21914.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 660
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PLivWN_year_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	CDI: u'Climate Data Interface version 1.6.2 (http://code.zmaw.de/projects/cdi)'
# 	history: u'Sun Dec 18 17:41:55 2016: cdo -f nc4 -z zip -yearsum global_historical_PLivWN_month_millionm3_5min_1960_2014.nc4 global_historical_PLivWN_year_millionm3_5min_1960_2014.nc4\nThu Jul 21 03:57:33 2016: cdo -f nc4 -z zip -cat global_historical_PLivWN_month_millionm3_5min_1960_2000.nc4 global_historical_PLivWN_month_millionm3_5min_2001_2014.nc4 global_historical_PLivWN_month_millionm3_5min_1960_2014.nc4\nThu Jul 21 03:38:48 2016: cdo -f nc4 -z zip -cat global_historical_PLivWN_month_millionm3_5min_1960_1980.nc4 global_historical_PLivWN_month_millionm3_5min_1981_2000.nc4 global_historical_PLivWN_month_millionm3_5min_1960_2000.nc4\nCreated on 2016-07-20 01:15:40.435000'
# 	source: u'Monthly sectoral water use has been calulated with WATCH ERA-Interim cliamte forcing and socio-economic data at 5min by AQURA Water Resources Assessment model over the period 1960-1980, netCDF created using netCDF4 Classic in python'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	Conventions: u'CF-1.4'
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly sectoral water use at 5min'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# 	CDO: u'Climate Data Operators version 1.6.2rc5 (http://code.zmaw.de/projects/cdo)'
# NetCDF dimension information:
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'longitude'
# 		long_name: u'Longitude cell centres'
# 		units: u'degrees_east'
# 		axis: u'X'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'latitude'
# 		long_name: u'Latitude cell centres'
# 		units: u'degrees_north'
# 		axis: u'Y'
# 	Name: time
# 		size: 55
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'days since 1900-01-01 00:00:00'
# 		calendar: u'standard'
# NetCDF variable information:
# 	Name: PLivWN
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 513216000
# 		type: dtype('float32')
# 		standard_name: u'livn'
# 		long_name: u'Livestock water consumption'
# 		units: u'million cubic meter per month'
# 		_FillValue: -9999.9004
# 		missing_value: -9999.9004
# Time Minimum:  1960-12-01 00:00:00 Days since start (1901 or 1900) 22249.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 55
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PIndUse_month_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly sectoral water use at 5min'
# 	source: u'Monthly sectoral water use has been calulated with WATCH ERA-Interim cliamte forcing and socio-economic data at 5min by AQURA Water Resources Assessment model over the period 1960-2014, netCDF created using netCDF4 Classic in python'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	history: u'Created on 2016-07-20 00:11:31.978000'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# NetCDF dimension information:
# 	Name: time
# 		size: 660
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'Days since 1900-01-01'
# 		calendar: u'standard'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'Latitude'
# 		long_name: u'Latitude cell centres'
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'Longitude'
# 		long_name: u'Longitude cell centres'
# NetCDF variable information:
# 	Name: indn
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 6158592000
# 		type: dtype('float32')
# 		_FillValue: -9999.9004
# 		units: u'million cubic meter per month'
# 		long_name: u'Industrial water consumption'
# 		standard_name: u'indn'
# Time Minimum:  1960-01-01 00:00:00 Days since start (1901 or 1900) 21914.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 660
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PDomWW_year_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	CDI: u'Climate Data Interface version 1.6.2 (http://code.zmaw.de/projects/cdi)'
# 	history: u'Sun Dec 18 01:36:19 2016: cdo -f nc4 -z zip -yearsum global_historical_PDomWW_month_millionm3_5min_1960_2014.nc4 global_historical_PDomWW_year_millionm3_5min_1960_2014.nc4\nThu Jul 21 03:22:52 2016: cdo -f nc4 -z zip -cat global_historical_PDomWW_month_millionm3_5min_1960_1990.nc4 global_historical_PDomWW_month_millionm3_5min_1991_2014.nc4 global_historical_PDomWW_month_millionm3_5min_1960_2014.nc4\nCreated on 2016-07-19 20:47:20.780000'
# 	source: u'Monthly sectoral water use has been calulated with WATCH ERA-Interim cliamte forcing and socio-economic data at 5min by AQURA Water Resources Assessment model over the period 1960-1990, netCDF created using netCDF4 Classic in python'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	Conventions: u'CF-1.4'
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly sectoral water use at 5min'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# 	CDO: u'Climate Data Operators version 1.6.2rc5 (http://code.zmaw.de/projects/cdo)'
# NetCDF dimension information:
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'longitude'
# 		long_name: u'Longitude cell centres'
# 		units: u'degrees_east'
# 		axis: u'X'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'latitude'
# 		long_name: u'Latitude cell centres'
# 		units: u'degrees_north'
# 		axis: u'Y'
# 	Name: time
# 		size: 55
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'days since 1900-01-01 00:00:00'
# 		calendar: u'standard'
# NetCDF variable information:
# 	Name: domw
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 513216000
# 		type: dtype('float32')
# 		standard_name: u'domw'
# 		long_name: u'Domestic water withdrawal'
# 		units: u'million cubic meter per month'
# 		_FillValue: -9999.9004
# 		missing_value: -9999.9004
# Time Minimum:  1960-12-01 00:00:00 Days since start (1901 or 1900) 22249.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 55
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PIndWW_year_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	CDI: u'Climate Data Interface version 1.6.2 (http://code.zmaw.de/projects/cdi)'
# 	Conventions: u'CF-1.4'
# 	history: u'Sun Dec 18 01:13:42 2016: cdo -f nc4 -z zip -yearsum global_historical_PIndWW_month_millionm3_5min_1960_2014.nc4 global_historical_PIndWW_year_millionm3_5min_1960_2014.nc4\nCreated on 2016-07-20 00:11:31.978000'
# 	source: u'Monthly sectoral water use has been calulated with WATCH ERA-Interim cliamte forcing and socio-economic data at 5min by AQURA Water Resources Assessment model over the period 1960-2014, netCDF created using netCDF4 Classic in python'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly sectoral water use at 5min'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# 	CDO: u'Climate Data Operators version 1.6.2rc5 (http://code.zmaw.de/projects/cdo)'
# NetCDF dimension information:
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'longitude'
# 		long_name: u'Longitude cell centres'
# 		units: u'degrees_east'
# 		axis: u'X'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'latitude'
# 		long_name: u'Latitude cell centres'
# 		units: u'degrees_north'
# 		axis: u'Y'
# 	Name: time
# 		size: 55
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'days since 1900-01-01 00:00:00'
# 		calendar: u'standard'
# NetCDF variable information:
# 	Name: indw
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 513216000
# 		type: dtype('float32')
# 		standard_name: u'indw'
# 		long_name: u'Industrial water withdrawal'
# 		units: u'million cubic meter per month'
# 		_FillValue: -9999.9004
# 		missing_value: -9999.9004
# Time Minimum:  1960-12-01 00:00:00 Days since start (1901 or 1900) 22249.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 55
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PLivWN_month_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	CDI: u'Climate Data Interface version 1.6.2 (http://code.zmaw.de/projects/cdi)'
# 	history: u'Thu Jul 21 03:57:33 2016: cdo -f nc4 -z zip -cat global_historical_PLivWN_month_millionm3_5min_1960_2000.nc4 global_historical_PLivWN_month_millionm3_5min_2001_2014.nc4 global_historical_PLivWN_month_millionm3_5min_1960_2014.nc4\nThu Jul 21 03:38:48 2016: cdo -f nc4 -z zip -cat global_historical_PLivWN_month_millionm3_5min_1960_1980.nc4 global_historical_PLivWN_month_millionm3_5min_1981_2000.nc4 global_historical_PLivWN_month_millionm3_5min_1960_2000.nc4\nCreated on 2016-07-20 01:15:40.435000'
# 	source: u'Monthly sectoral water use has been calulated with WATCH ERA-Interim cliamte forcing and socio-economic data at 5min by AQURA Water Resources Assessment model over the period 1960-1980, netCDF created using netCDF4 Classic in python'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	Conventions: u'CF-1.4'
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly sectoral water use at 5min'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# 	CDO: u'Climate Data Operators version 1.6.2rc5 (http://code.zmaw.de/projects/cdo)'
# NetCDF dimension information:
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'longitude'
# 		long_name: u'Longitude cell centres'
# 		units: u'degrees_east'
# 		axis: u'X'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'latitude'
# 		long_name: u'Latitude cell centres'
# 		units: u'degrees_north'
# 		axis: u'Y'
# 	Name: time
# 		size: 660
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'days since 1900-01-01 00:00:00'
# 		calendar: u'standard'
# NetCDF variable information:
# 	Name: PLivWN
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 6158592000
# 		type: dtype('float32')
# 		standard_name: u'livn'
# 		long_name: u'Livestock water consumption'
# 		units: u'million cubic meter per month'
# 		_FillValue: -9999.9004
# 		missing_value: -9999.9004
# Time Minimum:  1960-01-01 00:00:00 Days since start (1901 or 1900) 21914.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 660
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PDomUse_month_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	CDI: u'Climate Data Interface version 1.6.2 (http://code.zmaw.de/projects/cdi)'
# 	Conventions: u'CF-1.4'
# 	history: u'Thu Jul 21 03:01:50 2016: cdo -f nc4 -z zip -cat global_historical_PDomUse_month_millionm3_5min_1960_1990.nc4 global_historical_PDomUse_month_millionm3_5min_1991_2014.nc4 global_historical_PDomUse_month_millionm3_5min_1960_2014.nc4\nCreated on 2016-07-19 20:47:20.780000'
# 	source: u'Monthly sectoral water use has been calulated with WATCH ERA-Interim cliamte forcing and socio-economic data at 5min by AQURA Water Resources Assessment model over the period 1960-1990, netCDF created using netCDF4 Classic in python'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly sectoral water use at 5min'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# 	CDO: u'Climate Data Operators version 1.6.2rc5 (http://code.zmaw.de/projects/cdo)'
# NetCDF dimension information:
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'longitude'
# 		long_name: u'Longitude cell centres'
# 		units: u'degrees_east'
# 		axis: u'X'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'latitude'
# 		long_name: u'Latitude cell centres'
# 		units: u'degrees_north'
# 		axis: u'Y'
# 	Name: time
# 		size: 662
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'days since 1900-01-01 00:00:00'
# 		calendar: u'standard'
# NetCDF variable information:
# 	Name: domn
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 6177254400
# 		type: dtype('float32')
# 		standard_name: u'domn'
# 		long_name: u'Domestic water consumption'
# 		units: u'million cubic meter per month'
# 		_FillValue: -9999.9004
# 		missing_value: -9999.9004
# Time Minimum:  1960-01-01 00:00:00 Days since start (1901 or 1900) 21914.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 662
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PIndWW_month_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly sectoral water use at 5min'
# 	source: u'Monthly sectoral water use has been calulated with WATCH ERA-Interim cliamte forcing and socio-economic data at 5min by AQURA Water Resources Assessment model over the period 1960-2014, netCDF created using netCDF4 Classic in python'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	history: u'Created on 2016-07-20 00:11:31.978000'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# NetCDF dimension information:
# 	Name: time
# 		size: 660
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'Days since 1900-01-01'
# 		calendar: u'standard'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'Latitude'
# 		long_name: u'Latitude cell centres'
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'Longitude'
# 		long_name: u'Longitude cell centres'
# NetCDF variable information:
# 	Name: indw
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 6158592000
# 		type: dtype('float32')
# 		_FillValue: -9999.9004
# 		units: u'million cubic meter per month'
# 		long_name: u'Industrial water withdrawal'
# 		standard_name: u'indw'
# Time Minimum:  1960-01-01 00:00:00 Days since start (1901 or 1900) 21914.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 660
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PIndUse_year_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	CDI: u'Climate Data Interface version 1.6.2 (http://code.zmaw.de/projects/cdi)'
# 	Conventions: u'CF-1.4'
# 	history: u'Sun Dec 18 01:21:59 2016: cdo -f nc4 -z zip -yearsum global_historical_PIndUse_month_millionm3_5min_1960_2014.nc4 global_historical_PIndUse_year_millionm3_5min_1960_2014.nc4\nCreated on 2016-07-20 00:11:31.978000'
# 	source: u'Monthly sectoral water use has been calulated with WATCH ERA-Interim cliamte forcing and socio-economic data at 5min by AQURA Water Resources Assessment model over the period 1960-2014, netCDF created using netCDF4 Classic in python'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly sectoral water use at 5min'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# 	CDO: u'Climate Data Operators version 1.6.2rc5 (http://code.zmaw.de/projects/cdo)'
# NetCDF dimension information:
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'longitude'
# 		long_name: u'Longitude cell centres'
# 		units: u'degrees_east'
# 		axis: u'X'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'latitude'
# 		long_name: u'Latitude cell centres'
# 		units: u'degrees_north'
# 		axis: u'Y'
# 	Name: time
# 		size: 55
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'days since 1900-01-01 00:00:00'
# 		calendar: u'standard'
# NetCDF variable information:
# 	Name: indn
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 513216000
# 		type: dtype('float32')
# 		standard_name: u'indn'
# 		long_name: u'Industrial water consumption'
# 		units: u'million cubic meter per month'
# 		_FillValue: -9999.9004
# 		missing_value: -9999.9004
# Time Minimum:  1960-12-01 00:00:00 Days since start (1901 or 1900) 22249.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 55
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PDomUse_year_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	CDI: u'Climate Data Interface version 1.6.2 (http://code.zmaw.de/projects/cdi)'
# 	history: u'Sun Dec 18 01:28:35 2016: cdo -f nc4 -z zip -yearsum global_historical_PDomUse_month_millionm3_5min_1960_2014.nc4 global_historical_PDomUse_year_millionm3_5min_1960_2014.nc4\nThu Jul 21 03:01:50 2016: cdo -f nc4 -z zip -cat global_historical_PDomUse_month_millionm3_5min_1960_1990.nc4 global_historical_PDomUse_month_millionm3_5min_1991_2014.nc4 global_historical_PDomUse_month_millionm3_5min_1960_2014.nc4\nCreated on 2016-07-19 20:47:20.780000'
# 	source: u'Monthly sectoral water use has been calulated with WATCH ERA-Interim cliamte forcing and socio-economic data at 5min by AQURA Water Resources Assessment model over the period 1960-1990, netCDF created using netCDF4 Classic in python'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	Conventions: u'CF-1.4'
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly sectoral water use at 5min'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# 	CDO: u'Climate Data Operators version 1.6.2rc5 (http://code.zmaw.de/projects/cdo)'
# NetCDF dimension information:
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'longitude'
# 		long_name: u'Longitude cell centres'
# 		units: u'degrees_east'
# 		axis: u'X'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'latitude'
# 		long_name: u'Latitude cell centres'
# 		units: u'degrees_north'
# 		axis: u'Y'
# 	Name: time
# 		size: 56
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'days since 1900-01-01 00:00:00'
# 		calendar: u'standard'
# NetCDF variable information:
# 	Name: domn
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 522547200
# 		type: dtype('float32')
# 		standard_name: u'domn'
# 		long_name: u'Domestic water consumption'
# 		units: u'million cubic meter per month'
# 		_FillValue: -9999.9004
# 		missing_value: -9999.9004
# Time Minimum:  1960-01-01 00:00:00 Days since start (1901 or 1900) 21914.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 56
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PIrrWN_year_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	CDI: u'Climate Data Interface version 1.6.2 (http://code.zmaw.de/projects/cdi)'
# 	Conventions: u'CF-1.4'
# 	history: u'Sun Dec 18 00:53:38 2016: cdo -f nc4 -z zip -yearsum global_historical_PIrrWN_month_millionm3_5min_1960_2014.nc4 global_historical_PIrrWN_year_millionm3_5min_1960_2014.nc4\nCreated on 2016-07-19 05:55:24.603000'
# 	source: u'Monthly irrigation water requirements have been calulated with WATCH ERA-Interim cliamte forcing and 5min irrigated areas by AQURA Water Resources Assessment model over the period 1960-2014, netCDF created using netCDF4 Classic in python'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly irrigation water requirements at 5min'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# 	CDO: u'Climate Data Operators version 1.6.2rc5 (http://code.zmaw.de/projects/cdo)'
# NetCDF dimension information:
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'longitude'
# 		long_name: u'Longitude cell centres'
# 		units: u'degrees_east'
# 		axis: u'X'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'latitude'
# 		long_name: u'Latitude cell centres'
# 		units: u'degrees_north'
# 		axis: u'Y'
# 	Name: time
# 		size: 55
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'days since 1900-01-01 00:00:00'
# 		calendar: u'standard'
# NetCDF variable information:
# 	Name: PIrrWN
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 513216000
# 		type: dtype('float32')
# 		standard_name: u'incr'
# 		long_name: u'Irrigation water consumption'
# 		units: u'million cubic meter per month'
# 		_FillValue: -9999.9004
# 		missing_value: -9999.9004
# Time Minimum:  1960-12-01 00:00:00 Days since start (1901 or 1900) 22249.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 55
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PDomWW_month_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	CDI: u'Climate Data Interface version 1.6.2 (http://code.zmaw.de/projects/cdi)'
# 	Conventions: u'CF-1.4'
# 	history: u'Thu Jul 21 03:22:52 2016: cdo -f nc4 -z zip -cat global_historical_PDomWW_month_millionm3_5min_1960_1990.nc4 global_historical_PDomWW_month_millionm3_5min_1991_2014.nc4 global_historical_PDomWW_month_millionm3_5min_1960_2014.nc4\nCreated on 2016-07-19 20:47:20.780000'
# 	source: u'Monthly sectoral water use has been calulated with WATCH ERA-Interim cliamte forcing and socio-economic data at 5min by AQURA Water Resources Assessment model over the period 1960-1990, netCDF created using netCDF4 Classic in python'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly sectoral water use at 5min'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# 	CDO: u'Climate Data Operators version 1.6.2rc5 (http://code.zmaw.de/projects/cdo)'
# NetCDF dimension information:
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'longitude'
# 		long_name: u'Longitude cell centres'
# 		units: u'degrees_east'
# 		axis: u'X'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'latitude'
# 		long_name: u'Latitude cell centres'
# 		units: u'degrees_north'
# 		axis: u'Y'
# 	Name: time
# 		size: 660
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'days since 1900-01-01 00:00:00'
# 		calendar: u'standard'
# NetCDF variable information:
# 	Name: domw
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 6158592000
# 		type: dtype('float32')
# 		standard_name: u'domw'
# 		long_name: u'Domestic water withdrawal'
# 		units: u'million cubic meter per month'
# 		_FillValue: -9999.9004
# 		missing_value: -9999.9004
# Time Minimum:  1960-01-01 00:00:00 Days since start (1901 or 1900) 21914.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 660
# -89.9583
# 89.9583
# -179.958
# 179.958
# global_historical_PIrrWW_year_millionm3_5min_1960_2014.nc4
# NetCDF Global Attributes:
# 	CDI: u'Climate Data Interface version 1.6.2 (http://code.zmaw.de/projects/cdi)'
# 	Conventions: u'CF-1.4'
# 	history: u'Sun Dec 18 01:01:29 2016: cdo -f nc4 -z zip -yearsum global_historical_PIrrWW_month_millionm3_5min_1960_2014.nc4 global_historical_PIrrWW_year_millionm3_5min_1960_2014.nc4\nCreated on 2016-07-19 05:55:24.603000'
# 	source: u'Monthly irrigation water requirements have been calulated with WATCH ERA-Interim cliamte forcing and 5min irrigated areas by AQURA Water Resources Assessment model over the period 1960-2014, netCDF created using netCDF4 Classic in python'
# 	institution: u'Dept. Physical Geography, Utrecht University'
# 	description: u'Monthly irrigation water rquirements at 5min'
# 	title: u'Global monthly irrigation water requirements at 5min'
# 	references: u'For full documentation, see  Wada, Y. et al. [2016, J. Adv. Model. Earth Syst., 8, 735-763, doi:10.1002/2015MS000618] and [2014, Earth Syst. Dynam., 5, 15-40, doi:10.5194/esd-5-15-2014]'
# 	disclaimer: u'Data has been created for an internal use. Please contact for further usage to Yoshihide Wada [y.wada@uu.nl].'
# 	CDO: u'Climate Data Operators version 1.6.2rc5 (http://code.zmaw.de/projects/cdo)'
# NetCDF dimension information:
# 	Name: longitude
# 		size: 4320
# 		type: dtype('float32')
# 		standard_name: u'longitude'
# 		long_name: u'Longitude cell centres'
# 		units: u'degrees_east'
# 		axis: u'X'
# 	Name: latitude
# 		size: 2160
# 		type: dtype('float32')
# 		standard_name: u'latitude'
# 		long_name: u'Latitude cell centres'
# 		units: u'degrees_north'
# 		axis: u'Y'
# 	Name: time
# 		size: 55
# 		type: dtype('float64')
# 		standard_name: u'time'
# 		long_name: u'Days since 1900-01-01 '
# 		units: u'days since 1900-01-01 00:00:00'
# 		calendar: u'standard'
# NetCDF variable information:
# 	Name: PIrrWW
# 		dimensions: (u'time', u'latitude', u'longitude')
# 		size: 513216000
# 		type: dtype('float32')
# 		standard_name: u'igcr'
# 		long_name: u'Irrigation water withdrawal'
# 		units: u'million cubic meter per month'
# 		_FillValue: -9999.9004
# 		missing_value: -9999.9004
# Time Minimum:  1960-12-01 00:00:00 Days since start (1901 or 1900) 22249.0
# Time Maximum:  2014-12-01 00:00:00 Days since start (1901 or 1900) 41972.0
# Number of layers 55
# -89.9583
# 89.9583
# -179.958
# 179.958

# %% [markdown]
# this script was used to check the metadata. The results were copied to a texteditor and inpected. The results are not saved to disk.

# %% [markdown]
# Finding the maximum extend of the data to check the NetCDF4 CRS:
#
# Latitudes and Longitudes are postings meaning they represent the center of a cell and not the edge.

# %%
print min(lats) , max(lats), min(lons), max(lons)
# Out:
# -89.9583 89.9583 -179.958 179.958

# %% [markdown]
# Number of cells

# %%
print len(lats)
print len(lons)
# Out:
# 2160
# 4320

# %%
cellsize = 360.0/(len(lons))
cellsize2 = 180.0/(len(lats))
print cellsize, cellsize2
# Out:
# 0.0833333333333 0.0833333333333

# %%
maxLat = max(lats)+0.5*cellsize
minLat = min(lats)-0.5*cellsize

maxLon = max(lons)+0.5*cellsize
minLon = min(lons)-0.5*cellsize

# %% [markdown]
# The extent has a slight error, caused by the rounding error of the cellsize. This is due to the fact that the model uses 5 arc minute resolution and not a rational number. When creating a reference geotiff, you therefore make a slight error.

# %%
print maxLat, maxLon
print minLat, minLon
# Out:
# 90.0000025431 179.999994914
# -90.0000025431 -179.999994914

# %% [markdown]
# The error is not significant. For the development of Aqueduct we used a standard geometry and coordinate reference system (CRS). The standard geotiff can be found in our Amazon Bucket:
#
# `wri-projects/Aqueduct30/rawData/WRI/samplegeotiff`
#
# ArcGIS has a limited precision when storing CRS and the extent translates to (copied from ArcGIS/QGIS):

# %%
maxLatArc =  090.0000025443094
minLatArc = -089.9999923682499

minLonArc = -179.999994912559
maxLonArc =  179.999994912559

# %% [markdown]
# This yield a maximum error of (Degrees)

# %%
errors = [maxLat-maxLatArc,minLat-minLatArc,maxLon-maxLonArc,minLon-minLonArc]

def absolute(x): 
    return abs(x)

absErrors = map(absolute,errors)
maxError = max(absErrors)
WGS84r = 6378137
circumference = math.pi*WGS84r*2
maxErrorm = maxError * (circumference/360)
print "Maximum error in m: " + str(maxErrorm)
# Out:
# Maximum error in m: 1.13266263962

# %% [markdown]
# Which is acceptable given the cell size is 5min or ~9.3km at the equator

# %% [markdown]
# Done
