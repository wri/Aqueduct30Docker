# %% [markdown]
# # Y2018M03D26_RH_Moving_Average_Discharge_To_GCS_V01
#
# * Purpose of script: store moving average results for discharge in a CSV file in GCS.
#
# * Script exports to:
# * Kernel used: python35
# * Date created: 20180324

# %%
import time, datetime, sys
dateString = time.strftime("Y%YM%mD%d")
timeString = time.strftime("UTC %H:%M")
start = datetime.datetime.now()
print(dateString,timeString)
sys.version
# Out:
# Y2018M03D26 UTC 09:24
# '3.5.4 |Continuum Analytics, Inc.| (default, Aug 14 2017, 13:26:58) \n[GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]'

# %%
SCRIPT_NAME = "Y2018M03D26_RH_Moving_Average_Discharge_To_GCS_V01"

INPUT_VERSION = 2

OUTPUT_VERSION = 1

EE_PATH = "projects/WRI-Aquaduct/PCRGlobWB20V07"

GCS_OUTPUT_PATH = "{}/outputV{:02.0f}/".format(SCRIPT_NAME,OUTPUT_VERSION)
GCS_BUCKET = "aqueduct30_v01"

TESTING = 1

# %%
import ee
import pandas as pd

# %%
ee.Initialize()

# %%
# Functions

def ensure_default_properties(obj):
    """ Sets the properties mean, count and sum for an object
    
    if a reduceRegion operation returns no values in earth engine
    one cannot join the result list with a list of the zones without
    setting a  nodata (-9999) value first
    
    Args:
        obj (ee.Dictionary) : earth engine object.
    
    Returns
        obj (ee.Dictionary) : dictionary with mean, count and sum 
                              set to -9999.    
    
    """
    obj = ee.Dictionary(obj)
    default_properties = ee.Dictionary({"mean": -9999,"count": -9999,"sum":-9999})
    return default_properties.combine(obj)

def mapList(results, key):
    """ filter results by key
    server side function.
    
    Args:
        results (ee.List) : list of result dictionaries.
        key (string) : key name.
    
    Returns:
        newResult (ee.List) : List of values
    
    
    """
    newResult = results.map(lambda x: ee.Dictionary(x).get(key))
    return newResult


def dict_to_feature(d):
    """ Convert a dictionary to an earth engine feature
    server side
    
    Args:
        d (ee.Dictionary) : server side dictionary
    Returns
        f (ee.Feature) : server side earth engine feature    
    """
    f = ee.Feature(None,ee.Dictionary(d))
    return f

def filter_ic(ic,year,month):
    """ filters an imagecollection based on year and month
    
    Args:
        ic (ee.ImageCollection) : ImageColllection to filter. Must have
                                  year and month properties.
        year (integer) : year
        month (integer) : month  
    Returns:
        image (ee.Image): filtered image
    
    TODO: if the filter operation results in more than one image, 
    an error should be raised.
    
    """
    
    ic_filtered = (ic.filter(ee.Filter.eq("month",month))
                    .filter(ee.Filter.eq("year",year)))
    image = ee.Image(ic_filtered.first())
    return(image)


def zonalStatsToFeatureCollection(image,zonesImage,geometry,maxPixels,reducerType):
    """ Zonal statistics with rasters as input and rasters and lists as output
    
    Args:
        image (ee.Image) : image with value. Make sure the dimensions and units are 
                           compatible with the zones image.
        zonesImage (ee.Image) : image with zones stores as unique integers. Dimensions
                                must match image argument.
        geometry (ee.Geometry) : geometry specifying the extent of the calculation.
        maxPixels (integer) : Maximum number of pixels in calculation. Defaults to 1e10.
        reducerType (string) : reducer type. Options include mean max sum first and mode.
        
    Returns:
        resultList (ee.List) : List of dictionaries     
    
    
    """
    # reducertype can be mean, max, sum, first. Count is always included for QA
    # the resolution of the zonesimage is used for scale

    reducer = ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"mean"),ee.Reducer.mean(),
    ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"max"),ee.Reducer.max(),
    ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"sum"),ee.Reducer.sum(),
    ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"first"),ee.Reducer.first(),
    ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"mode"),ee.Reducer.mode(),"error"))))
    )
    reducer = ee.Reducer(reducer).combine(reducer2= ee.Reducer.count(), sharedInputs= True).group(groupField=1, groupName="zones") 

    scale = zonesImage.projection().nominalScale().getInfo()
    zonesImage = zonesImage.select(zonesImage.bandNames(),["zones"])

    totalImage = ee.Image(image).addBands(zonesImage)
    resultsList = ee.List(totalImage.reduceRegion(
        geometry= geometry, 
        reducer= reducer,
        scale= scale,
        maxPixels=maxPixels
        ).get("groups"))

    resultsList = resultsList.map(ensure_default_properties); 
    fc = ee.FeatureCollection(resultsList.map(dict_to_feature))

    return fc

# %%
geometry = ee.Geometry.Polygon(coords=[[-180.0, -90.0], [180,  -90.0], [180, 90], [-180,90]], proj= ee.Projection('EPSG:4326'),geodesic=False )

# %%
temp_image = ee.Image("projects/WRI-Aquaduct/PCRGlobWB20V07/area_30spfaf06_m2_V01V01")
area_30spfaf06_m2 = temp_image.select(["sum"])
zones_30spfaf06 = temp_image.select(["zones"])

# %%
months = range(1,13)
years = range(1960+9,2014+1)
indicators = ["availabledischarge"]

# %%
df = pd.DataFrame()

for indicator in indicators:
    for month in months:
        for year in years:
            newRow = {}
            newRow["month"] = month
            newRow["year"] = year
            newRow["indicator"] = indicator            
            df= df.append(newRow,ignore_index=True)

# %%
if TESTING:
    df = df[1:3]

# %%
df.shape
# Out:
# (2, 3)

# %%
function_time_start = datetime.datetime.now()
for index, row in df.iterrows():
    ic = ee.ImageCollection("{}/global_historical_{}_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V{:02.0f}".format(EE_PATH,row["indicator"],INPUT_VERSION))
    image = filter_ic(ic,row["year"],row["month"])
    # volumeToFlu
    
    fc = zonalStatsToFeatureCollection(image,zones_30spfaf06,geometry,1e10,"mode")
    fileNamePrefix = "global_historical_{}_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y{:04.0f}M{:02.0f}_V{:02.0f}".format(row["indicator"],row["year"],row["month"],OUTPUT_VERSION)
    #description = fileNamePrefix
    #export_table_to_cloudstorage(fc,description,fileNamePrefix)
    #print(index)

# %%
ic.getInfo()
# Out:
# {'bands': [],
#  'features': [{'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M01_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1969M01_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 1.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1960.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36059619,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M01_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1969.0},
#    'type': 'Image',
#    'version': 1520415867283299},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M02_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1969M02_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 2.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1960.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36150409,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M02_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1969.0},
#    'type': 'Image',
#    'version': 1520422095990075},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M03_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1969M03_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 3.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1960.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36060781,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M03_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1969.0},
#    'type': 'Image',
#    'version': 1520427975374715},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M04_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1969M04_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 4.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1960.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36050180,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M04_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1969.0},
#    'type': 'Image',
#    'version': 1520432951325827},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M05_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1969M05_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 5.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1960.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36143244,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M05_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1969.0},
#    'type': 'Image',
#    'version': 1520439692909945},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M06_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1969M06_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 6.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1960.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36118188,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M06_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1969.0},
#    'type': 'Image',
#    'version': 1520446003094918},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M07_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1969M07_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 7.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1960.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36096233,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M07_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1969.0},
#    'type': 'Image',
#    'version': 1520453265717394},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M08_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1969M08_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 8.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1960.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36113945,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M08_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1969.0},
#    'type': 'Image',
#    'version': 1520462316871955},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M09_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1969M09_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 9.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1960.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36109955,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M09_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1969.0},
#    'type': 'Image',
#    'version': 1520471387541896},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M10_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1969M10_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 10.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1960.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36067327,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M10_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1969.0},
#    'type': 'Image',
#    'version': 1520476901496075},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M11_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1969M11_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 11.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1960.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36128971,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M11_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1969.0},
#    'type': 'Image',
#    'version': 1520481921210019},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M12_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1969M12_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 12.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1960.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36131398,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1969M12_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1969.0},
#    'type': 'Image',
#    'version': 1520486491138307},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M01_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1970M01_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 1.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1961.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36067540,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M01_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1970.0},
#    'type': 'Image',
#    'version': 1520418149451156},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M02_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1970M02_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 2.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1961.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36156572,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M02_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1970.0},
#    'type': 'Image',
#    'version': 1520423010333216},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M03_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1970M03_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 3.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1961.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36069194,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M03_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1970.0},
#    'type': 'Image',
#    'version': 1520427165622740},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M04_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1970M04_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 4.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1961.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36045191,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M04_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1970.0},
#    'type': 'Image',
#    'version': 1520433467598419},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M06_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1970M06_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 6.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1961.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36094567,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M06_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1970.0},
#    'type': 'Image',
#    'version': 1520445717800709},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M07_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1970M07_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 7.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1961.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36089587,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M07_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1970.0},
#    'type': 'Image',
#    'version': 1520455404227829},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M08_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1970M08_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 8.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1961.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36117149,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M08_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1970.0},
#    'type': 'Image',
#    'version': 1520462737366665},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M09_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1970M09_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 9.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1961.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36122157,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M09_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1970.0},
#    'type': 'Image',
#    'version': 1520470231217520},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M10_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1970M10_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 10.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1961.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36065392,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M10_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1970.0},
#    'type': 'Image',
#    'version': 1520476637189349},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M11_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1970M11_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 11.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1961.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36149132,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M11_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1970.0},
#    'type': 'Image',
#    'version': 1520482347705420},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M12_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1970M12_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 12.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1961.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36125296,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1970M12_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1970.0},
#    'type': 'Image',
#    'version': 1520485531603293},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M01_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1971M01_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 1.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1962.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36068242,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M01_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1971.0},
#    'type': 'Image',
#    'version': 1520417578543197},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M02_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1971M02_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 2.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1962.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36156961,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M02_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1971.0},
#    'type': 'Image',
#    'version': 1520422345607537},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M03_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1971M03_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 3.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1962.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36059143,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M03_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1971.0},
#    'type': 'Image',
#    'version': 1520427945307513},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M04_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1971M04_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 4.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1962.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36041171,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M04_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1971.0},
#    'type': 'Image',
#    'version': 1520434047515525},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M05_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1971M05_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 5.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1962.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36125582,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M05_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1971.0},
#    'type': 'Image',
#    'version': 1520440097291331},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M06_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1971M06_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 6.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1962.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36107075,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M06_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1971.0},
#    'type': 'Image',
#    'version': 1520445439211201},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M07_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1971M07_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 7.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1962.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36084395,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M07_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1971.0},
#    'type': 'Image',
#    'version': 1520453142378716},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M08_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1971M08_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 8.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1962.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36122815,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M08_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1971.0},
#    'type': 'Image',
#    'version': 1520462523397236},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M09_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1971M09_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 9.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1962.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36120067,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M09_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1971.0},
#    'type': 'Image',
#    'version': 1520470251802624},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M10_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1971M10_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 10.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1962.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36069343,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M10_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1971.0},
#    'type': 'Image',
#    'version': 1520476645539670},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M11_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1971M11_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 11.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1962.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36127096,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M11_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 1971.0},
#    'type': 'Image',
#    'version': 1520482041981457},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M12_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y1971M12_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 12.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 1962.0,
#     'parameter': 'reducedDischarge',
# ...
#     'spatial_resolution': '30s',
#     'system:asset_size': 36552151,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M01_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 2014.0},
#    'type': 'Image',
#    'version': 1520422682345629},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M02_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y2014M02_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 2.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 2005.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36540304,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M02_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 2014.0},
#    'type': 'Image',
#    'version': 1520426962905062},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M03_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y2014M03_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 3.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 2005.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36566144,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M03_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 2014.0},
#    'type': 'Image',
#    'version': 1520433490967172},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M04_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y2014M04_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 4.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 2005.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36596121,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M04_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 2014.0},
#    'type': 'Image',
#    'version': 1520440050667597},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M05_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y2014M05_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 5.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 2005.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36591137,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M05_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 2014.0},
#    'type': 'Image',
#    'version': 1520445382228648},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M06_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y2014M06_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 6.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 2005.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36546863,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M06_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 2014.0},
#    'type': 'Image',
#    'version': 1520452544927242},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M07_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y2014M07_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 7.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 2005.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36531660,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M07_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 2014.0},
#    'type': 'Image',
#    'version': 1520461906248810},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M08_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y2014M08_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 8.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 2005.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36535393,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M08_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 2014.0},
#    'type': 'Image',
#    'version': 1520469358177559},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M09_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y2014M09_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 9.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 2005.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36515749,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M09_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 2014.0},
#    'type': 'Image',
#    'version': 1520476845323991},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M10_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y2014M10_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 10.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 2005.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36529209,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M10_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 2014.0},
#    'type': 'Image',
#    'version': 1520482092497303},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M11_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y2014M11_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 11.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 2005.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36497029,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M11_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 2014.0},
#    'type': 'Image',
#    'version': 1520485416611132},
#   {'bands': [{'crs': 'EPSG:4326',
#      'crs_transform': [0.008333333333333333,
#       0.0,
#       -180.0,
#       0.0,
#       -0.008333333333333333,
#       81.0],
#      'data_type': {'precision': 'double', 'type': 'PixelType'},
#      'dimensions': [43200, 19440],
#      'id': 'mode'}],
#    'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M12_movingaverage_10y_V02',
#    'properties': {'created_by': 'Rutger Hofste',
#     'exportdescription': 'availabledischarge_month_Y2014M12_movingaverage_10y',
#     'indicator': 'availabledischarge',
#     'month': 12.0,
#     'moving_average_length': 10.0,
#     'moving_average_year_min': 2005.0,
#     'parameter': 'reducedDischarge',
#     'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#     'spatial_resolution': '30s',
#     'system:asset_size': 36482154,
#     'system:footprint': {'coordinates': [[-180.0, -90.0],
#       [180.0, -90.0],
#       [180.0, 90.0],
#       [-180.0, 90.0],
#       [-180.0, -90.0]],
#      'type': 'LinearRing'},
#     'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y2014M12_movingaverage_10y_V02',
#     'temporalResolution': 'month',
#     'units': 'millionm3',
#     'version': 2.0,
#     'year': 2014.0},
#    'type': 'Image',
#    'version': 1520489705194246}],
#  'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02',
#  'type': 'ImageCollection',
#  'version': 1520489705194246}

# %%
image.getInfo()
# Out:
# {'bands': [{'crs': 'EPSG:4326',
#    'crs_transform': [0.008333333333333333,
#     0.0,
#     -180.0,
#     0.0,
#     -0.008333333333333333,
#     81.0],
#    'data_type': {'precision': 'double', 'type': 'PixelType'},
#    'dimensions': [43200, 19440],
#    'id': 'mode'}],
#  'id': 'projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02/global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M01_movingaverage_10y_V02',
#  'properties': {'created_by': 'Rutger Hofste',
#   'exportdescription': 'availabledischarge_month_Y1971M01_movingaverage_10y',
#   'indicator': 'availabledischarge',
#   'month': 1.0,
#   'moving_average_length': 10.0,
#   'moving_average_year_min': 1962.0,
#   'parameter': 'reducedDischarge',
#   'script_used': 'Y2018M02D27_RH_Moving_Average_Discharge_EE_V01',
#   'spatial_resolution': '30s',
#   'system:asset_size': 36068242,
#   'system:footprint': {'coordinates': [[-180.0, -90.0],
#     [180.0, -90.0],
#     [180.0, 90.0],
#     [-180.0, 90.0],
#     [-180.0, -90.0]],
#    'type': 'LinearRing'},
#   'system:index': 'global_historical_availabledischarge_month_millionm3_pfaf06_Y1971M01_movingaverage_10y_V02',
#   'temporalResolution': 'month',
#   'units': 'millionm3',
#   'version': 2.0,
#   'year': 1971.0},
#  'type': 'Image',
#  'version': 1520417578543197}
