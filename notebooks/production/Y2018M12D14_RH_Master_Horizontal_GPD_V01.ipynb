# %%
""" Create horizontal table for readability. 
-------------------------------------------------------------------------------

Data is strored vertically in bigquery which means each indicator has its 
own row. This script puts the verious indicators as columns in a new,
horizontal table. Additional useful attributes are added. 

gadm metadata:
https://gadm.org/metadata.html
 

Author: Rutger Hofste
Date: 20181214
Kernel: python35
Docker: rutgerhofste/gisdocker:ubuntu16.04

"""

SCRIPT_NAME = 'Y2018M12D14_RH_Master_Horizontal_GPD_V01'
OUTPUT_VERSION = 6


# AWS RDS PostGIS
DATABASE_ENDPOINT = "aqueduct30v05.cgpnumwmfcqc.eu-central-1.rds.amazonaws.com"
DATABASE_NAME = "database01"

POSTGIS_INPUT_TABLE_NAME = "y2018m12d06_rh_master_shape_v01_v02"

# BigQuery 
BQ_IN = {}
# gadm
BQ_IN["GADM36L01"] = "y2018m11d12_rh_gadm36_level1_rds_to_bq_v01_v01"
# Area 
BQ_IN["area"] = 'y2018m12d07_rh_process_area_bq_v01_v01'

# too slow, using s3 instead
BQ_IN["indicators"] = 'y2018m12d11_rh_master_weights_gpd_v02_v06'
S3_INPUT_PATH = "s3://wri-projects/Aqueduct30/processData/Y2018M12D11_RH_Master_Weights_GPD_V02/output_V05"

BQ_PROJECT_ID = "aqueduct30"
BQ_OUTPUT_DATASET_NAME = "aqueduct30v01"
BQ_OUTPUT_TABLE_NAME = "{}_v{:02.0f}".format(SCRIPT_NAME,OUTPUT_VERSION).lower()

ec2_input_path = "/volumes/data/{}/input_V{:02.0f}".format(SCRIPT_NAME,OUTPUT_VERSION) 
ec2_output_path = "/volumes/data/{}/output_V{:02.0f}".format(SCRIPT_NAME,OUTPUT_VERSION) 
s3_output_path = "s3://wri-projects/Aqueduct30/processData/{}/output_V{:02.0f}/".format(SCRIPT_NAME,OUTPUT_VERSION)

print("PostGIS table name: ", POSTGIS_INPUT_TABLE_NAME,
      "\nBQ_OUTPUT_DATASET_NAME: ", BQ_OUTPUT_DATASET_NAME,
      "\nBQ_OUTPUT_TABLE_NAME: ", BQ_OUTPUT_TABLE_NAME,
      "\ns3_output_path: ", s3_output_path,
      "\nec2_output_path:" , ec2_output_path)
# Out:
# PostGIS table name:  y2018m12d06_rh_master_shape_v01_v02
# BQ_OUTPUT_DATASET_NAME:  aqueduct30v01
# BQ_OUTPUT_TABLE_NAME:  y2018m12d14_rh_master_horizontal_gpd_v01_v06
# s3_output_path:  s3://wri-projects/Aqueduct30/processData/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/
# ec2_output_path: /volumes/data/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06

# %%
import time, datetime, sys
dateString = time.strftime("Y%YM%mD%d")
timeString = time.strftime("UTC %H:%M")
start = datetime.datetime.now()
print(dateString,timeString)
sys.version
# Out:
# Y2018M12D20 UTC 20:07
# '3.5.4 |Anaconda, Inc.| (default, Nov 20 2017, 18:44:38) \n[GCC 7.2.0]'

# %%
# !rm -r {ec2_output_path}
# !mkdir -p {ec2_output_path}
# Out:
# rm: cannot remove '/volumes/data/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06': No such file or directory

# %%
# !aws s3 cp {S3_INPUT_PATH} {ec2_input_path} --recursive
# Out:
# download: s3://wri-projects/Aqueduct30/processData/Y2018M12D11_RH_Master_Weights_GPD_V02/output_V05/Y2018M12D11_RH_Master_Weights_GPD_V02.pkl to ../../../../data/Y2018M12D14_RH_Master_Horizontal_GPD_V01/input_V06/Y2018M12D11_RH_Master_Weights_GPD_V02.pkl
# download: s3://wri-projects/Aqueduct30/processData/Y2018M12D11_RH_Master_Weights_GPD_V02/output_V05/Y2018M12D11_RH_Master_Weights_GPD_V02.csv to ../../../../data/Y2018M12D14_RH_Master_Horizontal_GPD_V01/input_V06/Y2018M12D11_RH_Master_Weights_GPD_V02.csv

# %%
import os
import pandas as pd
import geopandas as gpd
import numpy as np
import sqlalchemy
from google.cloud import bigquery
from shapely.geometry.multipolygon import MultiPolygon
from geoalchemy2 import Geometry, WKTElement

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/.google.json"
os.environ["GOOGLE_CLOUD_PROJECT"] = "aqueduct30"
client = bigquery.Client(project=BQ_PROJECT_ID)

# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %%
F = open("/.password","r")
password = F.read().splitlines()[0]
F.close()

engine = sqlalchemy.create_engine("postgresql://rutgerhofste:{}@{}:5432/{}".format(password,DATABASE_ENDPOINT,DATABASE_NAME))
connection = engine.connect()

# %%
def uploadGDFtoPostGIS(gdf,tableName,saveIndex):
    # this function uploads a polygon shapefile to table in AWS RDS. 
    # It handles combined polygon/multipolygon geometry and stores it in valid multipolygon in epsg 4326.
    
    # gdf = input geoDataframe
    # tableName = postGIS table name (string)
    # saveIndex = save index column in separate column in postgresql, otherwise discarded. (Boolean)
    
    
    gdf["type"] = gdf.geometry.geom_type    
    geomTypes = ["Polygon","MultiPolygon"]
    
    for geomType in geomTypes:
        gdfType = gdf.loc[gdf["type"]== geomType]
        geomTypeLower = str.lower(geomType)
        gdfType['geom'] = gdfType['geometry'].apply(lambda x: WKTElement(x.wkt, srid=4326))
        gdfType.drop(["geometry","type"],1, inplace=True)      
        print("Create table temp%s" %(geomTypeLower)) 
        gdfType.to_sql(
            name = "temp%s" %(geomTypeLower),
            con = engine,
            if_exists='replace',
            index= saveIndex, 
            dtype={'geom': Geometry(str.upper(geomType), srid= 4326)}
        )
        
    # Merge both tables and make valid
    sql = []
    sql.append("DROP TABLE IF EXISTS %s"  %(tableName))
    sql.append("ALTER TABLE temppolygon ALTER COLUMN geom type geometry(MultiPolygon, 4326) using ST_Multi(geom);")
    sql.append("CREATE TABLE %s AS (SELECT * FROM temppolygon UNION SELECT * FROM tempmultipolygon);" %(tableName))
    sql.append("UPDATE %s SET geom = st_makevalid(geom);" %(tableName))
    sql.append("DROP TABLE temppolygon,tempmultipolygon")

    for statement in sql:
        print(statement)
        result = connection.execute(statement)    
    gdfFromSQL =gpd.GeoDataFrame.from_postgis("select * from %s" %(tableName),connection,geom_col='geom' )
    return gdfFromSQL

# %%
sql = """
SELECT
    aq30_id,
    string_id,
    pfaf_id,
    gid_1, 
    aqid,
    geom
FROM {}
""".format(POSTGIS_INPUT_TABLE_NAME)

# %%
gdf =gpd.GeoDataFrame.from_postgis(sql,engine,geom_col='geom')

# %%
gdf.head()
# Out:
#    aq30_id             string_id  pfaf_id     gid_1  aqid  \
# 0        0  111011-EGY.11_1-3365   111011  EGY.11_1  3365
# 1        3      111011-None-3365   111011     -9999  3365
# 2        5  111012-EGY.11_1-3365   111012  EGY.11_1  3365
# 3        7  111012-EGY.15_1-None   111012  EGY.15_1 -9999
# 4        8   111012-EGY.8_1-3365   111012   EGY.8_1  3365
#
#                                                 geom
# 0  (POLYGON ((31.90590570688292 29.85788703615783...
# 1  (POLYGON ((32.46194054146073 29.89250514754305...
# 2  (POLYGON ((31.88750000022489 29.85833333371637...
# 3  (POLYGON ((32.36609158210641 29.63378296420298...
# 4  (POLYGON ((31.89332770960627 29.73370743035362...

# %%
gdf.shape
# Out:
# (68511, 6)

# %%
gdf_master = gdf

# %%
sql_gadm = """
SELECT
  gid_1,
  name_1,
  gid_0,
  name_0,
  varname_1,
  nl_name_1,
  type_1,
  engtype_1,
  cc_1,
  hasc_1
FROM
  `{}.{}.{}`
""".format(BQ_PROJECT_ID,BQ_OUTPUT_DATASET_NAME,BQ_IN["GADM36L01"])

# %%
df_gadm = pd.read_gbq(query=sql_gadm,dialect="standard")

# %%
gdf_master = pd.merge(left=gdf_master,
                      right=df_gadm,
                      left_on ="gid_1",
                      right_on = "gid_1",
                      how = "left")

# %%
sql_area = """
SELECT
  string_id,
  area_km2
FROM
  `{}.{}.{}`
""".format(BQ_PROJECT_ID,BQ_OUTPUT_DATASET_NAME,BQ_IN["area"])
df_area = pd.read_gbq(query=sql_area,dialect="standard")

# %%
gdf_master = pd.merge(left=gdf_master,
                      right=df_area,
                      left_on ="string_id",
                      right_on = "string_id",
                      how = "left")

# %%
sql_in = """
SELECT
  string_id,
  indicator,
  group_short,
  industry_short,
  raw,
  score,
  cat,
  label,
  weight_fraction,
  weighted_score
FROM
  `{}.{}.{}`
""".format(BQ_PROJECT_ID,BQ_OUTPUT_DATASET_NAME,BQ_IN["indicators"])
#df_in = pd.read_gbq(query=sql_in,dialect="standard") # Takes too long, reverting to pickled file instead

# %%
source_path = "{}/Y2018M12D11_RH_Master_Weights_GPD_V02.pkl".format(ec2_input_path)

# %%
df_in = pd.read_pickle(source_path)

# %%
df_in.head()
# Out:
#    cat group_short indicator industry_short                    label  raw  \
# 0  1.0         qal       cep            ong  Low to medium (-5 to 0)  0.0
# 1  1.0         qal       cep            fnb  Low to medium (-5 to 0)  0.0
# 2  1.0         qal       cep            smc  Low to medium (-5 to 0)  0.0
# 3  1.0         qal       cep            agr  Low to medium (-5 to 0)  0.0
# 4  1.0         qal       cep            che  Low to medium (-5 to 0)  0.0
#
#    score             string_id  weight_fraction  weighted_score
# 0   1.25  111011-EGY.11_1-3365         0.000000        0.000000
# 1   1.25  111011-EGY.11_1-3365         0.081633        0.102041
# 2   1.25  111011-EGY.11_1-3365         0.095238        0.119048
# 3   1.25  111011-EGY.11_1-3365         0.134454        0.168067
# 4   1.25  111011-EGY.11_1-3365         0.009524        0.011905

# %% [markdown]
# # Append (horizontally) all indicators

# %%
indicators = list(df_in["indicator"].unique())
indicators.remove('awr')
for indicator in indicators:
    print(indicator)
    df_sel = df_in.loc[(df_in["industry_short"] == "def") &(df_in["indicator"] == indicator)]
    df_out = df_sel[["string_id","raw","score","cat","label"]]
    df_out.columns = ["string_id",
                      indicator + "_raw",
                      indicator +"_score",
                      indicator +"_cat",
                      indicator +"_label"]
    gdf_master = pd.merge(left=gdf_master,
                          right=df_out,
                          left_on ="string_id",
                          right_on = "string_id",
                          how="left")
# Out:
# cep
# sev
# iav
# rri
# ucw
# udw
# bws
# bwd
# gtd
# usa
# rfr
# drr
# cfr

# %%
gdf_master.loc[gdf_master["string_id"] == "253001-SJM.2_1-89"]
# Out:
#       aq30_id          string_id  pfaf_id    gid_1  aqid  \
# 7731    20607  253001-SJM.2_1-89   253001  SJM.2_1    89
#
#                                                    geom    name_1 gid_0  \
# 7731  (POLYGON ((16.34196631819108 80.05218058366709...  Svalbard   SJM
#
#                       name_0 varname_1 nl_name_1     type_1  engtype_1  cc_1  \
# 7731  Svalbard and Jan Mayen      None      None  Territory  Territory  None
#
#      hasc_1      area_km2   cep_raw  cep_score  cep_cat   cep_label   sev_raw  \
# 7731  SJ.SV  35921.638036 -1.438554   0.890362      0.0  Low (< -5)  0.925506
#
#       sev_score  sev_cat      sev_label   iav_raw  iav_score  iav_cat  \
# 7731   2.776519      2.0  Medium - High  0.380097   1.520388      1.0
#
#          iav_label  rri_raw  rri_score  rri_cat rri_label  ucw_raw  ucw_score  \
# 7731  Low - Medium      NaN        NaN      NaN       NaN      NaN        NaN
#
#       ucw_cat ucw_label  udw_raw  udw_score  udw_cat     udw_label  bws_raw  \
# 7731      NaN       NaN      0.0        0.0      0.0  Low (< 2.5%)      NaN
#
#       bws_score  bws_cat bws_label  bwd_raw  bwd_score  bwd_cat bwd_label  \
# 7731        NaN      NaN      None      NaN        NaN      NaN      None
#
#       gtd_raw  gtd_score  gtd_cat            gtd_label  usa_raw  usa_score  \
# 7731  0.01858        NaN      NaN  Insignificant Trend      0.0        0.0
#
#       usa_cat     usa_label  rfr_raw  rfr_score  rfr_cat  \
# 7731      0.0  Low (< 2.5%)      0.0        0.0      0.0
#
#                   rfr_label  drr_raw  drr_score  drr_cat drr_label  cfr_raw  \
# 7731  Low (0 to 1 in 1,000)      NaN        NaN      NaN      None      0.0
#
#       cfr_score  cfr_cat                  cfr_label
# 7731        0.0      0.0  Low (0 to 9 in 1,000,000)

# %% [markdown]
# # Append (horizontally) all aggregated water risk scores

# %%
indicator = "awr"
industries = list(df_in["industry_short"].unique())
groups = list(df_in["group_short"].unique())

for industry in industries:
    for group in groups:
        print(industry,group)
        df_sel = df_in.loc[(df_in["industry_short"] == industry) &(df_in["group_short"] == group) &(df_in["indicator"] == indicator)]
        df_out = df_sel[["string_id","raw","score","cat","label"]]

        df_out.columns = ["string_id",
                          "w_{}_{}_{}_raw".format(indicator,industry,group),
                          "w_{}_{}_{}_score".format(indicator,industry,group),
                          "w_{}_{}_{}_cat".format(indicator,industry,group),
                          "w_{}_{}_{}_label".format(indicator,industry,group)]
        gdf_master = pd.merge(left=gdf_master,
                              right=df_out,
                              left_on ="string_id",
                              right_on = "string_id",
                              how="left")
# Out:
# ong qal
# ong qan
# ong rrr
# ong tot
# fnb qal
# fnb qan
# fnb rrr
# fnb tot
# smc qal
# smc qan
# smc rrr
# smc tot
# agr qal
# agr qan
# agr rrr
# agr tot
# che qal
# che qan
# che rrr
# che tot
# min qal
# min qan
# min rrr
# min tot
# con qal
# con qan
# con rrr
# con tot
# def qal
# def qan
# def rrr
# def tot
# elp qal
# elp qan
# elp rrr
# elp tot
# tex qal
# tex qan
# tex rrr
# tex tot

# %%
gdf_master.head()
# Out:
#    aq30_id             string_id  pfaf_id     gid_1  aqid  \
# 0        0  111011-EGY.11_1-3365   111011  EGY.11_1  3365
# 1        3      111011-None-3365   111011     -9999  3365
# 2        5  111012-EGY.11_1-3365   111012  EGY.11_1  3365
# 3        7  111012-EGY.15_1-None   111012  EGY.15_1 -9999
# 4        8   111012-EGY.8_1-3365   111012   EGY.8_1  3365
#
#                                                 geom      name_1 gid_0 name_0  \
# 0  (POLYGON ((31.90590570688292 29.85788703615783...  Al Qahirah   EGY  Egypt
# 1  (POLYGON ((32.46194054146073 29.89250514754305...         NaN   NaN    NaN
# 2  (POLYGON ((31.88750000022489 29.85833333371637...  Al Qahirah   EGY  Egypt
# 3  (POLYGON ((32.36609158210641 29.63378296420298...   As Suways   EGY  Egypt
# 4  (POLYGON ((31.89332770960627 29.73370743035362...    Al Jizah   EGY  Egypt
#
#                             varname_1      nl_name_1     type_1    engtype_1  \
# 0   Cairo|El Cairo|El Qahira|Le Caire           None  Muhafazah  Governorate
# 1                                 NaN            NaN        NaN          NaN
# 2   Cairo|El Cairo|El Qahira|Le Caire           None  Muhafazah  Governorate
# 3            El Suweiz|Es Suweis|Suez  محافظة السويس  Muhafazah  Governorate
# 4  El Giza|El Gīzah|Gizeh|Giza|Guizèh           None  Muhafazah  Governorate
#
#    cc_1 hasc_1    area_km2  cep_raw  cep_score  cep_cat  \
# 0  None  EG.QH    4.223754      0.0       1.25      1.0
# 1   NaN    NaN    0.742712      0.0       1.25      1.0
# 2  None  EG.QH  258.364251      0.0       1.25      1.0
# 3  None  EG.SW    1.748248      0.0       1.25      1.0
# 4  None  EG.JZ  510.535070      0.0       1.25      1.0
#
#                  cep_label   sev_raw  sev_score  sev_cat      sev_label  \
# 0  Low to medium (-5 to 0)  0.962396   2.887187      2.0  Medium - High
# 1  Low to medium (-5 to 0)  0.962396   2.887187      2.0  Medium - High
# 2  Low to medium (-5 to 0)  1.027464   3.082393      3.0           High
# 3  Low to medium (-5 to 0)  1.027464   3.082393      3.0           High
# 4  Low to medium (-5 to 0)  1.027464   3.082393      3.0           High
#
#     iav_raw  iav_score  iav_cat       iav_label  rri_raw  rri_score  rri_cat  \
# 0  1.035414   4.141657      4.0  Extremely High     58.0        2.8      2.0
# 1  1.035414   4.141657      4.0  Extremely High      NaN        NaN      NaN
# 2  1.161367   4.645469      4.0  Extremely High     58.0        2.8      2.0
# 3  1.161367   4.645469      4.0  Extremely High     58.0        2.8      2.0
# 4  1.161367   4.645469      4.0  Extremely High     58.0        2.8      2.0
#
#                     rri_label  ucw_raw  ucw_score  ucw_cat  \
# 0  Medium to high (50 to 60%)   0.6139   2.046333      2.0
# 1                         NaN      NaN        NaN      NaN
# 2  Medium to high (50 to 60%)   0.6139   2.046333      2.0
# 3  Medium to high (50 to 60%)   0.6139   2.046333      2.0
# 4  Medium to high (50 to 60%)   0.6139   2.046333      2.0
#
#                      ucw_label   udw_raw  udw_score  udw_cat     udw_label  \
# 0  Medium to high (0.6 to 90%)  0.011222   0.000000      0.0  Low (< 2.5%)
# 1                          NaN  0.011222   0.000000      0.0  Low (< 2.5%)
# 2  Medium to high (0.6 to 90%)  0.016651   0.413638      0.0  Low (< 2.5%)
# 3  Medium to high (0.6 to 90%)  0.016651   0.413638      0.0  Low (< 2.5%)
# 4  Medium to high (0.6 to 90%)  0.016651   0.413638      0.0  Low (< 2.5%)
#
#     bws_raw  bws_score  bws_cat               bws_label   bwd_raw  bwd_score  \
# 0  2.318042        5.0      4.0          Extremely High  0.987061   4.948243
# 1  2.318042        5.0      4.0          Extremely High  0.987061   4.948243
# 2  1.000000        5.0     -1.0  Arid and Low Water Use  1.000000   5.000000
# 3  1.000000        5.0     -1.0  Arid and Low Water Use  1.000000   5.000000
# 4  1.000000        5.0     -1.0  Arid and Low Water Use  1.000000   5.000000
#
#    bwd_cat               bwd_label   gtd_raw  gtd_score  gtd_cat  \
# 0      4.0          Extremely High  0.843958        NaN      NaN
# 1      4.0          Extremely High  0.843958        NaN      NaN
# 2     -1.0  Arid and Low Water Use  0.843958        NaN      NaN
# 3     -1.0  Arid and Low Water Use       NaN        NaN      NaN
# 4     -1.0  Arid and Low Water Use  0.843958        NaN      NaN
#
#              gtd_label   usa_raw  usa_score  usa_cat  \
# 0  Insignificant Trend  0.025333   1.019067      1.0
# 1  Insignificant Trend  0.025333   1.019067      1.0
# 2  Insignificant Trend  0.045942   1.877895      1.0
# 3                  NaN  0.045942   1.877895      1.0
# 4  Insignificant Trend  0.045942   1.877895      1.0
#
#                    usa_label   rfr_raw  rfr_score  rfr_cat  \
# 0  Low to medium (2.5 to 5%)  0.074383   4.180674      4.0
# 1  Low to medium (2.5 to 5%)  0.074383   4.180674      4.0
# 2  Low to medium (2.5 to 5%)  0.000000   0.000000      0.0
# 3  Low to medium (2.5 to 5%)  0.000000   0.000000      0.0
# 4  Low to medium (2.5 to 5%)  0.000000   0.000000      0.0
#
#                              rfr_label  drr_raw  drr_score  drr_cat drr_label  \
# 0  Extremely High (more than 1 in 100)      NaN        NaN      NaN      None
# 1  Extremely High (more than 1 in 100)      NaN        NaN      NaN      None
# 2                Low (0 to 1 in 1,000)      NaN        NaN      NaN      None
# 3                Low (0 to 1 in 1,000)      NaN        NaN      NaN      None
# 4                Low (0 to 1 in 1,000)      NaN        NaN      NaN      None
#
#    cfr_raw  cfr_score  cfr_cat                  cfr_label  w_awr_ong_qal_raw  \
# 0      0.0        0.0      0.0  Low (0 to 9 in 1,000,000)           2.046333
# 1      0.0        0.0      0.0  Low (0 to 9 in 1,000,000)                NaN
# 2      0.0        0.0      0.0  Low (0 to 9 in 1,000,000)           2.046333
# 3      0.0        0.0      0.0  Low (0 to 9 in 1,000,000)           2.046333
# 4      0.0        0.0      0.0  Low (0 to 9 in 1,000,000)           2.046333
#
#    w_awr_ong_qal_score  w_awr_ong_qal_cat w_awr_ong_qal_label  \
# 0             2.040533                2.0              Medium
# 1                  NaN                NaN              NoData
# 2             2.040533                2.0              Medium
# 3             2.040533                2.0              Medium
# 4             2.040533                2.0              Medium
#
#    w_awr_ong_qan_raw  w_awr_ong_qan_score  w_awr_ong_qan_cat  \
# 0           2.205417             3.799285                3.0
# 1           2.205417             3.799285                3.0
# 2           1.732991             3.167294                3.0
# 3           1.732991             3.167294                3.0
# 4           1.732991             3.167294                3.0
#
#   w_awr_ong_qan_label  w_awr_ong_rrr_raw  w_awr_ong_rrr_score  \
# 0       Medium - High           1.273022             1.845407
# 1       Medium - High           0.509533             1.179314
# 2       Medium - High           1.697178             2.173716
# 3       Medium - High           1.697178             2.173716
# 4       Medium - High           1.697178             2.173716
#
#    w_awr_ong_rrr_cat w_awr_ong_rrr_label  w_awr_ong_tot_raw  \
# 0                1.0        Low - Medium           1.650923
# 1                1.0        Low - Medium           1.357475
# 2                2.0              Medium           1.715637
# 3                2.0              Medium           1.715637
# 4                2.0              Medium           1.715637
#
#    w_awr_ong_tot_score  w_awr_ong_tot_cat w_awr_ong_tot_label  \
# 0             2.088404                2.0              Medium
# 1             1.588022                1.0        Low - Medium
# 2             2.219416                2.0              Medium
# 3             2.219416                2.0              Medium
# 4             2.219416                2.0              Medium
#
#    w_awr_fnb_qal_raw  w_awr_fnb_qal_score  w_awr_fnb_qal_cat  \
# 0           1.648167             1.578897                1.0
# 1           1.250000             1.118499                1.0
# 2           1.648167             1.578897                1.0
# 3           1.648167             1.578897                1.0
# 4           1.648167             1.578897                1.0
#
#   w_awr_fnb_qal_label  w_awr_fnb_qan_raw  w_awr_fnb_qan_score  \
# 0        Low - Medium           4.520815             4.818802
# 1        Low - Medium           4.520815             4.818802
# 2        Low - Medium           4.398730             4.772638
# 3        Low - Medium           4.398730             4.772638
# 4        Low - Medium           4.398730             4.772638
#
#    w_awr_fnb_qan_cat w_awr_fnb_qan_label  w_awr_fnb_rrr_raw  \
# 0                4.0                High           1.654767
# 1                4.0                High           0.509533
# 2                4.0                High           1.972883
# 3                4.0                High           1.972883
# 4                4.0                High           1.972883
#
#    w_awr_fnb_rrr_score  w_awr_fnb_rrr_cat w_awr_fnb_rrr_label  \
# 0             2.143883                2.0              Medium
# 1             1.179314                1.0        Low - Medium
# 2             2.367654                2.0              Medium
# 3             2.367654                2.0              Medium
# 4             2.367654                2.0              Medium
#
#    w_awr_fnb_tot_raw  w_awr_fnb_tot_score  w_awr_fnb_tot_cat  \
# 0           3.280016             4.260374                4.0
# 1           3.516388             4.362018                4.0
# 2           3.279506             4.260155                4.0
# 3           3.279506             4.260155                4.0
# 4           3.279506             4.260155                4.0
#
#   w_awr_fnb_tot_label  w_awr_smc_qal_raw  w_awr_smc_qal_score  \
# 0                High           1.780889             1.732363
# 1                High           1.250000             1.118499
# 2                High           1.780889             1.732363
# 3                High           1.780889             1.732363
# 4                High           1.780889             1.732363
#
#    w_awr_smc_qal_cat w_awr_smc_qal_label  w_awr_smc_qan_raw  \
# 0                1.0        Low - Medium           3.888250
# 1                1.0        Low - Medium           3.888250
# 2                1.0        Low - Medium           3.465983
# 3                1.0        Low - Medium           3.465983
# 4                1.0        Low - Medium           3.465983
#
#    w_awr_smc_qan_score  w_awr_smc_qan_cat w_awr_smc_qan_label  \
# 0             4.579606                4.0                High
# 1             4.579606                4.0                High
# 2             4.419931                4.0                High
# 3             4.419931                4.0                High
# 4             4.419931                4.0                High
#
#    w_awr_smc_rrr_raw  w_awr_smc_rrr_score  w_awr_smc_rrr_cat  \
# 0           1.654767             2.143883                2.0
# 1           0.509533             1.179314                1.0
# 2           1.972883             2.367654                2.0
# 3           1.972883             2.367654                2.0
# 4           1.972883             2.367654                2.0
#
#   w_awr_smc_rrr_label  w_awr_smc_tot_raw  w_awr_smc_tot_score  \
# 0              Medium           2.689467             4.006427
# 1        Low - Medium           2.885423             4.090691
# 2              Medium           2.572485             3.822022
# 3              Medium           2.572485             3.822022
# 4              Medium           2.572485             3.822022
#
#    w_awr_smc_tot_cat w_awr_smc_tot_label  w_awr_agr_qal_raw  \
# 0                4.0                High           1.409267
# 1                4.0                High           1.250000
# 2                3.0       Medium - High           1.409267
# 3                3.0       Medium - High           1.409267
# 4                3.0       Medium - High           1.409267
#
#    w_awr_agr_qal_score  w_awr_agr_qal_cat w_awr_agr_qal_label  \
# 0             1.302658                1.0        Low - Medium
# 1             1.118499                1.0        Low - Medium
# 2             1.302658                1.0        Low - Medium
# 3             1.302658                1.0        Low - Medium
# 4             1.302658                1.0        Low - Medium
#
#    w_awr_agr_qan_raw  w_awr_agr_qan_score  w_awr_agr_qan_cat  \
# 0           4.296044             4.733808                4.0
# 1           4.296044             4.733808                4.0
# 2           4.066571             4.647036                4.0
# 3           4.066571             4.647036                4.0
# 4           4.066571             4.647036                4.0
#
#   w_awr_agr_qan_label  w_awr_agr_rrr_raw  w_awr_agr_rrr_score  \
# 0                High           0.644267             1.296860
# 1                High           0.509533             1.179314
# 2                High           1.243075             1.819280
# 3                High           1.243075             1.819280
# 4                High           1.243075             1.819280
#
#    w_awr_agr_rrr_cat w_awr_agr_rrr_label  w_awr_agr_tot_raw  \
# 0                1.0        Low - Medium           2.918851
# 1                1.0        Low - Medium           2.962863
# 2                1.0        Low - Medium           2.903979
# 3                1.0        Low - Medium           2.903979
# 4                1.0        Low - Medium           2.903979
#
#    w_awr_agr_tot_score  w_awr_agr_tot_cat w_awr_agr_tot_label  \
# 0             4.105066                4.0                High
# 1             4.123992                4.0                High
# 2             4.098671                4.0                High
# 3             4.098671                4.0                High
# 4             4.098671                4.0                High
#
#    w_awr_che_qal_raw  w_awr_che_qal_score  w_awr_che_qal_cat  \
# 0           1.957852             1.936984                1.0
# 1           1.250000             1.118499                1.0
# 2           1.957852             1.936984                1.0
# 3           1.957852             1.936984                1.0
# 4           1.957852             1.936984                1.0
#
#   w_awr_che_qal_label  w_awr_che_qan_raw  w_awr_che_qan_score  \
# 0        Low - Medium           3.117716             4.288239
# 1        Low - Medium           3.117716             4.288239
# 2        Low - Medium           1.980562             3.498482
# 3        Low - Medium           1.980562             3.498482
# 4        Low - Medium           1.980562             3.498482
#
#    w_awr_che_qan_cat w_awr_che_qan_label  w_awr_che_rrr_raw  \
# 0                4.0                High           1.273022
# 1                4.0                High           0.509533
# 2                3.0       Medium - High           1.697178
# 3                3.0       Medium - High           1.697178
# 4                3.0       Medium - High           1.697178
#
#    w_awr_che_rrr_score  w_awr_che_rrr_cat w_awr_che_rrr_label  \
# 0             1.845407                1.0        Low - Medium
# 1             1.179314                1.0        Low - Medium
# 2             2.173716                2.0              Medium
# 3             2.173716                2.0              Medium
# 4             2.173716                2.0              Medium
#
#    w_awr_che_tot_raw  w_awr_che_tot_score  w_awr_che_tot_cat  \
# 0           2.502981             3.700790                3.0
# 1           2.520474             3.731303                3.0
# 2           1.901847             2.596396                2.0
# 3           1.901847             2.596396                2.0
# 4           1.901847             2.596396                2.0
#
#   w_awr_che_tot_label  w_awr_min_qal_raw  w_awr_min_qal_score  \
# 0       Medium - High           1.780889             1.732363
# 1       Medium - High           1.250000             1.118499
# 2              Medium           1.780889             1.732363
# 3              Medium           1.780889             1.732363
# 4              Medium           1.780889             1.732363
#
#    w_awr_min_qal_cat w_awr_min_qal_label  w_awr_min_qan_raw  \
# 0                1.0        Low - Medium           3.117716
# 1                1.0        Low - Medium           3.117716
# 2                1.0        Low - Medium           1.980562
# 3                1.0        Low - Medium           1.980562
# 4                1.0        Low - Medium           1.980562
#
#    w_awr_min_qan_score  w_awr_min_qan_cat w_awr_min_qan_label  \
# 0             4.288239                4.0                High
# 1             4.288239                4.0                High
# 2             3.498482                3.0       Medium - High
# 3             3.498482                3.0       Medium - High
# 4             3.498482                3.0       Medium - High
#
#    w_awr_min_rrr_raw  w_awr_min_rrr_score  w_awr_min_rrr_cat  \
# 0           1.273022             1.845407                1.0
# 1           0.509533             1.179314                1.0
# 2           1.697178             2.173716                2.0
# 3           1.697178             2.173716                2.0
# 4           1.697178             2.173716                2.0
#
#   w_awr_min_rrr_label  w_awr_min_tot_raw  w_awr_min_tot_score  \
# 0        Low - Medium           2.252709             3.264254
# 1        Low - Medium           2.158957             3.100728
# 2              Medium           1.847838             2.487055
# 3              Medium           1.847838             2.487055
# 4              Medium           1.847838             2.487055
#
#    w_awr_min_tot_cat w_awr_min_tot_label  w_awr_con_qal_raw  \
# 0                3.0       Medium - High           1.780889
# 1                3.0       Medium - High           1.250000
# 2                2.0              Medium           1.780889
# 3                2.0              Medium           1.780889
# 4                2.0              Medium           1.780889
#
#    w_awr_con_qal_score  w_awr_con_qal_cat w_awr_con_qal_label  \
# 0             1.732363                1.0        Low - Medium
# 1             1.118499                1.0        Low - Medium
# 2             1.732363                1.0        Low - Medium
# 3             1.732363                1.0        Low - Medium
# 4             1.732363                1.0        Low - Medium
#
#    w_awr_con_qan_raw  w_awr_con_qan_score  w_awr_con_qan_cat  \
# 0           3.941655             4.599800                4.0
# 1           3.941655             4.599800                4.0
# 2           3.409133             4.398434                4.0
# 3           3.409133             4.398434                4.0
# 4           3.409133             4.398434                4.0
#
#   w_awr_con_qan_label  w_awr_con_rrr_raw  w_awr_con_rrr_score  \
# 0                High           0.967627             1.578970
# 1                High           0.509533             1.179314
# 2                High           1.476613             2.018566
# 3                High           1.476613             2.018566
# 4                High           1.476613             2.018566
#
#    w_awr_con_rrr_cat w_awr_con_rrr_label  w_awr_con_tot_raw  \
# 0                1.0        Low - Medium           2.971089
# 1                1.0        Low - Medium           3.077437
# 2                2.0              Medium           2.747891
# 3                2.0              Medium           2.747891
# 4                2.0              Medium           2.747891
#
#    w_awr_con_tot_score  w_awr_con_tot_cat w_awr_con_tot_label  \
# 0             4.127530                4.0                High
# 1             4.173261                4.0                High
# 2             4.031550                4.0                High
# 3             4.031550                4.0                High
# 4             4.031550                4.0                High
#
#    w_awr_def_qal_raw  w_awr_def_qal_score  w_awr_def_qal_cat  \
# 0           1.780889             1.732363                1.0
# 1           1.250000             1.118499                1.0
# 2           1.780889             1.732363                1.0
# 3           1.780889             1.732363                1.0
# 4           1.780889             1.732363                1.0
#
#   w_awr_def_qal_label  w_awr_def_qan_raw  w_awr_def_qan_score  \
# 0        Low - Medium           4.317097             4.741769
# 1        Low - Medium           4.317097             4.741769
# 2        Low - Medium           3.987630             4.617185
# 3        Low - Medium           3.987630             4.617185
# 4        Low - Medium           3.987630             4.617185
#
#    w_awr_def_qan_cat w_awr_def_qan_label  w_awr_def_rrr_raw  \
# 0                4.0                High           0.764030
# 1                4.0                High           0.509533
# 2                4.0                High           1.329570
# 3                4.0                High           1.329570
# 4                4.0                High           1.329570
#
#    w_awr_def_rrr_score  w_awr_def_rrr_cat w_awr_def_rrr_label  \
# 0             1.401345                1.0        Low - Medium
# 1             1.179314                1.0        Low - Medium
# 2             1.894742                1.0        Low - Medium
# 3             1.894742                1.0        Low - Medium
# 4             1.894742                1.0        Low - Medium
#
#    w_awr_def_tot_raw  w_awr_def_tot_score  w_awr_def_tot_cat  \
# 0           3.041560             4.157834                4.0
# 1           3.173513             4.214575                4.0
# 2           2.983225             4.132748                4.0
# 3           2.983225             4.132748                4.0
# 4           2.983225             4.132748                4.0
#
#   w_awr_def_tot_label  w_awr_elp_qal_raw  w_awr_elp_qal_score  \
# 0                High           1.409267             1.302658
# 1                High           1.250000             1.118499
# 2                High           1.409267             1.302658
# 3                High           1.409267             1.302658
# 4                High           1.409267             1.302658
#
#    w_awr_elp_qal_cat w_awr_elp_qal_label  w_awr_elp_qan_raw  \
# 0                1.0        Low - Medium           3.415903
# 1                1.0        Low - Medium           3.415903
# 2                1.0        Low - Medium           2.988838
# 3                1.0        Low - Medium           2.988838
# 4                1.0        Low - Medium           2.988838
#
#    w_awr_elp_qan_score  w_awr_elp_qan_cat w_awr_elp_qan_label  \
# 0             4.400994                4.0                High
# 1             4.400994                4.0                High
# 2             4.239505                4.0                High
# 3             4.239505                4.0                High
# 4             4.239505                4.0                High
#
#    w_awr_elp_rrr_raw  w_awr_elp_rrr_score  w_awr_elp_rrr_cat  \
# 0           1.273022             1.845407                1.0
# 1           0.509533             1.179314                1.0
# 2           1.697178             2.173716                2.0
# 3           1.697178             2.173716                2.0
# 4           1.697178             2.173716                2.0
#
#   w_awr_elp_rrr_label  w_awr_elp_tot_raw  w_awr_elp_tot_score  \
# 0        Low - Medium           3.199300             4.225665
# 1        Low - Medium           3.220277             4.234685
# 2              Medium           2.833933             4.068550
# 3              Medium           2.833933             4.068550
# 4              Medium           2.833933             4.068550
#
#    w_awr_elp_tot_cat w_awr_elp_tot_label  w_awr_tex_qal_raw  \
# 0                4.0                High           1.887067
# 1                4.0                High           1.250000
# 2                4.0                High           1.887067
# 3                4.0                High           1.887067
# 4                4.0                High           1.887067
#
#    w_awr_tex_qal_score  w_awr_tex_qal_cat w_awr_tex_qal_label  \
# 0             1.855135                1.0        Low - Medium
# 1             1.118499                1.0        Low - Medium
# 2             1.855135                1.0        Low - Medium
# 3             1.855135                1.0        Low - Medium
# 4             1.855135                1.0        Low - Medium
#
#    w_awr_tex_qan_raw  w_awr_tex_qan_score  w_awr_tex_qan_cat  \
# 0           3.489695             4.428898                4.0
# 1           3.489695             4.428898                4.0
# 2           3.080784             4.274273                4.0
# 3           3.080784             4.274273                4.0
# 4           3.080784             4.274273                4.0
#
#   w_awr_tex_qan_label  w_awr_tex_rrr_raw  w_awr_tex_rrr_score  \
# 0                High           1.654767             2.143883
# 1                High           0.509533             1.179314
# 2                High           1.972883             2.367654
# 3                High           1.972883             2.367654
# 4                High           1.972883             2.367654
#
#    w_awr_tex_rrr_cat w_awr_tex_rrr_label  w_awr_tex_tot_raw  \
# 0                2.0              Medium           2.434227
# 1                1.0        Low - Medium           2.440781
# 2                2.0              Medium           2.390933
# 3                2.0              Medium           2.390933
# 4                2.0              Medium           2.390933
#
#    w_awr_tex_tot_score  w_awr_tex_tot_cat w_awr_tex_tot_label
# 0             3.580866                3.0       Medium - High
# 1             3.592298                3.0       Medium - High
# 2             3.505352                3.0       Medium - High
# 3             3.505352                3.0       Medium - High
# 4             3.505352                3.0       Medium - High

# %%
gdf_master.sort_index(axis=1,inplace=True)

# %%
gdf_master.shape
# Out:
# (68511, 228)

# %% [markdown]
# # Save in multiple formats:
#
# 1. Geopackage
# 1. CSV (no geom)
# 1. Pickle
# 1. Bigquery
# 1. PostGIS

# %%
df_master =gdf_master.drop("geom",axis=1)

# %%
destination_path_shp = "{}/{}.shp".format(ec2_output_path,SCRIPT_NAME)
destination_path_csv = "{}/{}.csv".format(ec2_output_path,SCRIPT_NAME)
destination_path_pkl = "{}/{}.pkl".format(ec2_output_path,SCRIPT_NAME)
output_table_name = "{}_v{:02.0f}".format(SCRIPT_NAME,OUTPUT_VERSION).lower()
destination_table = "{}.{}".format(BQ_OUTPUT_DATASET_NAME,BQ_OUTPUT_TABLE_NAME)

# %%
end = datetime.datetime.now()
elapsed = end - start
print(elapsed)
# Out:
# 0:02:48.161030

# %%
gdf_simple = gdf_master[["string_id","geom"]]

# %%
# Saving as geopackage did not work. Therefore saving the unique identifier (string_id) and geom as shapefile. 
# This can be joined in GIS software later
gdf_simple.to_file(filename=destination_path_shp,driver="ESRI Shapefile",encoding ='utf-8')

# %%
gdf_master.to_pickle(destination_path_pkl)

# %%
df_master.to_csv(destination_path_csv, encoding='utf-8')

# %%
# !aws s3 cp {ec2_output_path} {s3_output_path} --recursive
# Out:
# upload: ../../../../data/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.prj to s3://wri-projects/Aqueduct30/processData/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.prj
# upload: ../../../../data/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.shx to s3://wri-projects/Aqueduct30/processData/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.shx
# upload: ../../../../data/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.dbf to s3://wri-projects/Aqueduct30/processData/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.dbf
# upload: ../../../../data/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.cpg to s3://wri-projects/Aqueduct30/processData/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.cpg
# upload: ../../../../data/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.csv to s3://wri-projects/Aqueduct30/processData/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.csv
# upload: ../../../../data/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.shp to s3://wri-projects/Aqueduct30/processData/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.shp
# upload: ../../../../data/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.pkl to s3://wri-projects/Aqueduct30/processData/Y2018M12D14_RH_Master_Horizontal_GPD_V01/output_V06/Y2018M12D14_RH_Master_Horizontal_GPD_V01.pkl

# %%
gdf_master2 = gdf_master.rename(columns={"geom":"geometry"})
gdf_master2 = gpd.GeoDataFrame(gdf_master2,geometry="geometry")

# %%
gdfFromSQL = uploadGDFtoPostGIS(gdf_master2,output_table_name,False)
# Out:
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Create table temppolygon
# Create table tempmultipolygon
# DROP TABLE IF EXISTS y2018m12d14_rh_master_horizontal_gpd_v01_v06
# ALTER TABLE temppolygon ALTER COLUMN geom type geometry(MultiPolygon, 4326) using ST_Multi(geom);
# CREATE TABLE y2018m12d14_rh_master_horizontal_gpd_v01_v06 AS (SELECT * FROM temppolygon UNION SELECT * FROM tempmultipolygon);
# UPDATE y2018m12d14_rh_master_horizontal_gpd_v01_v06 SET geom = st_makevalid(geom);
# DROP TABLE temppolygon,tempmultipolygon

# %%
gdfFromSQL.to_gbq(destination_table=destination_table,
                  project_id=BQ_PROJECT_ID,
                  chunksize=1000,
                  if_exists="replace")
# Out:
# 69it [22:15, 19.35s/it]

# %%
end = datetime.datetime.now()
elapsed = end - start
print(elapsed)
# Out:
# 0:50:58.010675

# %% [markdown]
# Previous runs:
# 0:47:11.853503
