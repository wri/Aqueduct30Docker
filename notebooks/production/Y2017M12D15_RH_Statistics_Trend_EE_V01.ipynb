# %% [markdown]
# # Y2017M12D15_RH_Statistics_Trend_EE_V01
#
# * Purpose of script: Calculate short term and long term average and 2014_trend for Q, WW and WN per pfaf 6  basin
# * Kernel used: python27
# * Date created: 20171215

# %%
import time, datetime, sys
dateString = time.strftime("Y%YM%mD%d")
timeString = time.strftime("UTC %H:%M")
start = datetime.datetime.now()
print(dateString,timeString)
sys.version
# Out:
# ('Y2017M12D18', 'UTC 11:57')
# '2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:09:15) \n[GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]'

# %%
EE_PATH = "projects/WRI-Aquaduct/PCRGlobWB20V07"

SCRIPT_NAME = "Y2017M12D15_RH_Statistics_Trend_EE_V01"

OUTPUT_VERSION = 1

PFAF_LEVEL = 6

YEARMIN = 1960
YEARMAX = 2014

SHORT_TERM_MIN = 2004
SHORT_TERM_MAX = 2014

LONG_TERM_MIN = 1960
LONG_TERM_MAX = 2014


DIMENSIONS30SSMALL = "43200x19440"
CRS = "EPSG:4326"
CRS_TRANSFORM30S_SMALL = [0.008333333333333333, 0.0, -180.0, 0.0, -0.008333333333333333, 81.0]

# %%
import ee
import logging
import pandas as pd
import subprocess

# %%
ee.Initialize()

# %%
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s:%(levelname)s:%(message)s')
file_handler = logging.FileHandler("./logs/%sV%0.2d.log" %(SCRIPT_NAME,OUTPUT_VERSION))
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# %%
geometrySmall = ee.Geometry.Polygon(coords=[[-180.0, -81.0], [180,  -81.0], [180, 81], [-180,81]], proj= ee.Projection('EPSG:4326'),geodesic=False )

# %%
ic = {}
ic["year"] = ee.ImageCollection("projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_WS_year_dimensionless_30sPfaf06_1960_2014")
ic["month"] = ee.ImageCollection("projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_WS_month_dimensionless_30sPfaf06_1960_2014")

# %%
temporalRange = {}
temporalRange["short"] = [SHORT_TERM_MIN,SHORT_TERM_MAX]
temporalRange["long"] = [LONG_TERM_MIN,LONG_TERM_MAX]

# %% [markdown]
# Calculate mean

# %%
def createRow():
    newRow = {} 
    newRow["indicator"] = shortIndicator
    newRow["temporalResolution"] = temporalResolution
    newRow["reducerType"] =  reducerType
    newRow["interval"] = interval
    newRow["yearMin"] = yearMin
    newRow["yearMax"] = yearMax 

    newRow["ic"] = icTempFiltered
    newRow["month"] = month
    newRow["properties"] = {"rangeMin":yearMin,
                             "rangeMax":yearMax,
                             "month":month,
                             "script_used":SCRIPT_NAME,
                             "units":"millionm3",
                             "version":OUTPUT_VERSION,
                             "pfaf_level":PFAF_LEVEL,
                             "reducer":reducerType}
    newRow["newIcId"]= "%s/reduced_global_historical_combined" %(EE_PATH)
    newRow["newImageId"] = "%s/global_historical_%s_%s_%s_30sPfaf06_%s_%0.4d_%0.4dM%0.2d" %(newRow["newIcId"],shortIndicator,temporalResolution,"millionm3",reducerType,yearMin,yearMax,month)
    newRow["description"] = "reduced_global_historical_combined_%s_%s_%s_%0.2d" %(interval,reducerType,shortIndicator,OUTPUT_VERSION)
    
    return newRow
    


def createCollections(newIcId):        
    command = "earthengine create collection %s" %(newIcId) 
    print(command)
    result = subprocess.check_output(command,shell=True)
    if result:
        pass
    logger.error(result)
    
    
def exportAsset(imageOut,assetID,dimensions,description,properties,CRS_TRANSFORM30S_SMALL):
    try:
        ee.Image(assetID).id().getInfo()
        nonExisting = False
    except:
        nonExisting = True
    
    if  nonExisting:  
        imageOut = imageOut.set(properties)
        description = "global_historical_WS_%s_dimensionless_30sPfaf%0.2d_1960_2014Y%0.4dM%0.2dV%0.2d" %(row["temporalResolution"],PFAF_LEVEL,year,month,OUTPUT_VERSION)

        task = ee.batch.Export.image.toAsset(
            image =  ee.Image(imageOut),
            description = description,
            assetId = assetID,
            dimensions = dimensions,
            crs = CRS,
            crsTransform = CRS_TRANSFORM30S_SMALL,
            maxPixels = 1e10     
        )
        print(assetID)
        logger.debug(assetID)
        #task.start()

# %%
temporalResolutions = ["month","year"]

# %%
indicators = ["Q_millionm3","WW_millionm3","WN_millionm3"]

# %%
reducerTypes = ["mean","trend"]

# %%
intervals = ["long","short"]

# %%
df = pd.DataFrame()
for indicator in indicators:
    shortIndicator = indicator[:-10]
    for temporalResolution in temporalResolutions:
        for reducerType in reducerTypes:
            for interval in intervals:
                yearMin = temporalRange[interval][0]
                yearMax = temporalRange[interval][1]
                if temporalResolution == "year":
                    month = 12
                    icTemp = ee.ImageCollection(ic[temporalResolution]).select(indicator)
                    icTempFiltered = icTemp.filter(ee.Filter.gte("year",yearMin)).filter(ee.Filter.lte("year",yearMax))
                    
                    newRow = createRow()
                    df = df.append(newRow,ignore_index=True)                  


                elif temporalResolution == "month":
                    for month in range(1,13):
                        icTemp = ee.ImageCollection(ic[temporalResolution]).select(indicator)
                        icTempFiltered = icTemp.filter(ee.Filter.gte("year",yearMin)).filter(ee.Filter.lte("year",yearMax)).filter(ee.Filter.eq("month",month))
                        newRow = createRow()
                        df = df.append(newRow,ignore_index=True)

# %%
df
# Out:
#                                            description  \
# 0    reduced_global_historical_combined_long_mean_Q_01
# 1    reduced_global_historical_combined_long_mean_Q_01
# 2    reduced_global_historical_combined_long_mean_Q_01
# 3    reduced_global_historical_combined_long_mean_Q_01
# 4    reduced_global_historical_combined_long_mean_Q_01
# 5    reduced_global_historical_combined_long_mean_Q_01
# 6    reduced_global_historical_combined_long_mean_Q_01
# 7    reduced_global_historical_combined_long_mean_Q_01
# 8    reduced_global_historical_combined_long_mean_Q_01
# 9    reduced_global_historical_combined_long_mean_Q_01
# 10   reduced_global_historical_combined_long_mean_Q_01
# 11   reduced_global_historical_combined_long_mean_Q_01
# 12   reduced_global_historical_combined_short_mean_...
# 13   reduced_global_historical_combined_short_mean_...
# 14   reduced_global_historical_combined_short_mean_...
# 15   reduced_global_historical_combined_short_mean_...
# 16   reduced_global_historical_combined_short_mean_...
# 17   reduced_global_historical_combined_short_mean_...
# 18   reduced_global_historical_combined_short_mean_...
# 19   reduced_global_historical_combined_short_mean_...
# 20   reduced_global_historical_combined_short_mean_...
# 21   reduced_global_historical_combined_short_mean_...
# 22   reduced_global_historical_combined_short_mean_...
# 23   reduced_global_historical_combined_short_mean_...
# 24   reduced_global_historical_combined_long_trend_...
# 25   reduced_global_historical_combined_long_trend_...
# 26   reduced_global_historical_combined_long_trend_...
# 27   reduced_global_historical_combined_long_trend_...
# 28   reduced_global_historical_combined_long_trend_...
# 29   reduced_global_historical_combined_long_trend_...
# ..                                                 ...
# 126  reduced_global_historical_combined_short_mean_...
# 127  reduced_global_historical_combined_short_mean_...
# 128  reduced_global_historical_combined_long_trend_...
# 129  reduced_global_historical_combined_long_trend_...
# 130  reduced_global_historical_combined_long_trend_...
# 131  reduced_global_historical_combined_long_trend_...
# 132  reduced_global_historical_combined_long_trend_...
# 133  reduced_global_historical_combined_long_trend_...
# 134  reduced_global_historical_combined_long_trend_...
# 135  reduced_global_historical_combined_long_trend_...
# 136  reduced_global_historical_combined_long_trend_...
# 137  reduced_global_historical_combined_long_trend_...
# 138  reduced_global_historical_combined_long_trend_...
# 139  reduced_global_historical_combined_long_trend_...
# 140  reduced_global_historical_combined_short_trend...
# 141  reduced_global_historical_combined_short_trend...
# 142  reduced_global_historical_combined_short_trend...
# 143  reduced_global_historical_combined_short_trend...
# 144  reduced_global_historical_combined_short_trend...
# 145  reduced_global_historical_combined_short_trend...
# 146  reduced_global_historical_combined_short_trend...
# 147  reduced_global_historical_combined_short_trend...
# 148  reduced_global_historical_combined_short_trend...
# 149  reduced_global_historical_combined_short_trend...
# 150  reduced_global_historical_combined_short_trend...
# 151  reduced_global_historical_combined_short_trend...
# 152  reduced_global_historical_combined_long_mean_W...
# 153  reduced_global_historical_combined_short_mean_...
# 154  reduced_global_historical_combined_long_trend_...
# 155  reduced_global_historical_combined_short_trend...
#
#                                                     ic indicator interval  \
# 0    ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 1    ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 2    ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 3    ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 4    ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 5    ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 6    ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 7    ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 8    ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 9    ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 10   ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 11   ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 12   ee.ImageCollection({\n  "type": "Invocation", ...         Q    short
# 13   ee.ImageCollection({\n  "type": "Invocation", ...         Q    short
# 14   ee.ImageCollection({\n  "type": "Invocation", ...         Q    short
# 15   ee.ImageCollection({\n  "type": "Invocation", ...         Q    short
# 16   ee.ImageCollection({\n  "type": "Invocation", ...         Q    short
# 17   ee.ImageCollection({\n  "type": "Invocation", ...         Q    short
# 18   ee.ImageCollection({\n  "type": "Invocation", ...         Q    short
# 19   ee.ImageCollection({\n  "type": "Invocation", ...         Q    short
# 20   ee.ImageCollection({\n  "type": "Invocation", ...         Q    short
# 21   ee.ImageCollection({\n  "type": "Invocation", ...         Q    short
# 22   ee.ImageCollection({\n  "type": "Invocation", ...         Q    short
# 23   ee.ImageCollection({\n  "type": "Invocation", ...         Q    short
# 24   ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 25   ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 26   ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 27   ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 28   ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# 29   ee.ImageCollection({\n  "type": "Invocation", ...         Q     long
# ..                                                 ...       ...      ...
# 126  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 127  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 128  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 129  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 130  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 131  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 132  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 133  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 134  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 135  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 136  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 137  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 138  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 139  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 140  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 141  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 142  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 143  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 144  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 145  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 146  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 147  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 148  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 149  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 150  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 151  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 152  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 153  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
# 154  ee.ImageCollection({\n  "type": "Invocation", ...        WN     long
# 155  ee.ImageCollection({\n  "type": "Invocation", ...        WN    short
#
#      month                                            newIcId  \
# 0      1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 1      2.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 2      3.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 3      4.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 4      5.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 5      6.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 6      7.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 7      8.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 8      9.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 9     10.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 10    11.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 11    12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 12     1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 13     2.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 14     3.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 15     4.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 16     5.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 17     6.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 18     7.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 19     8.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 20     9.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 21    10.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 22    11.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 23    12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 24     1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 25     2.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 26     3.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 27     4.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 28     5.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 29     6.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# ..     ...                                                ...
# 126   11.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 127   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 128    1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 129    2.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 130    3.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 131    4.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 132    5.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 133    6.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 134    7.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 135    8.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 136    9.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 137   10.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 138   11.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 139   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 140    1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 141    2.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 142    3.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 143    4.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 144    5.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 145    6.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 146    7.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 147    8.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 148    9.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 149   10.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 150   11.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 151   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 152   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 153   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 154   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 155   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
#
#                                             newImageId  \
# 0    projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 1    projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 2    projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 3    projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 4    projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 5    projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 6    projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 7    projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 8    projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 9    projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 10   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 11   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 12   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 13   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 14   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 15   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 16   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 17   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 18   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 19   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 20   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 21   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 22   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 23   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 24   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 25   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 26   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 27   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 28   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 29   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# ..                                                 ...
# 126  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 127  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 128  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 129  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 130  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 131  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 132  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 133  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 134  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 135  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 136  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 137  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 138  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 139  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 140  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 141  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 142  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 143  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 144  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 145  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 146  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 147  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 148  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 149  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 150  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 151  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 152  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 153  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 154  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 155  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
#
#                                             properties reducerType  \
# 0    {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 1    {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 2    {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 3    {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 4    {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 5    {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 6    {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 7    {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 8    {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 9    {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 10   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 11   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 12   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 13   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 14   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 15   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 16   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 17   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 18   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 19   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 20   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 21   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 22   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 23   {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 24   {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 25   {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 26   {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 27   {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 28   {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 29   {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# ..                                                 ...         ...
# 126  {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 127  {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 128  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 129  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 130  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 131  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 132  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 133  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 134  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 135  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 136  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 137  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 138  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 139  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 140  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 141  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 142  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 143  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 144  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 145  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 146  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 147  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 148  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 149  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 150  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 151  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 152  {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 153  {u'script_used': u'Y2017M12D15_RH_Statistics_T...        mean
# 154  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
# 155  {u'script_used': u'Y2017M12D15_RH_Statistics_T...       trend
#
#     temporalResolution  yearMax  yearMin
# 0                month   2014.0   1960.0
# 1                month   2014.0   1960.0
# 2                month   2014.0   1960.0
# 3                month   2014.0   1960.0
# 4                month   2014.0   1960.0
# 5                month   2014.0   1960.0
# 6                month   2014.0   1960.0
# 7                month   2014.0   1960.0
# 8                month   2014.0   1960.0
# 9                month   2014.0   1960.0
# 10               month   2014.0   1960.0
# 11               month   2014.0   1960.0
# 12               month   2014.0   2004.0
# 13               month   2014.0   2004.0
# 14               month   2014.0   2004.0
# 15               month   2014.0   2004.0
# 16               month   2014.0   2004.0
# 17               month   2014.0   2004.0
# 18               month   2014.0   2004.0
# 19               month   2014.0   2004.0
# 20               month   2014.0   2004.0
# 21               month   2014.0   2004.0
# 22               month   2014.0   2004.0
# 23               month   2014.0   2004.0
# 24               month   2014.0   1960.0
# 25               month   2014.0   1960.0
# 26               month   2014.0   1960.0
# 27               month   2014.0   1960.0
# 28               month   2014.0   1960.0
# 29               month   2014.0   1960.0
# ..                 ...      ...      ...
# 126              month   2014.0   2004.0
# 127              month   2014.0   2004.0
# 128              month   2014.0   1960.0
# 129              month   2014.0   1960.0
# 130              month   2014.0   1960.0
# 131              month   2014.0   1960.0
# 132              month   2014.0   1960.0
# 133              month   2014.0   1960.0
# 134              month   2014.0   1960.0
# 135              month   2014.0   1960.0
# 136              month   2014.0   1960.0
# 137              month   2014.0   1960.0
# 138              month   2014.0   1960.0
# 139              month   2014.0   1960.0
# 140              month   2014.0   2004.0
# 141              month   2014.0   2004.0
# 142              month   2014.0   2004.0
# 143              month   2014.0   2004.0
# 144              month   2014.0   2004.0
# 145              month   2014.0   2004.0
# 146              month   2014.0   2004.0
# 147              month   2014.0   2004.0
# 148              month   2014.0   2004.0
# 149              month   2014.0   2004.0
# 150              month   2014.0   2004.0
# 151              month   2014.0   2004.0
# 152               year   2014.0   1960.0
# 153               year   2014.0   2004.0
# 154               year   2014.0   1960.0
# 155               year   2014.0   2004.0
#
# [156 rows x 12 columns]

# %%
createCollections(df["newIcId"].unique()[0])
# Out:
# earthengine create collection projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined

# %%
for index, row in df.iterrows():
    if row["reducerType"] == "mean":
        iReduced = ee.Image(ee.ImageCollection(row["ic"]).reduce(ee.Reducer.mean()))
        exportAsset(iReduced,row["newImageId"],DIMENSIONS30SSMALL,row["description"],row["properties"],CRS_TRANSFORM30S_SMALL)
    elif row["reducerType"] == "trend":
# Out:
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_1960_2014M01
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_1960_2014M02
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_1960_2014M03
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_1960_2014M04
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_1960_2014M05
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_1960_2014M06
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_1960_2014M07
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_1960_2014M08
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_1960_2014M09
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_1960_2014M10
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_1960_2014M11
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_1960_2014M12
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_2004_2014M01
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_2004_2014M02
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_2004_2014M03
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_2004_2014M04
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_2004_2014M05
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_2004_2014M06
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_2004_2014M07
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_2004_2014M08
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_2004_2014M09
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_2004_2014M10
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_2004_2014M11
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_month_millionm3_30sPfaf06_mean_2004_2014M12
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_year_millionm3_30sPfaf06_mean_1960_2014M12
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_Q_year_millionm3_30sPfaf06_mean_2004_2014M12
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_1960_2014M01
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_1960_2014M02
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_1960_2014M03
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_1960_2014M04
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_1960_2014M05
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_1960_2014M06
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_1960_2014M07
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_1960_2014M08
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_1960_2014M09
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_1960_2014M10
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_1960_2014M11
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_1960_2014M12
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_2004_2014M01
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_2004_2014M02
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_2004_2014M03
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_2004_2014M04
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_2004_2014M05
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_2004_2014M06
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_2004_2014M07
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_2004_2014M08
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_2004_2014M09
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_2004_2014M10
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_2004_2014M11
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_month_millionm3_30sPfaf06_mean_2004_2014M12
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_year_millionm3_30sPfaf06_mean_1960_2014M12
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WW_year_millionm3_30sPfaf06_mean_2004_2014M12
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_1960_2014M01
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_1960_2014M02
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_1960_2014M03
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_1960_2014M04
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_1960_2014M05
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_1960_2014M06
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_1960_2014M07
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_1960_2014M08
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_1960_2014M09
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_1960_2014M10
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_1960_2014M11
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_1960_2014M12
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_2004_2014M01
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_2004_2014M02
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_2004_2014M03
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_2004_2014M04
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_2004_2014M05
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_2004_2014M06
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_2004_2014M07
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_2004_2014M08
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_2004_2014M09
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_2004_2014M10
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_2004_2014M11
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_month_millionm3_30sPfaf06_mean_2004_2014M12
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_year_millionm3_30sPfaf06_mean_1960_2014M12
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined/global_historical_WN_year_millionm3_30sPfaf06_mean_2004_2014M12
