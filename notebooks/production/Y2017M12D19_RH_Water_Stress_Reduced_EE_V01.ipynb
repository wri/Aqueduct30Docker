# %% [markdown]
# # Y2017M12D19_RH_Water_Stress_Reduced_EE_V01
#
# * Purpose of script: Calculate water stress using reduced (Long/Short Mean/Trend) maximum discharge and total withdrawals.
# * Kernel used: python27
# * Date created: 20171219

# %%
import time, datetime, sys
dateString = time.strftime("Y%YM%mD%d")
timeString = time.strftime("UTC %H:%M")
start = datetime.datetime.now()
print(dateString,timeString)
sys.version
# Out:
# ('Y2017M12D19', 'UTC 16:20')
# '2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:09:15) \n[GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]'

# %%
EE_PATH = "projects/WRI-Aquaduct/PCRGlobWB20V07"

SCRIPT_NAME = "Y2017M12D19_RH_Water_Stress_Reduced_EE_V01"

OUTPUT_VERSION = 5  #must be same as previous script (stores in same imageCollection)

PFAF_LEVEL = 6

YEARMIN = 1960
YEARMAX = 2014

SHORT_TERM_MIN = 2004
SHORT_TERM_MAX = 2014

LONG_TERM_MIN = 1960
LONG_TERM_MAX = 2014

DIMENSIONS30SSMALL = "43200x19440"
CRS = "EPSG:4326"
CRS_TRANSFORM30S_SMALL = [0.008333333333333333, 0.0, -180.0, 0.0, -0.008333333333333333, 81.0]

# %%
import ee
import logging
import pandas as pd
import subprocess

# %%
ee.Initialize()

# %%
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s:%(levelname)s:%(message)s')
file_handler = logging.FileHandler("./logs/%sV%0.2d.log" %(SCRIPT_NAME,OUTPUT_VERSION))
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# %%
icResults = ee.ImageCollection("projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05")

# %%
temporalResolutions = ["month","year"]

# %%
indicators = ["Q_millionm3","WW_millionm3","WN_millionm3"]

# %%
reducerTypes = ["mean","trend"]

# %%
intervals = ["long","short"]

# %% [markdown]
# Water Stress (WS) is defined as total withdrawal (WW) / (Maximum Discharge Q + Local Consumption WN)
#
# we calculate 4 stress metrics per temporalResolution:
#
# 1. mean short
# 1. mean long
# 1. trend short
# 1. trend long

# %%
temporalRange = {}
temporalRange["short"] = [SHORT_TERM_MIN,SHORT_TERM_MAX]
temporalRange["long"] = [LONG_TERM_MIN,LONG_TERM_MAX]

# %%
def createRow():
    newRow = {}
    newRow["indicator"] = indicator
    newRow["temporalResolution"] = temporalResolution
    newRow["reducerType"] =  reducerType
    newRow["interval"] = interval
    newRow["yearMin"] = yearMin
    newRow["yearMax"] = yearMax 

    newRow["Q"] = Q
    newRow["WW"] = WW
    newRow["WN"] = WN
    newRow["month"] = month
    newRow["properties"] = {"rangeMin":yearMin,
                             "rangeMax":yearMax,
                             "interval":interval,
                             "indicator":indicator,
                             "temporalResolution": temporalResolution,
                             "month":month,
                             "script_used":SCRIPT_NAME,
                             "units":"dimensionless",
                             "version":OUTPUT_VERSION,
                             "pfaf_level":PFAF_LEVEL,
                             "reducer":reducerType
                           }
    newRow["newIcId"]= "%s/reduced_global_historical_combined_V%0.2d" %(EE_PATH,OUTPUT_VERSION)
    newRow["newImageId"] = "%s/global_historical_%s_%s_%s_30sPfaf06_%s_%0.4d_%0.4dM%0.2d" %(newRow["newIcId"],indicator,temporalResolution,"dimensionless",reducerType,yearMin,yearMax,month)
    newRow["description"] = "reduced_global_historical_combined_%s_%s_%s_V%0.2d" %(interval,reducerType,indicator,OUTPUT_VERSION)
    
    return newRow


def calculateWS(Q,WW,WN):
    BA = Q.add(WN)            
    WS = WW.divide(BA)
    WS = WS.select(WS.bandNames(),["WS_dimensionless"])
    imageOut = WS.addBands(Q).addBands(WW).addBands(WN)
    return imageOut

def exportAsset(imageOut,assetID,dimensions,description,properties,CRS_TRANSFORM30S_SMALL):
    try:
        ee.Image(assetID).id().getInfo()
        nonExisting = False
    except:
        nonExisting = True
    
    if  nonExisting:  
        imageOut = imageOut.set(properties)

        task = ee.batch.Export.image.toAsset(
            image =  ee.Image(imageOut),
            description = description,
            assetId = assetID,
            dimensions = dimensions,
            crs = CRS,
            crsTransform = CRS_TRANSFORM30S_SMALL,
            maxPixels = 1e10     
        )
        print(assetID)
        logger.debug(assetID)
        task.start()

# %%
indicator = "WS"
df = pd.DataFrame()
for temporalResolution in temporalResolutions:
    for reducerType in reducerTypes:
        for interval in intervals:
            yearMin = temporalRange[interval][0]
            yearMax = temporalRange[interval][1]
            if temporalResolution == "year":
                month = 12
                icTemp = icResults.filter(ee.Filter.eq("temporalResolution",temporalResolution)).filter(ee.Filter.eq("reducer",reducerType)).filter(ee.Filter.eq("interval",interval))
                
                Q = ee.Image(icTemp.filter(ee.Filter.eq("indicator","Q")).first())
                WW = ee.Image(icTemp.filter(ee.Filter.eq("indicator","WW")).first())
                WN = ee.Image(icTemp.filter(ee.Filter.eq("indicator","WN")).first())
                
                if reducerType == "trend":
                    Q = Q.select(["newValue"])
                    WW = WW.select(["newValue"])
                    WN = WN.select(["newValue"])
                
                newRow = createRow()
                df = df.append(newRow,ignore_index=True)
            elif temporalResolution == "month":
                for month in range(1,13):
                    icTemp = icResults.filter(ee.Filter.eq("temporalResolution",temporalResolution)).filter(ee.Filter.eq("reducer",reducerType)).filter(ee.Filter.eq("interval",interval)).filter(ee.Filter.eq("month",month))
                    Q = ee.Image(icTemp.filter(ee.Filter.eq("indicator","Q")).first())
                    WW = ee.Image(icTemp.filter(ee.Filter.eq("indicator","WW")).first())
                    WN = ee.Image(icTemp.filter(ee.Filter.eq("indicator","WN")).first())
                    if reducerType == "trend":
                        Q = Q.select(["newValue"])
                        WW = WW.select(["newValue"])
                        WN = WN.select(["newValue"])

                    newRow = createRow()
                    df = df.append(newRow,ignore_index=True)

# %%
df
# Out:
#                                                     Q  \
# 0   ee.Image({\n  "type": "Invocation", \n  "argum...
# 1   ee.Image({\n  "type": "Invocation", \n  "argum...
# 2   ee.Image({\n  "type": "Invocation", \n  "argum...
# 3   ee.Image({\n  "type": "Invocation", \n  "argum...
# 4   ee.Image({\n  "type": "Invocation", \n  "argum...
# 5   ee.Image({\n  "type": "Invocation", \n  "argum...
# 6   ee.Image({\n  "type": "Invocation", \n  "argum...
# 7   ee.Image({\n  "type": "Invocation", \n  "argum...
# 8   ee.Image({\n  "type": "Invocation", \n  "argum...
# 9   ee.Image({\n  "type": "Invocation", \n  "argum...
# 10  ee.Image({\n  "type": "Invocation", \n  "argum...
# 11  ee.Image({\n  "type": "Invocation", \n  "argum...
# 12  ee.Image({\n  "type": "Invocation", \n  "argum...
# 13  ee.Image({\n  "type": "Invocation", \n  "argum...
# 14  ee.Image({\n  "type": "Invocation", \n  "argum...
# 15  ee.Image({\n  "type": "Invocation", \n  "argum...
# 16  ee.Image({\n  "type": "Invocation", \n  "argum...
# 17  ee.Image({\n  "type": "Invocation", \n  "argum...
# 18  ee.Image({\n  "type": "Invocation", \n  "argum...
# 19  ee.Image({\n  "type": "Invocation", \n  "argum...
# 20  ee.Image({\n  "type": "Invocation", \n  "argum...
# 21  ee.Image({\n  "type": "Invocation", \n  "argum...
# 22  ee.Image({\n  "type": "Invocation", \n  "argum...
# 23  ee.Image({\n  "type": "Invocation", \n  "argum...
# 24  ee.Image({\n  "type": "Invocation", \n  "argum...
# 25  ee.Image({\n  "type": "Invocation", \n  "argum...
# 26  ee.Image({\n  "type": "Invocation", \n  "argum...
# 27  ee.Image({\n  "type": "Invocation", \n  "argum...
# 28  ee.Image({\n  "type": "Invocation", \n  "argum...
# 29  ee.Image({\n  "type": "Invocation", \n  "argum...
# 30  ee.Image({\n  "type": "Invocation", \n  "argum...
# 31  ee.Image({\n  "type": "Invocation", \n  "argum...
# 32  ee.Image({\n  "type": "Invocation", \n  "argum...
# 33  ee.Image({\n  "type": "Invocation", \n  "argum...
# 34  ee.Image({\n  "type": "Invocation", \n  "argum...
# 35  ee.Image({\n  "type": "Invocation", \n  "argum...
# 36  ee.Image({\n  "type": "Invocation", \n  "argum...
# 37  ee.Image({\n  "type": "Invocation", \n  "argum...
# 38  ee.Image({\n  "type": "Invocation", \n  "argum...
# 39  ee.Image({\n  "type": "Invocation", \n  "argum...
# 40  ee.Image({\n  "type": "Invocation", \n  "argum...
# 41  ee.Image({\n  "type": "Invocation", \n  "argum...
# 42  ee.Image({\n  "type": "Invocation", \n  "argum...
# 43  ee.Image({\n  "type": "Invocation", \n  "argum...
# 44  ee.Image({\n  "type": "Invocation", \n  "argum...
# 45  ee.Image({\n  "type": "Invocation", \n  "argum...
# 46  ee.Image({\n  "type": "Invocation", \n  "argum...
# 47  ee.Image({\n  "type": "Invocation", \n  "argum...
# 48  ee.Image({\n  "type": "Invocation", \n  "argum...
# 49  ee.Image({\n  "type": "Invocation", \n  "argum...
# 50  ee.Image({\n  "type": "Invocation", \n  "argum...
# 51  ee.Image({\n  "type": "Invocation", \n  "argum...
#
#                                                    WN  \
# 0   ee.Image({\n  "type": "Invocation", \n  "argum...
# 1   ee.Image({\n  "type": "Invocation", \n  "argum...
# 2   ee.Image({\n  "type": "Invocation", \n  "argum...
# 3   ee.Image({\n  "type": "Invocation", \n  "argum...
# 4   ee.Image({\n  "type": "Invocation", \n  "argum...
# 5   ee.Image({\n  "type": "Invocation", \n  "argum...
# 6   ee.Image({\n  "type": "Invocation", \n  "argum...
# 7   ee.Image({\n  "type": "Invocation", \n  "argum...
# 8   ee.Image({\n  "type": "Invocation", \n  "argum...
# 9   ee.Image({\n  "type": "Invocation", \n  "argum...
# 10  ee.Image({\n  "type": "Invocation", \n  "argum...
# 11  ee.Image({\n  "type": "Invocation", \n  "argum...
# 12  ee.Image({\n  "type": "Invocation", \n  "argum...
# 13  ee.Image({\n  "type": "Invocation", \n  "argum...
# 14  ee.Image({\n  "type": "Invocation", \n  "argum...
# 15  ee.Image({\n  "type": "Invocation", \n  "argum...
# 16  ee.Image({\n  "type": "Invocation", \n  "argum...
# 17  ee.Image({\n  "type": "Invocation", \n  "argum...
# 18  ee.Image({\n  "type": "Invocation", \n  "argum...
# 19  ee.Image({\n  "type": "Invocation", \n  "argum...
# 20  ee.Image({\n  "type": "Invocation", \n  "argum...
# 21  ee.Image({\n  "type": "Invocation", \n  "argum...
# 22  ee.Image({\n  "type": "Invocation", \n  "argum...
# 23  ee.Image({\n  "type": "Invocation", \n  "argum...
# 24  ee.Image({\n  "type": "Invocation", \n  "argum...
# 25  ee.Image({\n  "type": "Invocation", \n  "argum...
# 26  ee.Image({\n  "type": "Invocation", \n  "argum...
# 27  ee.Image({\n  "type": "Invocation", \n  "argum...
# 28  ee.Image({\n  "type": "Invocation", \n  "argum...
# 29  ee.Image({\n  "type": "Invocation", \n  "argum...
# 30  ee.Image({\n  "type": "Invocation", \n  "argum...
# 31  ee.Image({\n  "type": "Invocation", \n  "argum...
# 32  ee.Image({\n  "type": "Invocation", \n  "argum...
# 33  ee.Image({\n  "type": "Invocation", \n  "argum...
# 34  ee.Image({\n  "type": "Invocation", \n  "argum...
# 35  ee.Image({\n  "type": "Invocation", \n  "argum...
# 36  ee.Image({\n  "type": "Invocation", \n  "argum...
# 37  ee.Image({\n  "type": "Invocation", \n  "argum...
# 38  ee.Image({\n  "type": "Invocation", \n  "argum...
# 39  ee.Image({\n  "type": "Invocation", \n  "argum...
# 40  ee.Image({\n  "type": "Invocation", \n  "argum...
# 41  ee.Image({\n  "type": "Invocation", \n  "argum...
# 42  ee.Image({\n  "type": "Invocation", \n  "argum...
# 43  ee.Image({\n  "type": "Invocation", \n  "argum...
# 44  ee.Image({\n  "type": "Invocation", \n  "argum...
# 45  ee.Image({\n  "type": "Invocation", \n  "argum...
# 46  ee.Image({\n  "type": "Invocation", \n  "argum...
# 47  ee.Image({\n  "type": "Invocation", \n  "argum...
# 48  ee.Image({\n  "type": "Invocation", \n  "argum...
# 49  ee.Image({\n  "type": "Invocation", \n  "argum...
# 50  ee.Image({\n  "type": "Invocation", \n  "argum...
# 51  ee.Image({\n  "type": "Invocation", \n  "argum...
#
#                                                    WW  \
# 0   ee.Image({\n  "type": "Invocation", \n  "argum...
# 1   ee.Image({\n  "type": "Invocation", \n  "argum...
# 2   ee.Image({\n  "type": "Invocation", \n  "argum...
# 3   ee.Image({\n  "type": "Invocation", \n  "argum...
# 4   ee.Image({\n  "type": "Invocation", \n  "argum...
# 5   ee.Image({\n  "type": "Invocation", \n  "argum...
# 6   ee.Image({\n  "type": "Invocation", \n  "argum...
# 7   ee.Image({\n  "type": "Invocation", \n  "argum...
# 8   ee.Image({\n  "type": "Invocation", \n  "argum...
# 9   ee.Image({\n  "type": "Invocation", \n  "argum...
# 10  ee.Image({\n  "type": "Invocation", \n  "argum...
# 11  ee.Image({\n  "type": "Invocation", \n  "argum...
# 12  ee.Image({\n  "type": "Invocation", \n  "argum...
# 13  ee.Image({\n  "type": "Invocation", \n  "argum...
# 14  ee.Image({\n  "type": "Invocation", \n  "argum...
# 15  ee.Image({\n  "type": "Invocation", \n  "argum...
# 16  ee.Image({\n  "type": "Invocation", \n  "argum...
# 17  ee.Image({\n  "type": "Invocation", \n  "argum...
# 18  ee.Image({\n  "type": "Invocation", \n  "argum...
# 19  ee.Image({\n  "type": "Invocation", \n  "argum...
# 20  ee.Image({\n  "type": "Invocation", \n  "argum...
# 21  ee.Image({\n  "type": "Invocation", \n  "argum...
# 22  ee.Image({\n  "type": "Invocation", \n  "argum...
# 23  ee.Image({\n  "type": "Invocation", \n  "argum...
# 24  ee.Image({\n  "type": "Invocation", \n  "argum...
# 25  ee.Image({\n  "type": "Invocation", \n  "argum...
# 26  ee.Image({\n  "type": "Invocation", \n  "argum...
# 27  ee.Image({\n  "type": "Invocation", \n  "argum...
# 28  ee.Image({\n  "type": "Invocation", \n  "argum...
# 29  ee.Image({\n  "type": "Invocation", \n  "argum...
# 30  ee.Image({\n  "type": "Invocation", \n  "argum...
# 31  ee.Image({\n  "type": "Invocation", \n  "argum...
# 32  ee.Image({\n  "type": "Invocation", \n  "argum...
# 33  ee.Image({\n  "type": "Invocation", \n  "argum...
# 34  ee.Image({\n  "type": "Invocation", \n  "argum...
# 35  ee.Image({\n  "type": "Invocation", \n  "argum...
# 36  ee.Image({\n  "type": "Invocation", \n  "argum...
# 37  ee.Image({\n  "type": "Invocation", \n  "argum...
# 38  ee.Image({\n  "type": "Invocation", \n  "argum...
# 39  ee.Image({\n  "type": "Invocation", \n  "argum...
# 40  ee.Image({\n  "type": "Invocation", \n  "argum...
# 41  ee.Image({\n  "type": "Invocation", \n  "argum...
# 42  ee.Image({\n  "type": "Invocation", \n  "argum...
# 43  ee.Image({\n  "type": "Invocation", \n  "argum...
# 44  ee.Image({\n  "type": "Invocation", \n  "argum...
# 45  ee.Image({\n  "type": "Invocation", \n  "argum...
# 46  ee.Image({\n  "type": "Invocation", \n  "argum...
# 47  ee.Image({\n  "type": "Invocation", \n  "argum...
# 48  ee.Image({\n  "type": "Invocation", \n  "argum...
# 49  ee.Image({\n  "type": "Invocation", \n  "argum...
# 50  ee.Image({\n  "type": "Invocation", \n  "argum...
# 51  ee.Image({\n  "type": "Invocation", \n  "argum...
#
#                                           description indicator interval  \
# 0   reduced_global_historical_combined_long_mean_W...        WS     long
# 1   reduced_global_historical_combined_long_mean_W...        WS     long
# 2   reduced_global_historical_combined_long_mean_W...        WS     long
# 3   reduced_global_historical_combined_long_mean_W...        WS     long
# 4   reduced_global_historical_combined_long_mean_W...        WS     long
# 5   reduced_global_historical_combined_long_mean_W...        WS     long
# 6   reduced_global_historical_combined_long_mean_W...        WS     long
# 7   reduced_global_historical_combined_long_mean_W...        WS     long
# 8   reduced_global_historical_combined_long_mean_W...        WS     long
# 9   reduced_global_historical_combined_long_mean_W...        WS     long
# 10  reduced_global_historical_combined_long_mean_W...        WS     long
# 11  reduced_global_historical_combined_long_mean_W...        WS     long
# 12  reduced_global_historical_combined_short_mean_...        WS    short
# 13  reduced_global_historical_combined_short_mean_...        WS    short
# 14  reduced_global_historical_combined_short_mean_...        WS    short
# 15  reduced_global_historical_combined_short_mean_...        WS    short
# 16  reduced_global_historical_combined_short_mean_...        WS    short
# 17  reduced_global_historical_combined_short_mean_...        WS    short
# 18  reduced_global_historical_combined_short_mean_...        WS    short
# 19  reduced_global_historical_combined_short_mean_...        WS    short
# 20  reduced_global_historical_combined_short_mean_...        WS    short
# 21  reduced_global_historical_combined_short_mean_...        WS    short
# 22  reduced_global_historical_combined_short_mean_...        WS    short
# 23  reduced_global_historical_combined_short_mean_...        WS    short
# 24  reduced_global_historical_combined_long_trend_...        WS     long
# 25  reduced_global_historical_combined_long_trend_...        WS     long
# 26  reduced_global_historical_combined_long_trend_...        WS     long
# 27  reduced_global_historical_combined_long_trend_...        WS     long
# 28  reduced_global_historical_combined_long_trend_...        WS     long
# 29  reduced_global_historical_combined_long_trend_...        WS     long
# 30  reduced_global_historical_combined_long_trend_...        WS     long
# 31  reduced_global_historical_combined_long_trend_...        WS     long
# 32  reduced_global_historical_combined_long_trend_...        WS     long
# 33  reduced_global_historical_combined_long_trend_...        WS     long
# 34  reduced_global_historical_combined_long_trend_...        WS     long
# 35  reduced_global_historical_combined_long_trend_...        WS     long
# 36  reduced_global_historical_combined_short_trend...        WS    short
# 37  reduced_global_historical_combined_short_trend...        WS    short
# 38  reduced_global_historical_combined_short_trend...        WS    short
# 39  reduced_global_historical_combined_short_trend...        WS    short
# 40  reduced_global_historical_combined_short_trend...        WS    short
# 41  reduced_global_historical_combined_short_trend...        WS    short
# 42  reduced_global_historical_combined_short_trend...        WS    short
# 43  reduced_global_historical_combined_short_trend...        WS    short
# 44  reduced_global_historical_combined_short_trend...        WS    short
# 45  reduced_global_historical_combined_short_trend...        WS    short
# 46  reduced_global_historical_combined_short_trend...        WS    short
# 47  reduced_global_historical_combined_short_trend...        WS    short
# 48  reduced_global_historical_combined_long_mean_W...        WS     long
# 49  reduced_global_historical_combined_short_mean_...        WS    short
# 50  reduced_global_historical_combined_long_trend_...        WS     long
# 51  reduced_global_historical_combined_short_trend...        WS    short
#
#     month                                            newIcId  \
# 0     1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 1     2.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 2     3.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 3     4.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 4     5.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 5     6.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 6     7.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 7     8.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 8     9.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 9    10.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 10   11.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 11   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 12    1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 13    2.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 14    3.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 15    4.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 16    5.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 17    6.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 18    7.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 19    8.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 20    9.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 21   10.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 22   11.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 23   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 24    1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 25    2.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 26    3.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 27    4.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 28    5.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 29    6.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 30    7.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 31    8.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 32    9.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 33   10.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 34   11.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 35   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 36    1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 37    2.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 38    3.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 39    4.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 40    5.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 41    6.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 42    7.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 43    8.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 44    9.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 45   10.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 46   11.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 47   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 48   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 49   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 50   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 51   12.0  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
#
#                                            newImageId  \
# 0   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 1   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 2   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 3   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 4   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 5   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 6   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 7   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 8   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 9   projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 10  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 11  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 12  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 13  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 14  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 15  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 16  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 17  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 18  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 19  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 20  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 21  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 22  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 23  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 24  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 25  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 26  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 27  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 28  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 29  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 30  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 31  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 32  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 33  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 34  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 35  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 36  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 37  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 38  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 39  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 40  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 41  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 42  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 43  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 44  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 45  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 46  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 47  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 48  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 49  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 50  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
# 51  projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_g...
#
#                                            properties reducerType  \
# 0   {u'interval': u'long', u'temporalResolution': ...        mean
# 1   {u'interval': u'long', u'temporalResolution': ...        mean
# 2   {u'interval': u'long', u'temporalResolution': ...        mean
# 3   {u'interval': u'long', u'temporalResolution': ...        mean
# 4   {u'interval': u'long', u'temporalResolution': ...        mean
# 5   {u'interval': u'long', u'temporalResolution': ...        mean
# 6   {u'interval': u'long', u'temporalResolution': ...        mean
# 7   {u'interval': u'long', u'temporalResolution': ...        mean
# 8   {u'interval': u'long', u'temporalResolution': ...        mean
# 9   {u'interval': u'long', u'temporalResolution': ...        mean
# 10  {u'interval': u'long', u'temporalResolution': ...        mean
# 11  {u'interval': u'long', u'temporalResolution': ...        mean
# 12  {u'interval': u'short', u'temporalResolution':...        mean
# 13  {u'interval': u'short', u'temporalResolution':...        mean
# 14  {u'interval': u'short', u'temporalResolution':...        mean
# 15  {u'interval': u'short', u'temporalResolution':...        mean
# 16  {u'interval': u'short', u'temporalResolution':...        mean
# 17  {u'interval': u'short', u'temporalResolution':...        mean
# 18  {u'interval': u'short', u'temporalResolution':...        mean
# 19  {u'interval': u'short', u'temporalResolution':...        mean
# 20  {u'interval': u'short', u'temporalResolution':...        mean
# 21  {u'interval': u'short', u'temporalResolution':...        mean
# 22  {u'interval': u'short', u'temporalResolution':...        mean
# 23  {u'interval': u'short', u'temporalResolution':...        mean
# 24  {u'interval': u'long', u'temporalResolution': ...       trend
# 25  {u'interval': u'long', u'temporalResolution': ...       trend
# 26  {u'interval': u'long', u'temporalResolution': ...       trend
# 27  {u'interval': u'long', u'temporalResolution': ...       trend
# 28  {u'interval': u'long', u'temporalResolution': ...       trend
# 29  {u'interval': u'long', u'temporalResolution': ...       trend
# 30  {u'interval': u'long', u'temporalResolution': ...       trend
# 31  {u'interval': u'long', u'temporalResolution': ...       trend
# 32  {u'interval': u'long', u'temporalResolution': ...       trend
# 33  {u'interval': u'long', u'temporalResolution': ...       trend
# 34  {u'interval': u'long', u'temporalResolution': ...       trend
# 35  {u'interval': u'long', u'temporalResolution': ...       trend
# 36  {u'interval': u'short', u'temporalResolution':...       trend
# 37  {u'interval': u'short', u'temporalResolution':...       trend
# 38  {u'interval': u'short', u'temporalResolution':...       trend
# 39  {u'interval': u'short', u'temporalResolution':...       trend
# 40  {u'interval': u'short', u'temporalResolution':...       trend
# 41  {u'interval': u'short', u'temporalResolution':...       trend
# 42  {u'interval': u'short', u'temporalResolution':...       trend
# 43  {u'interval': u'short', u'temporalResolution':...       trend
# 44  {u'interval': u'short', u'temporalResolution':...       trend
# 45  {u'interval': u'short', u'temporalResolution':...       trend
# 46  {u'interval': u'short', u'temporalResolution':...       trend
# 47  {u'interval': u'short', u'temporalResolution':...       trend
# 48  {u'interval': u'long', u'temporalResolution': ...        mean
# 49  {u'interval': u'short', u'temporalResolution':...        mean
# 50  {u'interval': u'long', u'temporalResolution': ...       trend
# 51  {u'interval': u'short', u'temporalResolution':...       trend
#
#    temporalResolution  yearMax  yearMin
# 0               month   2014.0   1960.0
# 1               month   2014.0   1960.0
# 2               month   2014.0   1960.0
# 3               month   2014.0   1960.0
# 4               month   2014.0   1960.0
# 5               month   2014.0   1960.0
# 6               month   2014.0   1960.0
# 7               month   2014.0   1960.0
# 8               month   2014.0   1960.0
# 9               month   2014.0   1960.0
# 10              month   2014.0   1960.0
# 11              month   2014.0   1960.0
# 12              month   2014.0   2004.0
# 13              month   2014.0   2004.0
# 14              month   2014.0   2004.0
# 15              month   2014.0   2004.0
# 16              month   2014.0   2004.0
# 17              month   2014.0   2004.0
# 18              month   2014.0   2004.0
# 19              month   2014.0   2004.0
# 20              month   2014.0   2004.0
# 21              month   2014.0   2004.0
# 22              month   2014.0   2004.0
# 23              month   2014.0   2004.0
# 24              month   2014.0   1960.0
# 25              month   2014.0   1960.0
# 26              month   2014.0   1960.0
# 27              month   2014.0   1960.0
# 28              month   2014.0   1960.0
# 29              month   2014.0   1960.0
# 30              month   2014.0   1960.0
# 31              month   2014.0   1960.0
# 32              month   2014.0   1960.0
# 33              month   2014.0   1960.0
# 34              month   2014.0   1960.0
# 35              month   2014.0   1960.0
# 36              month   2014.0   2004.0
# 37              month   2014.0   2004.0
# 38              month   2014.0   2004.0
# 39              month   2014.0   2004.0
# 40              month   2014.0   2004.0
# 41              month   2014.0   2004.0
# 42              month   2014.0   2004.0
# 43              month   2014.0   2004.0
# 44              month   2014.0   2004.0
# 45              month   2014.0   2004.0
# 46              month   2014.0   2004.0
# 47              month   2014.0   2004.0
# 48               year   2014.0   1960.0
# 49               year   2014.0   2004.0
# 50               year   2014.0   1960.0
# 51               year   2014.0   2004.0

# %%
for index, row in df.iterrows():
    WS = calculateWS(row["Q"],row["WW"],row["WN"])
    exportAsset(WS,row["newImageId"],DIMENSIONS30SSMALL,row["description"],row["properties"],CRS_TRANSFORM30S_SMALL)
# Out:
# [u'WW_millionm3_mean']
# [u'WW_millionm3_mean']
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_1960_2014M03
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_1960_2014M04
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_1960_2014M05
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_1960_2014M06
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_1960_2014M07
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_1960_2014M08
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_1960_2014M09
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_1960_2014M10
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_1960_2014M11
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_1960_2014M12
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_2004_2014M01
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_2004_2014M02
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_2004_2014M03
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_2004_2014M04
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_2004_2014M05
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_2004_2014M06
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_2004_2014M07
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_2004_2014M08
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_2004_2014M09
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_2004_2014M10
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_2004_2014M11
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_mean_2004_2014M12
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_1960_2014M01
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_1960_2014M02
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_1960_2014M03
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_1960_2014M04
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_1960_2014M05
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_1960_2014M06
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_1960_2014M07
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_1960_2014M08
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_1960_2014M09
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_1960_2014M10
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_1960_2014M11
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_1960_2014M12
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_2004_2014M01
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_2004_2014M02
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_2004_2014M03
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_2004_2014M04
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_2004_2014M05
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_2004_2014M06
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_2004_2014M07
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_2004_2014M08
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_2004_2014M09
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_2004_2014M10
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_2004_2014M11
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_month_dimensionless_30sPfaf06_trend_2004_2014M12
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_year_dimensionless_30sPfaf06_mean_1960_2014M12
# [u'WW_millionm3_mean']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_year_dimensionless_30sPfaf06_mean_2004_2014M12
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_year_dimensionless_30sPfaf06_trend_1960_2014M12
# [u'newValue']
# projects/WRI-Aquaduct/PCRGlobWB20V07/reduced_global_historical_combined_V05/global_historical_WS_year_dimensionless_30sPfaf06_trend_2004_2014M12

# %%
end = datetime.datetime.now()
elapsed = end - start
print(elapsed)
# Out:
# 0:02:34.051907
