# %% [markdown]
# # Y2018M03D26_RH_Moving_Average_Discharge_To_GCS_V01
#
# * Purpose of script: store moving average results for discharge in a CSV file in GCS.
#
# * Script exports to:
# * Kernel used: python35
# * Date created: 20180324

# %%
import time, datetime, sys
dateString = time.strftime("Y%YM%mD%d")
timeString = time.strftime("UTC %H:%M")
start = datetime.datetime.now()
print(dateString,timeString)
sys.version
# Out:
# Y2018M03D26 UTC 10:23
# '3.5.4 |Continuum Analytics, Inc.| (default, Aug 14 2017, 13:26:58) \n[GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]'

# %%
SCRIPT_NAME = "Y2018M03D26_RH_Moving_Average_Discharge_To_GCS_V01"

INPUT_VERSION = 2

OUTPUT_VERSION = 2

EE_PATH = "projects/WRI-Aquaduct/PCRGlobWB20V07"

GCS_OUTPUT_PATH = "{}/outputV{:02.0f}/".format(SCRIPT_NAME,OUTPUT_VERSION)
GCS_BUCKET = "aqueduct30_v01"

TESTING = 0

# %%
import ee
import pandas as pd

# %%
ee.Initialize()

# %%
# Functions

def ensure_default_properties(obj):
    """ Sets the properties mean, count and sum for an object
    
    if a reduceRegion operation returns no values in earth engine
    one cannot join the result list with a list of the zones without
    setting a  nodata (-9999) value first
    
    Args:
        obj (ee.Dictionary) : earth engine object.
    
    Returns
        obj (ee.Dictionary) : dictionary with mean, count and sum 
                              set to -9999.    
    
    """
    obj = ee.Dictionary(obj)
    default_properties = ee.Dictionary({"mean": -9999,"count": -9999,"sum":-9999})
    return default_properties.combine(obj)

def mapList(results, key):
    """ filter results by key
    server side function.
    
    Args:
        results (ee.List) : list of result dictionaries.
        key (string) : key name.
    
    Returns:
        newResult (ee.List) : List of values
    
    
    """
    newResult = results.map(lambda x: ee.Dictionary(x).get(key))
    return newResult


def dict_to_feature(d):
    """ Convert a dictionary to an earth engine feature
    server side
    
    Args:
        d (ee.Dictionary) : server side dictionary
    Returns
        f (ee.Feature) : server side earth engine feature    
    """
    f = ee.Feature(None,ee.Dictionary(d))
    return f

def filter_ic(ic,year,month):
    """ filters an imagecollection based on year and month
    
    Args:
        ic (ee.ImageCollection) : ImageColllection to filter. Must have
                                  year and month properties.
        year (integer) : year
        month (integer) : month  
    Returns:
        image (ee.Image): filtered image
    
    TODO: if the filter operation results in more than one image, 
    an error should be raised.
    
    """
    
    ic_filtered = (ic.filter(ee.Filter.eq("month",month))
                    .filter(ee.Filter.eq("year",year)))
    image = ee.Image(ic_filtered.first())
    return(image)

def volumeToFlux(volume_image):
    """ convert volume image to flux
    WARNING: This function is applied (mapped) over an ic
    make sure the units / areas are consistent!
    
    Args:
        volume_image (ee.Image) : image with volume values (millionm3)
    
    Returns:
        flux_image (ee.Image) : Image with flux values (m) 
    
    """
    volume_image = ee.Image(volume_image)
    flux_image = volume_image.divide(ee.Image(area_30spfaf06_m2)).multiply(1e6).copyProperties(volume_image)
    flux_image = flux_image.set("units","m")
    flux_image = flux_image.set("convertedToFlux", 1)
    return flux_image


def zonalStatsToFeatureCollection(image,zonesImage,geometry,maxPixels,reducerType):
    """ Zonal statistics with rasters as input and rasters and lists as output
    
    Args:
        image (ee.Image) : image with value. Make sure the dimensions and units are 
                           compatible with the zones image.
        zonesImage (ee.Image) : image with zones stores as unique integers. Dimensions
                                must match image argument.
        geometry (ee.Geometry) : geometry specifying the extent of the calculation.
        maxPixels (integer) : Maximum number of pixels in calculation. Defaults to 1e10.
        reducerType (string) : reducer type. Options include mean max sum first and mode.
        
    Returns:
        resultList (ee.List) : List of dictionaries     
    
    
    """
    # reducertype can be mean, max, sum, first. Count is always included for QA
    # the resolution of the zonesimage is used for scale

    reducer = ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"mean"),ee.Reducer.mean(),
    ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"max"),ee.Reducer.max(),
    ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"sum"),ee.Reducer.sum(),
    ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"first"),ee.Reducer.first(),
    ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"mode"),ee.Reducer.mode(),"error"))))
    )
    reducer = ee.Reducer(reducer).combine(reducer2= ee.Reducer.count(), sharedInputs= True).group(groupField=1, groupName="zones") 

    scale = zonesImage.projection().nominalScale().getInfo()
    zonesImage = zonesImage.select(zonesImage.bandNames(),["zones"])

    totalImage = ee.Image(image).addBands(zonesImage)
    resultsList = ee.List(totalImage.reduceRegion(
        geometry= geometry, 
        reducer= reducer,
        scale= scale,
        maxPixels=maxPixels
        ).get("groups"))

    resultsList = resultsList.map(ensure_default_properties); 
    fc = ee.FeatureCollection(resultsList.map(dict_to_feature))

    return fc

def export_table_to_cloudstorage(fc,description,fileNamePrefix):
    """ Export a google earth engine featureCollection to an asset folder
    
    WARNING: Choose the filename wisely. Adding properties is inefficent
    store all properties in filename. 
    
    function will start a new task. To view the status of the task
    check the javascript API or query tasks script. Function is used 
    as mapped function so other arguments need to be set globally. 
    
    Args:
        fc (ee.FeatureCollection) : featureCollection to export
        
    Returns:
           
    """
    
    task = ee.batch.Export.table.toCloudStorage(
        collection =  ee.FeatureCollection(fc),
        description = description,
        bucket = GCS_BUCKET,
        fileNamePrefix = GCS_OUTPUT_PATH + fileNamePrefix,
        fileFormat = "CSV"
    )
    task.start()

# %%
geometry = ee.Geometry.Polygon(coords=[[-180.0, -90.0], [180,  -90.0], [180, 90], [-180,90]], proj= ee.Projection('EPSG:4326'),geodesic=False )

# %%
temp_image = ee.Image("projects/WRI-Aquaduct/PCRGlobWB20V07/area_30spfaf06_m2_V01V01")
area_30spfaf06_m2 = temp_image.select(["sum"])
zones_30spfaf06 = temp_image.select(["zones"])

# %%
months = range(1,13)
years = range(1960+9,2014+1)
indicators = ["availabledischarge"]

# %%
df = pd.DataFrame()

for indicator in indicators:
    for month in months:
        for year in years:
            newRow = {}
            newRow["month"] = month
            newRow["year"] = year
            newRow["indicator"] = indicator            
            df= df.append(newRow,ignore_index=True)

# %%
if TESTING:
    df = df[1:3]

# %%
df.shape
# Out:
# (552, 3)

# %%
function_time_start = datetime.datetime.now()
for index, row in df.iterrows():
    ic = ee.ImageCollection("{}/global_historical_{}_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V{:02.0f}".format(EE_PATH,row["indicator"],INPUT_VERSION))
    volume_image = filter_ic(ic,row["year"],row["month"])
    flux_image = volumeToFlux(volume_image)
    
    fc = zonalStatsToFeatureCollection(flux_image,zones_30spfaf06,geometry,1e10,"mode")
    fileNamePrefix = "global_historical_{}_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y{:04.0f}M{:02.0f}_V{:02.0f}".format(row["indicator"],row["year"],row["month"],OUTPUT_VERSION)
    description = fileNamePrefix[-98:] # description lenght limited to 100
    export_table_to_cloudstorage(fc,description,fileNamePrefix)
    print(index,description)
# Out:
# 0 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1969M01_V02
# 1 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1970M01_V02
# 2 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1971M01_V02
# 3 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1972M01_V02
# 4 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1973M01_V02
# 5 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1974M01_V02
# 6 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1975M01_V02
# 7 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1976M01_V02
# 8 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1977M01_V02
# 9 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1978M01_V02
# 10 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1979M01_V02
# 11 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1980M01_V02
# 12 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1981M01_V02
# 13 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1982M01_V02
# 14 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1983M01_V02
# 15 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1984M01_V02
# 16 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1985M01_V02
# 17 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1986M01_V02
# 18 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1987M01_V02
# 19 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1988M01_V02
# 20 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1989M01_V02
# 21 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1990M01_V02
# 22 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1991M01_V02
# 23 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1992M01_V02
# 24 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1993M01_V02
# 25 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1994M01_V02
# 26 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1995M01_V02
# 27 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1996M01_V02
# 28 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1997M01_V02
# 29 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1998M01_V02
# 30 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1999M01_V02
# 31 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2000M01_V02
# 32 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2001M01_V02
# 33 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2002M01_V02
# 34 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2003M01_V02
# 35 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2004M01_V02
# 36 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2005M01_V02
# 37 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2006M01_V02
# 38 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2007M01_V02
# 39 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2008M01_V02
# 40 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2009M01_V02
# 41 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2010M01_V02
# 42 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2011M01_V02
# 43 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2012M01_V02
# 44 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2013M01_V02
# 45 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2014M01_V02
# 46 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1969M02_V02
# 47 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1970M02_V02
# 48 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1971M02_V02
# 49 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1972M02_V02
# 50 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1973M02_V02
# 51 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1974M02_V02
# 52 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1975M02_V02
# 53 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1976M02_V02
# 54 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1977M02_V02
# 55 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1978M02_V02
# 56 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1979M02_V02
# 57 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1980M02_V02
# 58 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1981M02_V02
# 59 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1982M02_V02
# 60 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1983M02_V02
# 61 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1984M02_V02
# 62 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1985M02_V02
# 63 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1986M02_V02
# 64 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1987M02_V02
# 65 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1988M02_V02
# 66 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1989M02_V02
# 67 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1990M02_V02
# 68 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1991M02_V02
# 69 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1992M02_V02
# 70 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1993M02_V02
# 71 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1994M02_V02
# 72 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1995M02_V02
# 73 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1996M02_V02
# 74 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1997M02_V02
# 75 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1998M02_V02
# 76 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1999M02_V02
# 77 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2000M02_V02
# 78 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2001M02_V02
# 79 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2002M02_V02
# 80 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2003M02_V02
# 81 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2004M02_V02
# 82 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2005M02_V02
# 83 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2006M02_V02
# 84 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2007M02_V02
# 85 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2008M02_V02
# 86 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2009M02_V02
# 87 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2010M02_V02
# 88 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2011M02_V02
# 89 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2012M02_V02
# 90 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2013M02_V02
# 91 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2014M02_V02
# 92 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1969M03_V02
# 93 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1970M03_V02
# 94 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1971M03_V02
# 95 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1972M03_V02
# 96 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1973M03_V02
# 97 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1974M03_V02
# 98 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1975M03_V02
# 99 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1976M03_V02
# 100 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1977M03_V02
# 101 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1978M03_V02
# 102 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1979M03_V02
# 103 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1980M03_V02
# 104 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1981M03_V02
# 105 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1982M03_V02
# 106 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1983M03_V02
# 107 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1984M03_V02
# 108 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1985M03_V02
# 109 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1986M03_V02
# 110 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1987M03_V02
# 111 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1988M03_V02
# 112 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1989M03_V02
# 113 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1990M03_V02
# 114 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1991M03_V02
# 115 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1992M03_V02
# 116 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1993M03_V02
# 117 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1994M03_V02
# 118 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1995M03_V02
# 119 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1996M03_V02
# 120 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1997M03_V02
# 121 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1998M03_V02
# 122 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1999M03_V02
# 123 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2000M03_V02
# 124 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2001M03_V02
# 125 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2002M03_V02
# 126 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2003M03_V02
# 127 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2004M03_V02
# 128 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2005M03_V02
# 129 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2006M03_V02
# 130 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2007M03_V02
# 131 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2008M03_V02
# 132 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2009M03_V02
# 133 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2010M03_V02
# 134 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2011M03_V02
# 135 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2012M03_V02
# 136 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2013M03_V02
# 137 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2014M03_V02
# 138 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1969M04_V02
# 139 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1970M04_V02
# 140 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1971M04_V02
# 141 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1972M04_V02
# 142 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1973M04_V02
# 143 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1974M04_V02
# 144 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1975M04_V02
# 145 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1976M04_V02
# 146 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1977M04_V02
# 147 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1978M04_V02
# 148 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1979M04_V02
# 149 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1980M04_V02
# 150 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1981M04_V02
# 151 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1982M04_V02
# 152 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1983M04_V02
# 153 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1984M04_V02
# 154 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1985M04_V02
# 155 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1986M04_V02
# 156 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1987M04_V02
# 157 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1988M04_V02
# 158 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1989M04_V02
# 159 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1990M04_V02
# 160 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1991M04_V02
# 161 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1992M04_V02
# 162 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1993M04_V02
# 163 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1994M04_V02
# 164 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1995M04_V02
# 165 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1996M04_V02
# 166 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1997M04_V02
# 167 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1998M04_V02
# 168 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1999M04_V02
# 169 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2000M04_V02
# 170 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2001M04_V02
# 171 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2002M04_V02
# 172 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2003M04_V02
# 173 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2004M04_V02
# 174 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2005M04_V02
# 185 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1970M05_V02
# 186 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1971M05_V02
# 187 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1972M05_V02
# 188 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1973M05_V02
# 189 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1974M05_V02
# 190 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1975M05_V02
# 191 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1976M05_V02
# 192 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1977M05_V02
# 193 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1978M05_V02
# 194 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1979M05_V02
# 195 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1980M05_V02
# 196 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1981M05_V02
# 197 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1982M05_V02
# 198 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1983M05_V02
# 199 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1984M05_V02
# 200 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1985M05_V02
# 201 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1986M05_V02
# 202 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1987M05_V02
# 203 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1988M05_V02
# 204 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1989M05_V02
# 205 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1990M05_V02
# 206 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1991M05_V02
# 207 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1992M05_V02
# 208 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1993M05_V02
# 209 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1994M05_V02
# 210 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1995M05_V02
# 211 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1996M05_V02
# 212 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1997M05_V02
# 213 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1998M05_V02
# 214 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1999M05_V02
# 215 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2000M05_V02
# 216 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2001M05_V02
# 217 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2002M05_V02
# 218 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2003M05_V02
# 219 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2004M05_V02
# 220 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2005M05_V02
# 221 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2006M05_V02
# 222 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2007M05_V02
# 223 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2008M05_V02
# 224 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2009M05_V02
# 225 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2010M05_V02
# 226 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2011M05_V02
# 227 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2012M05_V02
# 228 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2013M05_V02
# 229 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2014M05_V02
# 230 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1969M06_V02
# 231 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1970M06_V02
# 232 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1971M06_V02
# 233 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1972M06_V02
# 234 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1973M06_V02
# 235 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1974M06_V02
# 236 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1975M06_V02
# 237 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1976M06_V02
# 238 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1977M06_V02
# 239 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1978M06_V02
# 240 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1979M06_V02
# 241 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1980M06_V02
# 242 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1981M06_V02
# 243 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1982M06_V02
# 244 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1983M06_V02
# 245 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1984M06_V02
# 246 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1985M06_V02
# 247 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1986M06_V02
# 248 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1987M06_V02
# 249 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1988M06_V02
# 250 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1989M06_V02
# 251 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1990M06_V02
# 252 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1991M06_V02
# 253 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1992M06_V02
# 254 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1993M06_V02
# 255 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1994M06_V02
# 256 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1995M06_V02
# 257 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1996M06_V02
# 258 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1997M06_V02
# 259 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1998M06_V02
# 260 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1999M06_V02
# 261 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2000M06_V02
# 262 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2001M06_V02
# 263 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2002M06_V02
# 264 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2003M06_V02
# 265 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2004M06_V02
# 266 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2005M06_V02
# 267 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2006M06_V02
# 268 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2007M06_V02
# 269 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2008M06_V02
# 287 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1980M07_V02
# 288 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1981M07_V02
# 289 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1982M07_V02
# 290 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1983M07_V02
# 299 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1992M07_V02
# 300 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1993M07_V02
# 301 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1994M07_V02
# 302 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1995M07_V02
# 303 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1996M07_V02
# 304 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1997M07_V02
# 305 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1998M07_V02
# 306 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1999M07_V02
# 307 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2000M07_V02
# 308 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2001M07_V02
# 309 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2002M07_V02
# 310 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2003M07_V02
# 311 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2004M07_V02
# 312 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2005M07_V02
# 313 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2006M07_V02
# 314 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2007M07_V02
# 315 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2008M07_V02
# 316 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2009M07_V02
# 317 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2010M07_V02
# 318 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2011M07_V02
# 319 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2012M07_V02
# 320 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2013M07_V02
# 321 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2014M07_V02
# 322 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1969M08_V02
# 323 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1970M08_V02
# 324 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1971M08_V02
# 325 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1972M08_V02
# 326 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1973M08_V02
# 327 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1974M08_V02
# 328 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1975M08_V02
# 329 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1976M08_V02
# 330 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1977M08_V02
# 331 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1978M08_V02
# 332 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1979M08_V02
# 333 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1980M08_V02
# 334 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1981M08_V02
# 335 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1982M08_V02
# 336 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1983M08_V02
# 337 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1984M08_V02
# 338 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1985M08_V02
# 339 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1986M08_V02
# 340 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1987M08_V02
# 341 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1988M08_V02
# 342 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1989M08_V02
# 343 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1990M08_V02
# 344 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1991M08_V02
# 345 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1992M08_V02
# 346 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1993M08_V02
# 347 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1994M08_V02
# 348 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1995M08_V02
# 349 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1996M08_V02
# 350 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1997M08_V02
# 351 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1998M08_V02
# 352 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1999M08_V02
# 353 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2000M08_V02
# 354 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2001M08_V02
# 355 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2002M08_V02
# 356 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2003M08_V02
# 357 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2004M08_V02
# 358 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2005M08_V02
# 359 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2006M08_V02
# 360 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2007M08_V02
# 361 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2008M08_V02
# 362 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2009M08_V02
# 363 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2010M08_V02
# 364 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2011M08_V02
# 365 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2012M08_V02
# 366 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2013M08_V02
# 367 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2014M08_V02
# 368 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1969M09_V02
# 369 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1970M09_V02
# 370 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1971M09_V02
# 371 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1972M09_V02
# 372 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1973M09_V02
# 373 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1974M09_V02
# 374 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1975M09_V02
# 375 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1976M09_V02
# 376 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1977M09_V02
# 377 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1978M09_V02
# 378 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1979M09_V02
# 379 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1980M09_V02
# 380 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1981M09_V02
# 381 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1982M09_V02
# 382 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1983M09_V02
# 383 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1984M09_V02
# 412 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2013M09_V02
# 413 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2014M09_V02
# 426 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1981M10_V02
# 427 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1982M10_V02
# 428 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1983M10_V02
# 429 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1984M10_V02
# 430 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1985M10_V02
# 431 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1986M10_V02
# 432 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1987M10_V02
# 433 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1988M10_V02
# 434 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1989M10_V02
# 435 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1990M10_V02
# 436 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1991M10_V02
# 437 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1992M10_V02
# 438 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1993M10_V02
# 439 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1994M10_V02
# 440 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1995M10_V02
# 441 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1996M10_V02
# 442 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1997M10_V02
# 443 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1998M10_V02
# 444 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1999M10_V02
# 445 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2000M10_V02
# 446 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2001M10_V02
# 447 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2002M10_V02
# 448 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2003M10_V02
# 449 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2004M10_V02
# 450 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2005M10_V02
# 451 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2006M10_V02
# 452 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2007M10_V02
# 453 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2008M10_V02
# 454 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2009M10_V02
# 455 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2010M10_V02
# 456 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2011M10_V02
# 457 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2012M10_V02
# 458 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2013M10_V02
# 459 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2014M10_V02
# 460 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1969M11_V02
# 461 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1970M11_V02
# 462 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1971M11_V02
# 463 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1972M11_V02
# 464 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1973M11_V02
# 465 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1974M11_V02
# 466 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1975M11_V02
# 467 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1976M11_V02
# 468 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1977M11_V02
# 469 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1978M11_V02
# 470 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1979M11_V02
# 471 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1980M11_V02
# 472 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1981M11_V02
# 473 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1982M11_V02
# 474 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1983M11_V02
# 475 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1984M11_V02
# 476 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1985M11_V02
# 477 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1986M11_V02
# 478 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1987M11_V02
# 479 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1988M11_V02
# 480 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1989M11_V02
# 481 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1990M11_V02
# 482 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1991M11_V02
# 483 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1992M11_V02
# 484 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1993M11_V02
# 485 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1994M11_V02
# 486 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1995M11_V02
# 487 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1996M11_V02
# 488 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1997M11_V02
# 489 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1998M11_V02
# 490 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1999M11_V02
# 491 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2000M11_V02
# 492 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2001M11_V02
# 493 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2002M11_V02
# 494 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2003M11_V02
# 495 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2004M11_V02
# 496 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2005M11_V02
# 497 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2006M11_V02
# 498 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2007M11_V02
# 499 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2008M11_V02
# 500 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2009M11_V02
# 501 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2010M11_V02
# 502 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2011M11_V02
# 503 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2012M11_V02
# 504 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2013M11_V02
# 505 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2014M11_V02
# 506 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1969M12_V02
# 507 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1970M12_V02
# 508 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1971M12_V02
# 509 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1972M12_V02
# 510 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1973M12_V02
# 511 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1974M12_V02
# 512 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1975M12_V02
# 513 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1976M12_V02
# 514 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1977M12_V02
# 515 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1978M12_V02
# 516 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1979M12_V02
# 517 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1980M12_V02
# 518 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1981M12_V02
# 519 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1982M12_V02
# 520 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1983M12_V02
# 521 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1984M12_V02
# 522 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1985M12_V02
# 523 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1986M12_V02
# 524 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1987M12_V02
# 525 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1988M12_V02
# 526 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1989M12_V02
# 527 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1990M12_V02
# 528 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1991M12_V02
# 529 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1992M12_V02
# 530 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1993M12_V02
# 531 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1994M12_V02
# 532 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1995M12_V02
# 533 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1996M12_V02
# 534 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1997M12_V02
# 535 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1998M12_V02
# 536 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y1999M12_V02
# 537 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2000M12_V02
# 538 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2001M12_V02
# 539 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2002M12_V02
# 540 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2003M12_V02
# 541 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2004M12_V02
# 542 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2005M12_V02
# 543 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2006M12_V02
# 544 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2007M12_V02
# 545 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2008M12_V02
# 546 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2009M12_V02
# 547 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2010M12_V02
# 548 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2011M12_V02
# 549 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2012M12_V02
# 550 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2013M12_V02
# 551 historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_mode_Y2014M12_V02

# %%
end = datetime.datetime.now()
elapsed = end - start
print(elapsed)
# Out:
# 0:20:03.952281
