# %% [markdown]
# # Y2018M02D27_RH_Moving_Average_Discharge_EE_V01
#
# * Purpose of script: Moving average for discharge at basin resolution. The script will calculate the volumetric and flux 10 year moving average at a Pfaf6 basin level for total demand. (potentially also per sector demand)
#
# * Script exports to:
# * Update this projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_PTotWW_month_m_pfaf06_1960_2014_movingaverage_10y_V01
# * Update this projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_PTotWN_month_m_pfaf06_1960_2014_movingaverage_10y_V01
# * Kernel used: python35
# * Date created: 20170301
#
# The imageCollection global_historical_availableriverdischarge_month_millionm3_5minPfaf6_1960_2014 (output of script: Y2017M12D07_RH_ZonalStats_MaxQ_toImage_EE_V01) contains three bands:
#
# 1. zones_mode_pfaf6
# 1. sum. sum is the sum of the discharge in millionm3 at the q_search_mask (output of Y2017M12D06_RH_Conservative_Basin_Sinks_EE_V01). q_search_mask is FAmax-1 expect when endorheic or sinks
# 1. max. global maximum of Q within basin.
#
#
#
# Methodology to apply.
#
#
# if qmax < 1.25 qsum:
#     q = qmax
# else:
#     q = qsum
#
# Can be optimized. Options include: Use flow accumulation instead of discharge
# Use multiple level FAmax FAmax-1 FAmax-2 etc.
#
#
# Known issues:
# When the most downstream pixel is a lake, the blue water available of the lake is available to the entire sub-basin. For example pfaf_id 434210
#
# Sub-basins which have only one discharge cell of the main river: e.g. 142739 (Famale, Niger)

# %%
import time, datetime, sys
dateString = time.strftime("Y%YM%mD%d")
timeString = time.strftime("UTC %H:%M")
start = datetime.datetime.now()
print(dateString,timeString)
sys.version
# Out:
# Y2018M03D07 UTC 09:55
# '3.5.4 |Continuum Analytics, Inc.| (default, Aug 14 2017, 13:26:58) \n[GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]'

# %%
SCRIPT_NAME = "Y2018M02D27_RH_Moving_Average_Discharge_EE_V01"

CRS = "EPSG:4326"

EE_PATH = "projects/WRI-Aquaduct/PCRGlobWB20V07"

OUTPUT_VERSION = 2

DIMENSION5MIN = {}
DIMENSION5MIN["x"] = 4320
DIMENSION5MIN["y"] = 2160


MA_WINDOW_LENGTH = 10 # Moving average window length. 

TESTING = 0

THRESHOLD = 1.25

PFAF_LEVEL = 6

DIMENSIONS30SSMALL = "43200x19440"
CRS_TRANSFORM30S_SMALL = [0.008333333333333333, 0.0, -180.0, 0.0, -0.008333333333333333, 81.0]

# %%
import ee
import os
import logging
import pandas as pd
import subprocess

# %%
ee.Initialize()

# %%
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s:%(levelname)s:%(message)s')
file_handler = logging.FileHandler("./logs/%sV%0.2d.log" %(SCRIPT_NAME,OUTPUT_VERSION))
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# %%
geometry = ee.Geometry.Polygon(coords=[[-180.0, -90.0], [180,  -90.0], [180, 90], [-180,90]], proj= ee.Projection('EPSG:4326'),geodesic=False )

# %%
geometrySmall = ee.Geometry.Polygon(coords=[[-180.0, -81.0], [180,  -81.0], [180, 81], [-180,81]], proj= ee.Projection('EPSG:4326'),geodesic=False )

# %%
area30s = ee.Image("projects/WRI-Aquaduct/PCRGlobWB20V07/area_30s_m2V11")
zones30s = ee.Image("projects/WRI-Aquaduct/PCRGlobWB20V07/hybas_lev00_v1c_merged_fiona_30s_V01")
zones30s = zones30s.divide(ee.Number(10).pow(ee.Number(12).subtract(PFAF_LEVEL))).floor().toInt64();

crs30s = area30s.projection()

area30s_pfaf06 = ee.Image("projects/WRI-Aquaduct/PCRGlobWB20V07/area_30spfaf06_m2_V01V01").select(["sum"])

scale30s = zones30s.projection().nominalScale().getInfo()

# %%
"""
crsTransform5min = [
                0.0833333309780367,
                0,
                -179.99999491255934,
                0,
                -0.0833333309780367,
                90.00000254430942
              ]
"""
# Out:
# '\ncrsTransform5min = [\n                0.0833333309780367,\n                0,\n                -179.99999491255934,\n                0,\n                -0.0833333309780367,\n                90.00000254430942\n              ]\n'

# %%
def prepare_discharge_collection(image):
    """ find the available discharge based on max and sum bands of available discharge
    
    if qmax =< threshold (1.25) qsum:
        q = qmax
    else:
        q = qsum
    
    Args:
        i_in (ee.Image) :image of available discharge with three bands: zones, max and sum
    
    Returns:
        i_q_out (ee.Image) : image with only one band 'b1'
    
    
    """


    i_q_max = image.select(["max"])  
    i_q_sum = image.select(["sum"])
    
    i_ratio_q = i_q_max.divide(i_q_sum)
       
    use_max = i_ratio_q.lte(THRESHOLD)
    use_sum = i_ratio_q.gt(THRESHOLD)
    
    i_q_out = use_max.multiply(i_q_max).add((use_sum.multiply(i_q_sum)))
    i_q_out = i_q_out.select(["max"],["b1"]) 
    i_q_out = i_q_out.copyProperties(image)                                                                              
                                                             
    return i_q_out



def create_collection(assetid):
    """ Create image collection in earth engine asset folder
    
    This function will only work if the folder in which the
    new imageCollection will be created is valid
    
    
    Args:
        assetid (string) : asset id for the new image collection
    
    Returns: 
        result (string) : captured message from command line
    
    """   
    
    command = "earthengine create collection {}".format(assetid) 
    result = subprocess.check_output(command,shell=True)
    if result:
        logger.error(result)
    return result 


def moving_average_decade(year,ic):
    """ Calculate a 10 year moving average
    
    This function is limited to one input paramater to allow mapping over a simple list. 
    Averages the 10 year up to the input year. (]
    
    Global variables required include an imageCollection with a year property.
    
    
    Args:
        year (integer) : final year of interest.
        ic (ee.ImageCollection) : input imageCollection
    
    Returns: 
        image (ee.Image) : earth engine image with the mean of the last 10 years
    """
    
    min_year = year - MA_WINDOW_LENGTH
    
    ic_filtered = (ic.filter(ee.Filter.gt("year",min_year))
                     .filter(ee.Filter.lte("year",year)))
                  
    i_mean = ic_filtered.reduce(ee.Reducer.mean()) 
    
    
    i_mean = i_mean.copyProperties(source=ic_filtered.first(),
                          exclude=["script_used",
                                   "output_version",
                                   "year",
                                   "output_version",
                                   "version",
                                   "reducer",
                                   "description"])
    
    return ee.Image(i_mean)


def mapList(results, key):
    newResult = results.map(lambda x: ee.Dictionary(x).get(key))
    return newResult

def ensure_default_properties(obj): 
    obj = ee.Dictionary(obj)
    default_properties = ee.Dictionary({"mean": -9999,"count": -9999})
    return default_properties.combine(obj)


def zonal_stats_to_raster(image,zonesImage,geometry,maxPixels,reducerType,scale):
    """ Zonal statistics using rasterized zones
    
    Args:
        image (ee.Image) : input image with values (Check the units)
        zonesImage (ee.Image) : integer image with the zones
        geometry (ee.Geometry) : geometry indicating the extent of the calculation. Note if geometry is geodesic
        maxPixels (integer) : maximum numbers of pixels within geometry
        reducerType (string) : options include 'mean', 'max', 'sum', 'first' en 'mode' 
    
    
    
    # reducertype can be mean, max, sum, first. Count is always included for QA
    # the resolution of the zonesimage is used for scale
    """
    
    reducer = ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"mean"),ee.Reducer.mean(),
    ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"max"),ee.Reducer.max(),
    ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"sum"),ee.Reducer.sum(),
    ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"first"),ee.Reducer.first(),
    ee.Algorithms.If(ee.Algorithms.IsEqual(reducerType,"mode"),ee.Reducer.mode(),"error"))))
    )
    reducer = ee.Reducer(reducer).combine(reducer2= ee.Reducer.count(), sharedInputs= True).group(groupField=1, groupName="zones") 

    
    zonesImage = zonesImage.select(zonesImage.bandNames(),["zones"])

    totalImage = ee.Image(image).addBands(zonesImage)
    resultsList = ee.List(totalImage.reduceRegion(
        geometry= geometry, 
        reducer= reducer,
        scale= scale,
        maxPixels=maxPixels,
        bestEffort =True
        ).get("groups"))

    resultsList = resultsList.map(ensure_default_properties); 
    zoneList = mapList(resultsList, 'zones');
    countList = mapList(resultsList, 'count');
    valueList = mapList(resultsList, reducerType);

    valueImage = zonesImage.remap(zoneList, valueList).select(["remapped"],[reducerType])
    countImage = zonesImage.remap(zoneList, countList).select(["remapped"],["count"])
    newImage = zonesImage.addBands(countImage).addBands(valueImage)
    return newImage


def set_properties(image):
    """ Set properties to image based on rows in pandas dataframe
    
    Args:
        image (ee.Image) : image without properties
        
    Returns:
        image_out (ee.Image) : image with properties
    """
    
    properties ={}
    properties["year"] = row["year"]
    properties["month"] = row["month"]
    properties["units"] = "millionm3"
    properties["moving_average_length"] = MA_WINDOW_LENGTH
    properties["moving_average_year_min"] = row["year"]- (MA_WINDOW_LENGTH-1)
    properties["script_used"] = SCRIPT_NAME
    properties["indicator"] = row["indicator"]
    properties["version"] = OUTPUT_VERSION
    properties["spatial_resolution"] = "30s"
    properties["exportdescription"] = row["exportdescription"]
    
    image_out = ee.Image(image).set(properties)
    return image_out


def export_asset(image):
    """ Export a google earth engine image to an asset folder
    
    function will start a new task. To view the status of the task
    check the javascript API or query tasks script. Function is used 
    as mapped function so other arguments need to be set globally. 
    
    Args:
        image (ee.Image) : Image to export
        
    Returns:
        asset_id (string) : asset id of     
    """
    
    asset_id = row["output_i_assetid"]
    task = ee.batch.Export.image.toAsset(
        image =  ee.Image(image),
        description = "{}V{}".format(row["exportdescription"],OUTPUT_VERSION),
        assetId = asset_id,
        dimensions = DIMENSIONS30SSMALL,
        crs = CRS,
        crsTransform = CRS_TRANSFORM30S_SMALL,
        maxPixels = 1e10     
    )
    task.start()
    return asset_id

# %%
area30sPfaf6 = zonal_stats_to_raster(area30s,zones30s,geometrySmall,1e10,"sum",scale30s)

# %%
area30sPfaf6_m2 = area30sPfaf6.select(["sum"]) # image at 30s with area in m^2 per basin

# %%
months = range(1,13)
years = range(1960+9,2014+1)
indicators = ["availabledischarge"]

# %%
df = pd.DataFrame()
for indicator in indicators:
    for month in months:
        for year in years:
            newRow = {}
            newRow["month"] = month
            newRow["year"] = year
            newRow["output_ic_filename"] = "global_historical_{}_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V{:02.0f}".format(indicator,OUTPUT_VERSION)
            newRow["output_ic_assetid"] = "{}/{}".format(EE_PATH,newRow["output_ic_filename"])
            newRow["output_i_filename"] = "global_historical_{}_month_millionm3_pfaf06_Y{:04.0f}M{:02.0f}_movingaverage_10y_V{:02.0f}".format(indicator,year,month,OUTPUT_VERSION)
            newRow["output_i_assetid"] = "{}/{}".format(newRow["output_ic_assetid"],newRow["output_i_filename"])
            newRow["indicator"] = indicator
            newRow["exportdescription"] = "{}_month_Y{:04.0f}M{:02.0f}_movingaverage_10y".format(indicator,year,month)
            df= df.append(newRow,ignore_index=True)

# %%
df.head()
# Out:
#                                    exportdescription           indicator  \
# 0  availabledischarge_month_Y1969M01_movingaverag...  availabledischarge
# 1  availabledischarge_month_Y1970M01_movingaverag...  availabledischarge
# 2  availabledischarge_month_Y1971M01_movingaverag...  availabledischarge
# 3  availabledischarge_month_Y1972M01_movingaverag...  availabledischarge
# 4  availabledischarge_month_Y1973M01_movingaverag...  availabledischarge
#
#    month                                   output_i_assetid  \
# 0    1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/global_hi...
# 1    1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/global_hi...
# 2    1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/global_hi...
# 3    1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/global_hi...
# 4    1.0  projects/WRI-Aquaduct/PCRGlobWB20V07/global_hi...
#
#                                    output_i_filename  \
# 0  global_historical_availabledischarge_month_mil...
# 1  global_historical_availabledischarge_month_mil...
# 2  global_historical_availabledischarge_month_mil...
# 3  global_historical_availabledischarge_month_mil...
# 4  global_historical_availabledischarge_month_mil...
#
#                                    output_ic_assetid  \
# 0  projects/WRI-Aquaduct/PCRGlobWB20V07/global_hi...
# 1  projects/WRI-Aquaduct/PCRGlobWB20V07/global_hi...
# 2  projects/WRI-Aquaduct/PCRGlobWB20V07/global_hi...
# 3  projects/WRI-Aquaduct/PCRGlobWB20V07/global_hi...
# 4  projects/WRI-Aquaduct/PCRGlobWB20V07/global_hi...
#
#                                   output_ic_filename    year
# 0  global_historical_availabledischarge_month_mil...  1969.0
# 1  global_historical_availabledischarge_month_mil...  1970.0
# 2  global_historical_availabledischarge_month_mil...  1971.0
# 3  global_historical_availabledischarge_month_mil...  1972.0
# 4  global_historical_availabledischarge_month_mil...  1973.0

# %%
if TESTING:
    df = df[0:1]

# %%
df.shape
# Out:
# (552, 8)

# %%
for output_ic_assetid in df["output_ic_assetid"].unique():
    result = create_collection(output_ic_assetid)
    print(result)
# Out:
# b'Asset projects/WRI-Aquaduct/PCRGlobWB20V07/global_historical_availabledischarge_month_millionm3_pfaf06_1960_2014_movingaverage_10y_V02 already exists\n'

# %%
function_time_start = datetime.datetime.now()
for index, row in df.iterrows():    
    ic = ee.ImageCollection("{}/global_historical_availableriverdischarge_month_millionm3_5minPfaf6_1960_2014".format(EE_PATH))
    ic_month = ic.filter(ee.Filter.eq("month",row["month"]))
      
    ic_month_simplified = ic_month.map(prepare_discharge_collection)
    i_mean = moving_average_decade(row["year"],ic_month_simplified)
    
    # The result of this operation is at 5arc min. The withdrawal and demand data is at 30s though. Resampling to 30s using the "mode" aka majority
    i_mean_30s = zonal_stats_to_raster(i_mean,zones30s,geometrySmall,1e10,"mode",scale30s).select(["mode"])
    i_mean_30s = i_mean_30s.copyProperties(
        source = i_mean,
        exclude= ["resolution","spatial_resolution"])
    i_mean_30s = set_properties(i_mean_30s)
        
    asset_id = export_asset(i_mean_30s)
    logger.info(asset_id)
    elapsed = datetime.datetime.now() - function_time_start
    print("Processing image {} month {} of year {} runtime {}".format(index,row["month"],row["year"],elapsed))
# Out:
# Processing image 0 month 1.0 of year 1969.0 runtime 0:00:01.760351
# Processing image 1 month 1.0 of year 1970.0 runtime 0:00:03.486720
# Processing image 2 month 1.0 of year 1971.0 runtime 0:00:05.219571
# Processing image 3 month 1.0 of year 1972.0 runtime 0:00:06.911853
# Processing image 4 month 1.0 of year 1973.0 runtime 0:00:08.644994
# Processing image 5 month 1.0 of year 1974.0 runtime 0:00:10.373721
# Processing image 6 month 1.0 of year 1975.0 runtime 0:00:12.416981
# Processing image 7 month 1.0 of year 1976.0 runtime 0:00:14.140064
# Processing image 8 month 1.0 of year 1977.0 runtime 0:00:15.842484
# Processing image 9 month 1.0 of year 1978.0 runtime 0:00:17.561791
# Processing image 10 month 1.0 of year 1979.0 runtime 0:00:19.277790
# Processing image 11 month 1.0 of year 1980.0 runtime 0:00:20.965147
# Processing image 12 month 1.0 of year 1981.0 runtime 0:00:22.717680
# Processing image 13 month 1.0 of year 1982.0 runtime 0:00:24.432604
# Processing image 14 month 1.0 of year 1983.0 runtime 0:00:26.157620
# Processing image 15 month 1.0 of year 1984.0 runtime 0:00:27.954696
# Processing image 16 month 1.0 of year 1985.0 runtime 0:00:29.719480
# Processing image 17 month 1.0 of year 1986.0 runtime 0:00:31.498647
# Processing image 18 month 1.0 of year 1987.0 runtime 0:00:32.729081
# Processing image 19 month 1.0 of year 1988.0 runtime 0:00:34.482023
# Processing image 20 month 1.0 of year 1989.0 runtime 0:00:36.187195
# Processing image 21 month 1.0 of year 1990.0 runtime 0:00:37.909997
# Processing image 22 month 1.0 of year 1991.0 runtime 0:00:39.725946
# Processing image 23 month 1.0 of year 1992.0 runtime 0:00:41.411039
# Processing image 24 month 1.0 of year 1993.0 runtime 0:00:43.204259
# Processing image 25 month 1.0 of year 1994.0 runtime 0:00:44.948872
# Processing image 26 month 1.0 of year 1995.0 runtime 0:00:46.701176
# Processing image 27 month 1.0 of year 1996.0 runtime 0:00:48.396332
# Processing image 28 month 1.0 of year 1997.0 runtime 0:00:50.150842
# Processing image 29 month 1.0 of year 1998.0 runtime 0:00:51.872815
# Processing image 30 month 1.0 of year 1999.0 runtime 0:00:53.630751
# Processing image 31 month 1.0 of year 2000.0 runtime 0:00:55.419818
# Processing image 32 month 1.0 of year 2001.0 runtime 0:00:57.145800
# Processing image 33 month 1.0 of year 2002.0 runtime 0:00:58.964940
# Processing image 34 month 1.0 of year 2003.0 runtime 0:01:00.642062
# Processing image 35 month 1.0 of year 2004.0 runtime 0:01:02.395636
# Processing image 36 month 1.0 of year 2005.0 runtime 0:01:04.141268
# Processing image 37 month 1.0 of year 2006.0 runtime 0:01:05.847367
# Processing image 38 month 1.0 of year 2007.0 runtime 0:01:07.576357
# Processing image 39 month 1.0 of year 2008.0 runtime 0:01:09.321724
# Processing image 40 month 1.0 of year 2009.0 runtime 0:01:11.039937
# Processing image 41 month 1.0 of year 2010.0 runtime 0:01:12.786081
# Processing image 42 month 1.0 of year 2011.0 runtime 0:01:14.481165
# Processing image 43 month 1.0 of year 2012.0 runtime 0:01:16.215075
# Processing image 44 month 1.0 of year 2013.0 runtime 0:01:18.097006
# Processing image 45 month 1.0 of year 2014.0 runtime 0:01:19.890670
# Processing image 46 month 2.0 of year 1969.0 runtime 0:01:21.584009
# Processing image 47 month 2.0 of year 1970.0 runtime 0:01:23.334154
# Processing image 48 month 2.0 of year 1971.0 runtime 0:01:25.058818
# Processing image 49 month 2.0 of year 1972.0 runtime 0:01:26.764099
# Processing image 50 month 2.0 of year 1973.0 runtime 0:01:28.533914
# Processing image 51 month 2.0 of year 1974.0 runtime 0:01:30.459145
# Processing image 52 month 2.0 of year 1975.0 runtime 0:01:32.222101
# Processing image 53 month 2.0 of year 1976.0 runtime 0:01:33.958710
# Processing image 54 month 2.0 of year 1977.0 runtime 0:01:35.673407
# Processing image 55 month 2.0 of year 1978.0 runtime 0:01:37.441069
# Processing image 56 month 2.0 of year 1979.0 runtime 0:01:39.163806
# Processing image 57 month 2.0 of year 1980.0 runtime 0:01:40.869718
# Processing image 58 month 2.0 of year 1981.0 runtime 0:01:42.635899
# Processing image 59 month 2.0 of year 1982.0 runtime 0:01:44.372459
# Processing image 60 month 2.0 of year 1983.0 runtime 0:01:46.077621
# Processing image 61 month 2.0 of year 1984.0 runtime 0:01:47.776071
# Processing image 62 month 2.0 of year 1985.0 runtime 0:01:49.496979
# Processing image 63 month 2.0 of year 1986.0 runtime 0:01:51.191242
# Processing image 64 month 2.0 of year 1987.0 runtime 0:01:52.909002
# Processing image 65 month 2.0 of year 1988.0 runtime 0:01:54.610774
# Processing image 66 month 2.0 of year 1989.0 runtime 0:01:56.323552
# Processing image 67 month 2.0 of year 1990.0 runtime 0:01:58.055967
# Processing image 68 month 2.0 of year 1991.0 runtime 0:01:59.835324
# Processing image 69 month 2.0 of year 1992.0 runtime 0:02:01.634788
# Processing image 70 month 2.0 of year 1993.0 runtime 0:02:03.487309
# Processing image 71 month 2.0 of year 1994.0 runtime 0:02:05.356757
# Processing image 72 month 2.0 of year 1995.0 runtime 0:02:07.204361
# Processing image 73 month 2.0 of year 1996.0 runtime 0:02:09.148250
# Processing image 74 month 2.0 of year 1997.0 runtime 0:02:11.043463
# Processing image 75 month 2.0 of year 1998.0 runtime 0:02:13.139802
# Processing image 76 month 2.0 of year 1999.0 runtime 0:02:14.963244
# Processing image 77 month 2.0 of year 2000.0 runtime 0:02:16.900070
# Processing image 78 month 2.0 of year 2001.0 runtime 0:02:18.744184
# Processing image 79 month 2.0 of year 2002.0 runtime 0:02:20.678102
# Processing image 80 month 2.0 of year 2003.0 runtime 0:02:22.533509
# Processing image 81 month 2.0 of year 2004.0 runtime 0:02:24.369359
# Processing image 82 month 2.0 of year 2005.0 runtime 0:02:25.757252
# Processing image 83 month 2.0 of year 2006.0 runtime 0:02:27.640384
# Processing image 84 month 2.0 of year 2007.0 runtime 0:02:29.823628
# Processing image 85 month 2.0 of year 2008.0 runtime 0:02:31.798529
# Processing image 86 month 2.0 of year 2009.0 runtime 0:02:33.162148
# Processing image 87 month 2.0 of year 2010.0 runtime 0:02:35.006179
# Processing image 88 month 2.0 of year 2011.0 runtime 0:02:36.904086
# Processing image 89 month 2.0 of year 2012.0 runtime 0:02:38.771226
# Processing image 90 month 2.0 of year 2013.0 runtime 0:02:40.597645
# Processing image 91 month 2.0 of year 2014.0 runtime 0:02:42.458979
# Processing image 92 month 3.0 of year 1969.0 runtime 0:02:44.276522
# Processing image 93 month 3.0 of year 1970.0 runtime 0:02:46.168441
# Processing image 94 month 3.0 of year 1971.0 runtime 0:02:48.034705
# Processing image 95 month 3.0 of year 1972.0 runtime 0:02:49.864337
# Processing image 96 month 3.0 of year 1973.0 runtime 0:02:51.755363
# Processing image 97 month 3.0 of year 1974.0 runtime 0:02:53.639997
# Processing image 98 month 3.0 of year 1975.0 runtime 0:02:55.452029
# Processing image 99 month 3.0 of year 1976.0 runtime 0:02:57.287165
# Processing image 100 month 3.0 of year 1977.0 runtime 0:02:59.129950
# Processing image 101 month 3.0 of year 1978.0 runtime 0:03:00.542503
# Processing image 102 month 3.0 of year 1979.0 runtime 0:03:01.946254
# Processing image 103 month 3.0 of year 1980.0 runtime 0:03:03.795393
# Processing image 104 month 3.0 of year 1981.0 runtime 0:03:05.190252
# Processing image 105 month 3.0 of year 1982.0 runtime 0:03:07.015765
# Processing image 106 month 3.0 of year 1983.0 runtime 0:03:08.818557
# Processing image 107 month 3.0 of year 1984.0 runtime 0:03:10.666965
# Processing image 108 month 3.0 of year 1985.0 runtime 0:03:13.102070
# Processing image 109 month 3.0 of year 1986.0 runtime 0:03:14.963658
# Processing image 110 month 3.0 of year 1987.0 runtime 0:03:16.903633
# Processing image 111 month 3.0 of year 1988.0 runtime 0:03:18.767017
# Processing image 112 month 3.0 of year 1989.0 runtime 0:03:20.659403
# Processing image 113 month 3.0 of year 1990.0 runtime 0:03:22.522984
# Processing image 114 month 3.0 of year 1991.0 runtime 0:03:24.340720
# Processing image 115 month 3.0 of year 1992.0 runtime 0:03:26.203578
# Processing image 116 month 3.0 of year 1993.0 runtime 0:03:27.978150
# Processing image 117 month 3.0 of year 1994.0 runtime 0:03:29.813798
# Processing image 118 month 3.0 of year 1995.0 runtime 0:03:31.657123
# Processing image 119 month 3.0 of year 1996.0 runtime 0:03:33.447525
# Processing image 120 month 3.0 of year 1997.0 runtime 0:03:35.300870
# Processing image 121 month 3.0 of year 1998.0 runtime 0:03:37.147873
# Processing image 122 month 3.0 of year 1999.0 runtime 0:03:39.009680
# Processing image 123 month 3.0 of year 2000.0 runtime 0:03:40.826720
# Processing image 124 month 3.0 of year 2001.0 runtime 0:03:42.655753
# Processing image 125 month 3.0 of year 2002.0 runtime 0:03:44.534014
# Processing image 126 month 3.0 of year 2003.0 runtime 0:03:46.377424
# Processing image 127 month 3.0 of year 2004.0 runtime 0:03:48.284065
# Processing image 128 month 3.0 of year 2005.0 runtime 0:03:50.126513
# Processing image 129 month 3.0 of year 2006.0 runtime 0:03:51.994505
# Processing image 130 month 3.0 of year 2007.0 runtime 0:03:53.814533
# Processing image 131 month 3.0 of year 2008.0 runtime 0:03:55.685232
# Processing image 132 month 3.0 of year 2009.0 runtime 0:03:57.485551
# Processing image 133 month 3.0 of year 2010.0 runtime 0:03:59.353678
# Processing image 134 month 3.0 of year 2011.0 runtime 0:04:01.238661
# Processing image 135 month 3.0 of year 2012.0 runtime 0:04:03.054894
# Processing image 136 month 3.0 of year 2013.0 runtime 0:04:04.790534
# Processing image 137 month 3.0 of year 2014.0 runtime 0:04:06.573771
# Processing image 138 month 4.0 of year 1969.0 runtime 0:04:08.296076
# Processing image 139 month 4.0 of year 1970.0 runtime 0:04:10.030051
# Processing image 140 month 4.0 of year 1971.0 runtime 0:04:11.759994
# Processing image 141 month 4.0 of year 1972.0 runtime 0:04:13.545857
# Processing image 142 month 4.0 of year 1973.0 runtime 0:04:15.250136
# Processing image 143 month 4.0 of year 1974.0 runtime 0:04:16.533481
# Processing image 144 month 4.0 of year 1975.0 runtime 0:04:18.263669
# Processing image 145 month 4.0 of year 1976.0 runtime 0:04:19.973716
# Processing image 146 month 4.0 of year 1977.0 runtime 0:04:21.734814
# Processing image 147 month 4.0 of year 1978.0 runtime 0:04:23.459392
# Processing image 148 month 4.0 of year 1979.0 runtime 0:04:25.204360
# Processing image 149 month 4.0 of year 1980.0 runtime 0:04:26.458692
# Processing image 150 month 4.0 of year 1981.0 runtime 0:04:28.208027
# Processing image 151 month 4.0 of year 1982.0 runtime 0:04:29.948089
# Processing image 152 month 4.0 of year 1983.0 runtime 0:04:31.698542
# Processing image 153 month 4.0 of year 1984.0 runtime 0:04:33.414953
# Processing image 154 month 4.0 of year 1985.0 runtime 0:04:35.155762
# Processing image 155 month 4.0 of year 1986.0 runtime 0:04:36.924579
# Processing image 156 month 4.0 of year 1987.0 runtime 0:04:38.761151
# Processing image 157 month 4.0 of year 1988.0 runtime 0:04:40.480694
# Processing image 158 month 4.0 of year 1989.0 runtime 0:04:42.168184
# Processing image 159 month 4.0 of year 1990.0 runtime 0:04:43.928453
# Processing image 160 month 4.0 of year 1991.0 runtime 0:04:45.672238
# Processing image 161 month 4.0 of year 1992.0 runtime 0:04:47.373886
# Processing image 162 month 4.0 of year 1993.0 runtime 0:04:49.122565
# Processing image 163 month 4.0 of year 1994.0 runtime 0:04:50.809457
# Processing image 164 month 4.0 of year 1995.0 runtime 0:04:52.565393
# Processing image 165 month 4.0 of year 1996.0 runtime 0:04:53.801893
# Processing image 166 month 4.0 of year 1997.0 runtime 0:04:55.630283
# Processing image 167 month 4.0 of year 1998.0 runtime 0:04:57.374557
# Processing image 168 month 4.0 of year 1999.0 runtime 0:04:59.246775
# Processing image 169 month 4.0 of year 2000.0 runtime 0:05:01.009796
# Processing image 170 month 4.0 of year 2001.0 runtime 0:05:02.772745
# Processing image 171 month 4.0 of year 2002.0 runtime 0:05:04.730921
# Processing image 172 month 4.0 of year 2003.0 runtime 0:05:06.659420
# Processing image 173 month 4.0 of year 2004.0 runtime 0:05:08.503724
# Processing image 174 month 4.0 of year 2005.0 runtime 0:05:10.362714
# Processing image 175 month 4.0 of year 2006.0 runtime 0:05:12.160987
# Processing image 176 month 4.0 of year 2007.0 runtime 0:05:14.064959
# Processing image 177 month 4.0 of year 2008.0 runtime 0:05:15.969748
# Processing image 178 month 4.0 of year 2009.0 runtime 0:05:17.828721
# Processing image 179 month 4.0 of year 2010.0 runtime 0:05:19.657662
# Processing image 180 month 4.0 of year 2011.0 runtime 0:05:21.688892
# Processing image 181 month 4.0 of year 2012.0 runtime 0:05:23.574935
# Processing image 182 month 4.0 of year 2013.0 runtime 0:05:25.414299
# Processing image 183 month 4.0 of year 2014.0 runtime 0:05:27.246309
# Processing image 184 month 5.0 of year 1969.0 runtime 0:05:29.115136
# Processing image 185 month 5.0 of year 1970.0 runtime 0:05:30.933221
# Processing image 186 month 5.0 of year 1971.0 runtime 0:05:32.879416
# Processing image 187 month 5.0 of year 1972.0 runtime 0:05:34.313319
# Processing image 188 month 5.0 of year 1973.0 runtime 0:05:36.147949
# Processing image 189 month 5.0 of year 1974.0 runtime 0:05:38.081553
# Processing image 190 month 5.0 of year 1975.0 runtime 0:05:39.943498
# Processing image 191 month 5.0 of year 1976.0 runtime 0:05:41.776737
# Processing image 192 month 5.0 of year 1977.0 runtime 0:05:43.674442
# Processing image 193 month 5.0 of year 1978.0 runtime 0:05:45.490072
# Processing image 194 month 5.0 of year 1979.0 runtime 0:05:47.412378
# Processing image 195 month 5.0 of year 1980.0 runtime 0:05:49.323957
# Processing image 196 month 5.0 of year 1981.0 runtime 0:05:51.176215
# Processing image 197 month 5.0 of year 1982.0 runtime 0:05:53.020132
# Processing image 198 month 5.0 of year 1983.0 runtime 0:05:54.837912
# Processing image 199 month 5.0 of year 1984.0 runtime 0:05:56.744827
# Processing image 200 month 5.0 of year 1985.0 runtime 0:05:58.542714
# Processing image 201 month 5.0 of year 1986.0 runtime 0:06:00.364552
# Processing image 202 month 5.0 of year 1987.0 runtime 0:06:01.753197
# Processing image 203 month 5.0 of year 1988.0 runtime 0:06:03.483580
# Processing image 204 month 5.0 of year 1989.0 runtime 0:06:05.247681
# Processing image 205 month 5.0 of year 1990.0 runtime 0:06:06.962777
# Processing image 206 month 5.0 of year 1991.0 runtime 0:06:08.709431
# Processing image 207 month 5.0 of year 1992.0 runtime 0:06:10.397486
# Processing image 208 month 5.0 of year 1993.0 runtime 0:06:12.102618
# Processing image 209 month 5.0 of year 1994.0 runtime 0:06:13.373000
# Processing image 210 month 5.0 of year 1995.0 runtime 0:06:15.100630
# Processing image 211 month 5.0 of year 1996.0 runtime 0:06:16.841182
# Processing image 212 month 5.0 of year 1997.0 runtime 0:06:18.551399
# Processing image 213 month 5.0 of year 1998.0 runtime 0:06:20.300405
# Processing image 214 month 5.0 of year 1999.0 runtime 0:06:22.025586
# Processing image 215 month 5.0 of year 2000.0 runtime 0:06:24.138693
# Processing image 216 month 5.0 of year 2001.0 runtime 0:06:25.917575
# Processing image 217 month 5.0 of year 2002.0 runtime 0:06:27.150291
# Processing image 218 month 5.0 of year 2003.0 runtime 0:06:28.876070
# Processing image 219 month 5.0 of year 2004.0 runtime 0:06:30.633945
# Processing image 220 month 5.0 of year 2005.0 runtime 0:06:32.365360
# Processing image 221 month 5.0 of year 2006.0 runtime 0:06:34.097523
# Processing image 222 month 5.0 of year 2007.0 runtime 0:06:35.816365
# Processing image 223 month 5.0 of year 2008.0 runtime 0:06:37.561803
# Processing image 224 month 5.0 of year 2009.0 runtime 0:06:38.817070
# Processing image 225 month 5.0 of year 2010.0 runtime 0:06:40.088498
# Processing image 226 month 5.0 of year 2011.0 runtime 0:06:41.815970
# Processing image 227 month 5.0 of year 2012.0 runtime 0:06:43.615700
# Processing image 228 month 5.0 of year 2013.0 runtime 0:06:45.370693
# Processing image 229 month 5.0 of year 2014.0 runtime 0:06:47.097191
# Processing image 230 month 6.0 of year 1969.0 runtime 0:06:48.789563
# Processing image 231 month 6.0 of year 1970.0 runtime 0:06:50.607799
# Processing image 232 month 6.0 of year 1971.0 runtime 0:06:52.295607
# Processing image 233 month 6.0 of year 1972.0 runtime 0:06:54.122442
# Processing image 234 month 6.0 of year 1973.0 runtime 0:06:55.834838
# Processing image 235 month 6.0 of year 1974.0 runtime 0:06:57.608045
# Processing image 236 month 6.0 of year 1975.0 runtime 0:06:59.462880
# Processing image 237 month 6.0 of year 1976.0 runtime 0:07:01.265327
# Processing image 238 month 6.0 of year 1977.0 runtime 0:07:03.035046
# Processing image 239 month 6.0 of year 1978.0 runtime 0:07:04.815006
# Processing image 240 month 6.0 of year 1979.0 runtime 0:07:06.615574
# Processing image 241 month 6.0 of year 1980.0 runtime 0:07:08.341009
# Processing image 242 month 6.0 of year 1981.0 runtime 0:07:10.049886
# Processing image 243 month 6.0 of year 1982.0 runtime 0:07:11.810222
# Processing image 244 month 6.0 of year 1983.0 runtime 0:07:13.523200
# Processing image 245 month 6.0 of year 1984.0 runtime 0:07:15.261658
# Processing image 246 month 6.0 of year 1985.0 runtime 0:07:17.001449
# Processing image 247 month 6.0 of year 1986.0 runtime 0:07:18.723928
# Processing image 248 month 6.0 of year 1987.0 runtime 0:07:20.479500
# Processing image 249 month 6.0 of year 1988.0 runtime 0:07:22.230015
# Processing image 250 month 6.0 of year 1989.0 runtime 0:07:23.982315
# Processing image 251 month 6.0 of year 1990.0 runtime 0:07:25.713695
# Processing image 252 month 6.0 of year 1991.0 runtime 0:07:27.435344
# Processing image 253 month 6.0 of year 1992.0 runtime 0:07:29.187616
# Processing image 254 month 6.0 of year 1993.0 runtime 0:07:31.011355
# Processing image 255 month 6.0 of year 1994.0 runtime 0:07:32.882069
# Processing image 256 month 6.0 of year 1995.0 runtime 0:07:34.634901
# Processing image 257 month 6.0 of year 1996.0 runtime 0:07:36.372396
# Processing image 258 month 6.0 of year 1997.0 runtime 0:07:38.114410
# Processing image 259 month 6.0 of year 1998.0 runtime 0:07:39.875794
# Processing image 260 month 6.0 of year 1999.0 runtime 0:07:41.645660
# Processing image 261 month 6.0 of year 2000.0 runtime 0:07:43.350517
# Processing image 262 month 6.0 of year 2001.0 runtime 0:07:45.093599
# Processing image 263 month 6.0 of year 2002.0 runtime 0:07:46.845546
# Processing image 264 month 6.0 of year 2003.0 runtime 0:07:49.284481
# Processing image 265 month 6.0 of year 2004.0 runtime 0:07:51.018138
# Processing image 266 month 6.0 of year 2005.0 runtime 0:07:52.773058
# Processing image 267 month 6.0 of year 2006.0 runtime 0:07:54.500077
# Processing image 268 month 6.0 of year 2007.0 runtime 0:07:56.267157
# Processing image 269 month 6.0 of year 2008.0 runtime 0:07:58.264752
# Processing image 270 month 6.0 of year 2009.0 runtime 0:08:00.043937
# Processing image 271 month 6.0 of year 2010.0 runtime 0:08:01.808845
# Processing image 272 month 6.0 of year 2011.0 runtime 0:08:03.762076
# Processing image 273 month 6.0 of year 2012.0 runtime 0:08:05.613921
# Processing image 274 month 6.0 of year 2013.0 runtime 0:08:07.484011
# Processing image 275 month 6.0 of year 2014.0 runtime 0:08:09.419310
# Processing image 276 month 7.0 of year 1969.0 runtime 0:08:11.291191
# Processing image 277 month 7.0 of year 1970.0 runtime 0:08:13.155261
# Processing image 278 month 7.0 of year 1971.0 runtime 0:08:14.548331
# Processing image 279 month 7.0 of year 1972.0 runtime 0:08:16.485670
# Processing image 280 month 7.0 of year 1973.0 runtime 0:08:18.376890
# Processing image 281 month 7.0 of year 1974.0 runtime 0:08:20.236278
# Processing image 282 month 7.0 of year 1975.0 runtime 0:08:22.197824
# Processing image 283 month 7.0 of year 1976.0 runtime 0:08:24.087226
# Processing image 284 month 7.0 of year 1977.0 runtime 0:08:26.034652
# Processing image 285 month 7.0 of year 1978.0 runtime 0:08:27.901479
# Processing image 286 month 7.0 of year 1979.0 runtime 0:08:29.829049
# Processing image 287 month 7.0 of year 1980.0 runtime 0:08:31.707528
# Processing image 288 month 7.0 of year 1981.0 runtime 0:08:33.602584
# Processing image 289 month 7.0 of year 1982.0 runtime 0:08:35.454276
# Processing image 290 month 7.0 of year 1983.0 runtime 0:08:37.333315
# Processing image 291 month 7.0 of year 1984.0 runtime 0:08:39.190653
# Processing image 292 month 7.0 of year 1985.0 runtime 0:08:41.128631
# Processing image 293 month 7.0 of year 1986.0 runtime 0:08:42.526960
# Processing image 294 month 7.0 of year 1987.0 runtime 0:08:43.958443
# Processing image 295 month 7.0 of year 1988.0 runtime 0:08:45.827100
# Processing image 296 month 7.0 of year 1989.0 runtime 0:08:47.700556
# Processing image 297 month 7.0 of year 1990.0 runtime 0:08:49.562075
# Processing image 298 month 7.0 of year 1991.0 runtime 0:08:51.465709
# Processing image 299 month 7.0 of year 1992.0 runtime 0:08:53.408585
# Processing image 300 month 7.0 of year 1993.0 runtime 0:08:55.355737
# Processing image 301 month 7.0 of year 1994.0 runtime 0:08:57.408102
# Processing image 302 month 7.0 of year 1995.0 runtime 0:08:58.879439
# Processing image 303 month 7.0 of year 1996.0 runtime 0:09:00.720886
# Processing image 304 month 7.0 of year 1997.0 runtime 0:09:02.620232
# Processing image 305 month 7.0 of year 1998.0 runtime 0:09:04.322839
# Processing image 306 month 7.0 of year 1999.0 runtime 0:09:06.042427
# Processing image 307 month 7.0 of year 2000.0 runtime 0:09:07.821241
# Processing image 308 month 7.0 of year 2001.0 runtime 0:09:09.555833
# Processing image 309 month 7.0 of year 2002.0 runtime 0:09:11.326623
# Processing image 310 month 7.0 of year 2003.0 runtime 0:09:13.056140
# Processing image 311 month 7.0 of year 2004.0 runtime 0:09:14.756216
# Processing image 312 month 7.0 of year 2005.0 runtime 0:09:16.496017
# Processing image 313 month 7.0 of year 2006.0 runtime 0:09:18.233402
# Processing image 314 month 7.0 of year 2007.0 runtime 0:09:19.976633
# Processing image 315 month 7.0 of year 2008.0 runtime 0:09:21.768291
# Processing image 316 month 7.0 of year 2009.0 runtime 0:09:23.522673
# Processing image 317 month 7.0 of year 2010.0 runtime 0:09:24.267529
# Processing image 318 month 7.0 of year 2011.0 runtime 0:09:25.973112
# Processing image 319 month 7.0 of year 2012.0 runtime 0:09:27.709631
# Processing image 320 month 7.0 of year 2013.0 runtime 0:09:29.441240
# Processing image 321 month 7.0 of year 2014.0 runtime 0:09:31.203439
# Processing image 322 month 8.0 of year 1969.0 runtime 0:09:32.958584
# Processing image 323 month 8.0 of year 1970.0 runtime 0:09:34.695765
# Processing image 324 month 8.0 of year 1971.0 runtime 0:09:36.438720
# Processing image 325 month 8.0 of year 1972.0 runtime 0:09:38.135321
# Processing image 326 month 8.0 of year 1973.0 runtime 0:09:39.893242
# Processing image 327 month 8.0 of year 1974.0 runtime 0:09:41.600706
# Processing image 328 month 8.0 of year 1975.0 runtime 0:09:43.337880
# Processing image 329 month 8.0 of year 1976.0 runtime 0:09:45.083189
# Processing image 330 month 8.0 of year 1977.0 runtime 0:09:46.788543
# Processing image 331 month 8.0 of year 1978.0 runtime 0:09:48.573641
# Processing image 332 month 8.0 of year 1979.0 runtime 0:09:50.355712
# Processing image 333 month 8.0 of year 1980.0 runtime 0:09:52.075746
# Processing image 334 month 8.0 of year 1981.0 runtime 0:09:53.401110
# Processing image 335 month 8.0 of year 1982.0 runtime 0:09:55.125570
# Processing image 336 month 8.0 of year 1983.0 runtime 0:09:56.857522
# Processing image 337 month 8.0 of year 1984.0 runtime 0:09:58.588547
# Processing image 338 month 8.0 of year 1985.0 runtime 0:10:00.342231
# Processing image 339 month 8.0 of year 1986.0 runtime 0:10:02.093024
# Processing image 340 month 8.0 of year 1987.0 runtime 0:10:03.844940
# Processing image 341 month 8.0 of year 1988.0 runtime 0:10:05.142970
# Processing image 342 month 8.0 of year 1989.0 runtime 0:10:06.866440
# Processing image 343 month 8.0 of year 1990.0 runtime 0:10:08.594095
# Processing image 344 month 8.0 of year 1991.0 runtime 0:10:10.353313
# Processing image 345 month 8.0 of year 1992.0 runtime 0:10:12.065880
# Processing image 346 month 8.0 of year 1993.0 runtime 0:10:13.302473
# Processing image 347 month 8.0 of year 1994.0 runtime 0:10:15.044479
# Processing image 348 month 8.0 of year 1995.0 runtime 0:10:16.779564
# Processing image 349 month 8.0 of year 1996.0 runtime 0:10:18.519617
# Processing image 350 month 8.0 of year 1997.0 runtime 0:10:20.270151
# Processing image 351 month 8.0 of year 1998.0 runtime 0:10:22.044577
# Processing image 352 month 8.0 of year 1999.0 runtime 0:10:23.800396
# Processing image 353 month 8.0 of year 2000.0 runtime 0:10:25.515703
# Processing image 354 month 8.0 of year 2001.0 runtime 0:10:26.822974
# Processing image 355 month 8.0 of year 2002.0 runtime 0:10:28.542920
# Processing image 356 month 8.0 of year 2003.0 runtime 0:10:30.314098
# Processing image 357 month 8.0 of year 2004.0 runtime 0:10:32.029294
# Processing image 358 month 8.0 of year 2005.0 runtime 0:10:33.808583
# Processing image 359 month 8.0 of year 2006.0 runtime 0:10:35.555790
# Processing image 360 month 8.0 of year 2007.0 runtime 0:10:36.955684
# Processing image 361 month 8.0 of year 2008.0 runtime 0:10:38.669615
# Processing image 362 month 8.0 of year 2009.0 runtime 0:10:40.450274
# Processing image 363 month 8.0 of year 2010.0 runtime 0:10:42.158639
# Processing image 364 month 8.0 of year 2011.0 runtime 0:10:43.917699
# Processing image 365 month 8.0 of year 2012.0 runtime 0:10:45.661877
# Processing image 366 month 8.0 of year 2013.0 runtime 0:10:47.376997
# Processing image 367 month 8.0 of year 2014.0 runtime 0:10:49.097853
# Processing image 368 month 9.0 of year 1969.0 runtime 0:10:50.343872
# Processing image 369 month 9.0 of year 1970.0 runtime 0:10:52.089798
# Processing image 370 month 9.0 of year 1971.0 runtime 0:10:53.845257
# Processing image 371 month 9.0 of year 1972.0 runtime 0:10:55.607207
# Processing image 372 month 9.0 of year 1973.0 runtime 0:10:57.356717
# Processing image 373 month 9.0 of year 1974.0 runtime 0:10:59.098677
# Processing image 374 month 9.0 of year 1975.0 runtime 0:11:00.856458
# Processing image 375 month 9.0 of year 1976.0 runtime 0:11:02.598249
# Processing image 376 month 9.0 of year 1977.0 runtime 0:11:04.304245
# Processing image 377 month 9.0 of year 1978.0 runtime 0:11:06.064987
# Processing image 378 month 9.0 of year 1979.0 runtime 0:11:07.843313
# Processing image 379 month 9.0 of year 1980.0 runtime 0:11:09.603731
# Processing image 380 month 9.0 of year 1981.0 runtime 0:11:11.352727
# Processing image 381 month 9.0 of year 1982.0 runtime 0:11:13.090482
# Processing image 382 month 9.0 of year 1983.0 runtime 0:11:14.890652
# Processing image 383 month 9.0 of year 1984.0 runtime 0:11:16.628747
# Processing image 384 month 9.0 of year 1985.0 runtime 0:11:18.353551
# Processing image 385 month 9.0 of year 1986.0 runtime 0:11:20.102672
# Processing image 386 month 9.0 of year 1987.0 runtime 0:11:21.848630
# Processing image 387 month 9.0 of year 1988.0 runtime 0:11:23.563892
# Processing image 388 month 9.0 of year 1989.0 runtime 0:11:25.279519
# Processing image 389 month 9.0 of year 1990.0 runtime 0:11:27.019920
# Processing image 390 month 9.0 of year 1991.0 runtime 0:11:28.807679
# Processing image 391 month 9.0 of year 1992.0 runtime 0:11:30.504941
# Processing image 392 month 9.0 of year 1993.0 runtime 0:11:32.222459
# Processing image 393 month 9.0 of year 1994.0 runtime 0:11:33.963254
# Processing image 394 month 9.0 of year 1995.0 runtime 0:11:35.696039
# Processing image 395 month 9.0 of year 1996.0 runtime 0:11:37.517898
# Processing image 396 month 9.0 of year 1997.0 runtime 0:11:39.260540
# Processing image 397 month 9.0 of year 1998.0 runtime 0:11:41.026699
# Processing image 398 month 9.0 of year 1999.0 runtime 0:11:42.766539
# Processing image 399 month 9.0 of year 2000.0 runtime 0:11:44.492001
# Processing image 400 month 9.0 of year 2001.0 runtime 0:11:46.286491
# Processing image 401 month 9.0 of year 2002.0 runtime 0:11:48.074415
# Processing image 402 month 9.0 of year 2003.0 runtime 0:11:49.856152
# Processing image 403 month 9.0 of year 2004.0 runtime 0:11:51.595826
# Processing image 404 month 9.0 of year 2005.0 runtime 0:11:53.337228
# Processing image 405 month 9.0 of year 2006.0 runtime 0:11:54.597299
# Processing image 406 month 9.0 of year 2007.0 runtime 0:11:56.387143
# Processing image 407 month 9.0 of year 2008.0 runtime 0:11:58.309858
# Processing image 408 month 9.0 of year 2009.0 runtime 0:12:00.177620
# Processing image 409 month 9.0 of year 2010.0 runtime 0:12:01.874020
# Processing image 410 month 9.0 of year 2011.0 runtime 0:12:03.639379
# Processing image 411 month 9.0 of year 2012.0 runtime 0:12:05.396009
# Processing image 412 month 9.0 of year 2013.0 runtime 0:12:07.135726
# Processing image 413 month 9.0 of year 2014.0 runtime 0:12:08.904360
# Processing image 414 month 10.0 of year 1969.0 runtime 0:12:10.677010
# Processing image 415 month 10.0 of year 1970.0 runtime 0:12:12.432595
# Processing image 416 month 10.0 of year 1971.0 runtime 0:12:13.661650
# Processing image 417 month 10.0 of year 1972.0 runtime 0:12:15.179565
# Processing image 418 month 10.0 of year 1973.0 runtime 0:12:16.962587
# Processing image 419 month 10.0 of year 1974.0 runtime 0:12:18.687354
# Processing image 420 month 10.0 of year 1975.0 runtime 0:12:20.471417
# Processing image 421 month 10.0 of year 1976.0 runtime 0:12:22.224007
# Processing image 422 month 10.0 of year 1977.0 runtime 0:12:23.955603
# Processing image 423 month 10.0 of year 1978.0 runtime 0:12:25.715556
# Processing image 424 month 10.0 of year 1979.0 runtime 0:12:27.444095
# Processing image 425 month 10.0 of year 1980.0 runtime 0:12:29.152772
# Processing image 426 month 10.0 of year 1981.0 runtime 0:12:30.858138
# Processing image 427 month 10.0 of year 1982.0 runtime 0:12:32.579693
# Processing image 428 month 10.0 of year 1983.0 runtime 0:12:34.279042
# Processing image 429 month 10.0 of year 1984.0 runtime 0:12:36.104113
# Processing image 430 month 10.0 of year 1985.0 runtime 0:12:37.854838
# Processing image 431 month 10.0 of year 1986.0 runtime 0:12:39.577263
# Processing image 432 month 10.0 of year 1987.0 runtime 0:12:40.798050
# Processing image 433 month 10.0 of year 1988.0 runtime 0:12:42.526850
# Processing image 434 month 10.0 of year 1989.0 runtime 0:12:44.284992
# Processing image 435 month 10.0 of year 1990.0 runtime 0:12:46.001996
# Processing image 436 month 10.0 of year 1991.0 runtime 0:12:47.764876
# Processing image 437 month 10.0 of year 1992.0 runtime 0:12:49.486264
# Processing image 438 month 10.0 of year 1993.0 runtime 0:12:51.232054
# Processing image 439 month 10.0 of year 1994.0 runtime 0:12:54.836892
# Processing image 440 month 10.0 of year 1995.0 runtime 0:12:56.578385
# Processing image 441 month 10.0 of year 1996.0 runtime 0:12:58.341730
# Processing image 442 month 10.0 of year 1997.0 runtime 0:13:00.117129
# Processing image 443 month 10.0 of year 1998.0 runtime 0:13:01.848000
# Processing image 444 month 10.0 of year 1999.0 runtime 0:13:03.583214
# Processing image 445 month 10.0 of year 2000.0 runtime 0:13:05.637491
# Processing image 446 month 10.0 of year 2001.0 runtime 0:13:07.379101
# Processing image 447 month 10.0 of year 2002.0 runtime 0:13:09.100785
# Processing image 448 month 10.0 of year 2003.0 runtime 0:13:10.966208
# Processing image 449 month 10.0 of year 2004.0 runtime 0:13:12.725605
# Processing image 450 month 10.0 of year 2005.0 runtime 0:13:14.428257
# Processing image 451 month 10.0 of year 2006.0 runtime 0:13:16.158712
# Processing image 452 month 10.0 of year 2007.0 runtime 0:13:17.923796
# Processing image 453 month 10.0 of year 2008.0 runtime 0:13:19.657771
# Processing image 454 month 10.0 of year 2009.0 runtime 0:13:21.418183
# Processing image 455 month 10.0 of year 2010.0 runtime 0:13:23.141099
# Processing image 456 month 10.0 of year 2011.0 runtime 0:13:25.052255
# Processing image 457 month 10.0 of year 2012.0 runtime 0:13:26.761682
# Processing image 458 month 10.0 of year 2013.0 runtime 0:13:28.500532
# Processing image 459 month 10.0 of year 2014.0 runtime 0:13:30.295859
# Processing image 460 month 11.0 of year 1969.0 runtime 0:13:31.998895
# Processing image 461 month 11.0 of year 1970.0 runtime 0:13:33.783623
# Processing image 462 month 11.0 of year 1971.0 runtime 0:13:35.527636
# Processing image 463 month 11.0 of year 1972.0 runtime 0:13:37.266495
# Processing image 464 month 11.0 of year 1973.0 runtime 0:13:38.996131
# Processing image 465 month 11.0 of year 1974.0 runtime 0:13:40.757259
# Processing image 466 month 11.0 of year 1975.0 runtime 0:13:42.501754
# Processing image 467 month 11.0 of year 1976.0 runtime 0:13:44.221641
# Processing image 468 month 11.0 of year 1977.0 runtime 0:13:45.958326
# Processing image 469 month 11.0 of year 1978.0 runtime 0:13:47.684309
# Processing image 470 month 11.0 of year 1979.0 runtime 0:13:49.445938
# Processing image 471 month 11.0 of year 1980.0 runtime 0:13:51.175110
# Processing image 472 month 11.0 of year 1981.0 runtime 0:13:52.993916
# Processing image 473 month 11.0 of year 1982.0 runtime 0:13:54.692163
# Processing image 474 month 11.0 of year 1983.0 runtime 0:13:56.413917
# Processing image 475 month 11.0 of year 1984.0 runtime 0:13:57.719015
# Processing image 476 month 11.0 of year 1985.0 runtime 0:13:59.598910
# Processing image 477 month 11.0 of year 1986.0 runtime 0:14:01.358538
# Processing image 478 month 11.0 of year 1987.0 runtime 0:14:03.185093
# Processing image 479 month 11.0 of year 1988.0 runtime 0:14:05.057573
# Processing image 480 month 11.0 of year 1989.0 runtime 0:14:06.945972
# Processing image 481 month 11.0 of year 1990.0 runtime 0:14:08.821352
# Processing image 482 month 11.0 of year 1991.0 runtime 0:14:10.665791
# Processing image 483 month 11.0 of year 1992.0 runtime 0:14:12.661300
# Processing image 484 month 11.0 of year 1993.0 runtime 0:14:14.529218
# Processing image 485 month 11.0 of year 1994.0 runtime 0:14:16.369037
# Processing image 486 month 11.0 of year 1995.0 runtime 0:14:17.796182
# Processing image 487 month 11.0 of year 1996.0 runtime 0:14:19.717656
# Processing image 488 month 11.0 of year 1997.0 runtime 0:14:21.559682
# Processing image 489 month 11.0 of year 1998.0 runtime 0:14:23.445172
# Processing image 490 month 11.0 of year 1999.0 runtime 0:14:25.339112
# Processing image 491 month 11.0 of year 2000.0 runtime 0:14:27.215281
# Processing image 492 month 11.0 of year 2001.0 runtime 0:14:29.080987
# Processing image 493 month 11.0 of year 2002.0 runtime 0:14:31.044141
# Processing image 494 month 11.0 of year 2003.0 runtime 0:14:32.905479
# Processing image 495 month 11.0 of year 2004.0 runtime 0:14:34.780508
# Processing image 496 month 11.0 of year 2005.0 runtime 0:14:36.636659
# Processing image 497 month 11.0 of year 2006.0 runtime 0:14:38.514715
# Processing image 498 month 11.0 of year 2007.0 runtime 0:14:40.362328
# Processing image 499 month 11.0 of year 2008.0 runtime 0:14:41.761491
# Processing image 500 month 11.0 of year 2009.0 runtime 0:14:43.713619
# Processing image 501 month 11.0 of year 2010.0 runtime 0:14:45.603333
# Processing image 502 month 11.0 of year 2011.0 runtime 0:14:47.471937
# Processing image 503 month 11.0 of year 2012.0 runtime 0:14:49.338618
# Processing image 504 month 11.0 of year 2013.0 runtime 0:14:51.186029
# Processing image 505 month 11.0 of year 2014.0 runtime 0:14:53.086178
# Processing image 506 month 12.0 of year 1969.0 runtime 0:14:54.977363
# Processing image 507 month 12.0 of year 1970.0 runtime 0:14:56.938616
# Processing image 508 month 12.0 of year 1971.0 runtime 0:14:58.807192
# Processing image 509 month 12.0 of year 1972.0 runtime 0:15:00.678736
# Processing image 510 month 12.0 of year 1973.0 runtime 0:15:02.515055
# Processing image 511 month 12.0 of year 1974.0 runtime 0:15:04.450730
# Processing image 512 month 12.0 of year 1975.0 runtime 0:15:06.323674
# Processing image 513 month 12.0 of year 1976.0 runtime 0:15:08.224622
# Processing image 514 month 12.0 of year 1977.0 runtime 0:15:09.727140
# Processing image 515 month 12.0 of year 1978.0 runtime 0:15:11.604675
# Processing image 516 month 12.0 of year 1979.0 runtime 0:15:13.436199
# Processing image 517 month 12.0 of year 1980.0 runtime 0:15:15.357589
# Processing image 518 month 12.0 of year 1981.0 runtime 0:15:17.238102
# Processing image 519 month 12.0 of year 1982.0 runtime 0:15:19.135452
# Processing image 520 month 12.0 of year 1983.0 runtime 0:15:21.037484
# Processing image 521 month 12.0 of year 1984.0 runtime 0:15:23.041905
# Processing image 522 month 12.0 of year 1985.0 runtime 0:15:24.458536
# Processing image 523 month 12.0 of year 1986.0 runtime 0:15:26.321962
# Processing image 524 month 12.0 of year 1987.0 runtime 0:15:28.226150
# Processing image 525 month 12.0 of year 1988.0 runtime 0:15:30.170663
# Processing image 526 month 12.0 of year 1989.0 runtime 0:15:32.067608
# Processing image 527 month 12.0 of year 1990.0 runtime 0:15:34.004552
# Processing image 528 month 12.0 of year 1991.0 runtime 0:15:35.919795
# Processing image 529 month 12.0 of year 1992.0 runtime 0:15:37.771951
# Processing image 530 month 12.0 of year 1993.0 runtime 0:15:39.620302
# Processing image 531 month 12.0 of year 1994.0 runtime 0:15:41.566325
# Processing image 532 month 12.0 of year 1995.0 runtime 0:15:43.454564
# Processing image 533 month 12.0 of year 1996.0 runtime 0:15:45.366094
# Processing image 534 month 12.0 of year 1997.0 runtime 0:15:47.244044
# Processing image 535 month 12.0 of year 1998.0 runtime 0:15:49.076753
# Processing image 536 month 12.0 of year 1999.0 runtime 0:15:50.506506
# Processing image 537 month 12.0 of year 2000.0 runtime 0:15:52.377207
# Processing image 538 month 12.0 of year 2001.0 runtime 0:15:54.304499
# Processing image 539 month 12.0 of year 2002.0 runtime 0:15:56.201606
# Processing image 540 month 12.0 of year 2003.0 runtime 0:15:58.077880
# Processing image 541 month 12.0 of year 2004.0 runtime 0:16:00.025149
# Processing image 542 month 12.0 of year 2005.0 runtime 0:16:01.487346
# Processing image 543 month 12.0 of year 2006.0 runtime 0:16:03.389217
# Processing image 544 month 12.0 of year 2007.0 runtime 0:16:05.151540
# Processing image 545 month 12.0 of year 2008.0 runtime 0:16:06.886521
# Processing image 546 month 12.0 of year 2009.0 runtime 0:16:08.688614
# Processing image 547 month 12.0 of year 2010.0 runtime 0:16:10.443149
# Processing image 548 month 12.0 of year 2011.0 runtime 0:16:12.174258
# Processing image 549 month 12.0 of year 2012.0 runtime 0:16:13.906817
# Processing image 550 month 12.0 of year 2013.0 runtime 0:16:15.698487
# Processing image 551 month 12.0 of year 2014.0 runtime 0:16:17.425728

# %%
end = datetime.datetime.now()
elapsed = end - start
print(elapsed)
# Out:
# 0:16:24.985188
