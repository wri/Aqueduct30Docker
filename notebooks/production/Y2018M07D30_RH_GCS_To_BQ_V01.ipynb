# %%
# ready to run
""" Store Cloudstorage CSV files into bigquery table.
-------------------------------------------------------------------------------

Author: Rutger Hofste
Date: 20180712
Kernel: python35
Docker: rutgerhofste/gisdocker:ubuntu16.04
"""

SCRIPT_NAME = 'Y2018M07D30_RH_GCS_To_BQ_V01'
OUTPUT_VERSION = 6
OVERWRITE_OUTPUT = 1 


GCS_INPUT_PATH = "gs://aqueduct30_v01/Y2018M07D17_RH_RDS_To_S3_V02/output_V10/"

DATABASE_ENDPOINT = "aqueduct30v05.cgpnumwmfcqc.eu-central-1.rds.amazonaws.com"
DATABASE_NAME = "database01"
INPUT_TABLE_NAME = "y2018m07d30_rh_coalesce_columns_v01_v08" #For header


OUTPUT_DATASET_NAME = "aqueduct30v01"
OUTPUT_TABLE_NAME = "{}_v{:02.0f}".format(SCRIPT_NAME,OUTPUT_VERSION).lower()

print("Input gcs: ", GCS_INPUT_PATH,
      "\nOutput bq dataset name: ", OUTPUT_DATASET_NAME,
      "\nOutput bq table name: ", OUTPUT_TABLE_NAME)
# Out:
# Input gcs:  gs://aqueduct30_v01/Y2018M07D17_RH_RDS_To_S3_V02/output_V10/
# Output bq dataset name:  aqueduct30v01
# Output bq table name:  y2018m07d30_rh_gcs_to_bq_v01_v06

# %%
import time, datetime, sys
dateString = time.strftime("Y%YM%mD%d")
timeString = time.strftime("UTC %H:%M")
start = datetime.datetime.now()
print(dateString,timeString)
sys.version
# Out:
# Y2019M04D04 UTC 14:18
# '3.5.4 |Anaconda, Inc.| (default, Nov 20 2017, 18:44:38) \n[GCC 7.2.0]'

# %%
import os
import pandas as pd
from sqlalchemy import *
from google.cloud import bigquery

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/.google.json"
client = bigquery.Client()

# %%
F = open("/.password","r")
password = F.read().splitlines()[0]
F.close()

engine = create_engine("postgresql://rutgerhofste:{}@{}:5432/{}".format(password,DATABASE_ENDPOINT,DATABASE_NAME))

# %%
def bq_check_if_exists(dataset_name,table_name):
    dataset_ref = client.dataset(dataset_name)
    tables_server = list(client.list_tables(dataset_ref))
    tables_client = list(map(lambda x: x.table_id,tables_server))
    return table_name in tables_client

# %%
def bq_delete_table(dataset_name,table_name):
    table_ref = client.dataset(dataset_name).table(table_name)
    client.delete_table(table_ref)
    print('Table {}:{} deleted.'.format(dataset_name, table_name))
    return 1

# %%
exists = bq_check_if_exists(OUTPUT_DATASET_NAME,OUTPUT_TABLE_NAME)

# %%
if exists and OVERWRITE_OUTPUT:
    print("table exists, overwriting table")
    bq_delete_table(OUTPUT_DATASET_NAME,OUTPUT_TABLE_NAME)
# Out:
# table exists, overwriting table
# Table aqueduct30v01:y2018m07d30_rh_gcs_to_bq_v01_v06 deleted.

# %%
# obtain schema from PostgreSQL
sql =  "SELECT column_name,data_type"
sql += " FROM information_schema.columns"
sql += " where table_name = '{}';".format(INPUT_TABLE_NAME)
print(sql)
df = pd.read_sql(sql,engine)
# Out:
# SELECT column_name,data_type FROM information_schema.columns where table_name = 'y2018m07d30_rh_coalesce_columns_v01_v08';

# %%
df
# Out:
#                                            column_name         data_type
# 0                                     pfafid_30spfaf06            bigint
# 1                                  temporal_resolution              text
# 2                                                 year            bigint
# 3                                                month            bigint
# 4                                    area_m2_30spfaf06  double precision
# 5                                 area_count_30spfaf06            bigint
# 6                                   ptotww_m_30spfaf06  double precision
# 7                                   ptotwn_m_30spfaf06  double precision
# 8                                   pdomww_m_30spfaf06  double precision
# 9                                   pdomwn_m_30spfaf06  double precision
# 10                                  pindww_m_30spfaf06  double precision
# 11                                  pindwn_m_30spfaf06  double precision
# 12                                  pirrww_m_30spfaf06  double precision
# 13                                  pirrwn_m_30spfaf06  double precision
# 14                                  plivww_m_30spfaf06  double precision
# 15                                  plivwn_m_30spfaf06  double precision
# 16                          riverdischarge_m_30spfaf06  double precision
# 17                             ma10_ptotww_m_30spfaf06  double precision
# 18                             ma10_ptotwn_m_30spfaf06  double precision
# 19                             ma10_pdomww_m_30spfaf06  double precision
# 20                             ma10_pdomwn_m_30spfaf06  double precision
# 21                             ma10_pindww_m_30spfaf06  double precision
# 22                             ma10_pindwn_m_30spfaf06  double precision
# 23                             ma10_pirrww_m_30spfaf06  double precision
# 24                             ma10_pirrwn_m_30spfaf06  double precision
# 25                             ma10_plivww_m_30spfaf06  double precision
# 26                             ma10_plivwn_m_30spfaf06  double precision
# 27                     ma10_riverdischarge_m_30spfaf06  double precision
# 28                            min10_ptotww_m_30spfaf06  double precision
# 29                            min10_ptotwn_m_30spfaf06  double precision
# ..                                                 ...               ...
# 203  avg1y_ols_ols10_weighted_waterstress_dimension...  double precision
# 204  avg1y_ols_ols10_waterdepletion_dimensionless_3...  double precision
# 205  avg1y_ols_ols10_weighted_waterdepletion_dimens...  double precision
# 206            waterstress_raw_dimensionless_30spfaf06  double precision
# 207         waterdepletion_raw_dimensionless_30spfaf06  double precision
# 208          waterstress_score_dimensionless_30spfaf06  double precision
# 209       waterdepletion_score_dimensionless_30spfaf06  double precision
# 210       waterstress_category_dimensionless_30spfaf06  double precision
# 211    waterdepletion_category_dimensionless_30spfaf06  double precision
# 212          waterstress_label_dimensionless_30spfaf06              text
# 213       waterdepletion_label_dimensionless_30spfaf06              text
# 214                                           delta_id           integer
# 215                             riverdischarge_m_delta  double precision
# 216                waterstress_raw_dimensionless_delta  double precision
# 217              waterstress_score_dimensionless_delta  double precision
# 218           waterstress_category_dimensionless_delta  double precision
# 219              waterstress_label_dimensionless_delta              text
# 220             waterdepletion_raw_dimensionless_delta  double precision
# 221           waterdepletion_score_dimensionless_delta  double precision
# 222        waterdepletion_category_dimensionless_delta  double precision
# 223           waterdepletion_label_dimensionless_delta              text
# 224                         riverdischarge_m_coalesced  double precision
# 225            waterstress_raw_dimensionless_coalesced  double precision
# 226          waterstress_score_dimensionless_coalesced  double precision
# 227       waterstress_category_dimensionless_coalesced  double precision
# 228          waterstress_label_dimensionless_coalesced              text
# 229         waterdepletion_raw_dimensionless_coalesced  double precision
# 230       waterdepletion_score_dimensionless_coalesced  double precision
# 231    waterdepletion_category_dimensionless_coalesced  double precision
# 232       waterdepletion_label_dimensionless_coalesced              text
#
# [233 rows x 2 columns]

# %%
def SQL_to_BQ_dict(sql_type):
    """
    SQL to Bigquery type (string)
    """
    
    if sql_type == "bigint" or sql_type == "integer":
        bq_type = "INTEGER"
    elif sql_type == "text":
        bq_type = "STRING"
    elif sql_type == "double precision":
        bq_type = "FLOAT"
    else:
        bq_type = "error!!"
    return bq_type

# %%
schema = []
for index, row in df.iterrows():
    sql_type = row["data_type"]
    bq_type = SQL_to_BQ_dict(sql_type)
    if bq_type == "error!!":
        print(sql_type)
    schema.append(bigquery.SchemaField(row["column_name"], bq_type))

# %%
dataset_ref = client.dataset(OUTPUT_DATASET_NAME)
job_config = bigquery.LoadJobConfig()
#job_config.schema = schema
job_config.write_disposition = "WRITE_APPEND"
job_config.autodetect = True
job_config.skip_leading_rows = 1
# The source format defaults to CSV, so the line below is optional.
job_config.source_format = bigquery.SourceFormat.CSV
#uri = 'gs://aqueduct30_v01/Y2018M07D17_RH_RDS_To_S3_V02/output_V02/*'
uri = '{}*'.format(GCS_INPUT_PATH)

# %%
load_job = client.load_table_from_uri(source_uris = uri,
                                      destination = dataset_ref.table(OUTPUT_TABLE_NAME),
                                      job_config=job_config) 
print('Starting job {}'.format(load_job.job_id))
load_job.result()
print('Job finished.')
# Out:
# Starting job da1b48cd-ebcb-49e5-b184-b9fb81a40bcf
# Job finished.

# %%
end = datetime.datetime.now()
elapsed = end - start
print(elapsed)
# Out:
# 0:02:37.833459

# %% [markdown]
# Previous runs:
# 0:03:08.852822
# 0:02:24.556886
# 0:02:31.501342
# 0:02:21.296729
# 0:02:37.833459
