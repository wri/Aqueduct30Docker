# %%
""" Rasterize Aqueduct 30 and store to Google Cloud Storage.
-------------------------------------------------------------------------------

Recap: The quantiles approach has been applied to all weightings, not just
the default one. Therefore there are slight variations in the histogram for
"def" or default weighting. 

Rasterizing the master geom at 30s takes a long time. Consider using the 
simplified version of the master geomtery. 

Update:
- In order to compare overall water risk, it is important to export the
mask with the fraction of valid data.

The column is renamed to owr_wf (overall water risk weight fraction)

Author: Rutger Hofste
Date: 20190521
Kernel: python35
Docker: rutgerhofste/gisdocker:ubuntu16.04

"""
TESTING = 0

SCRIPT_NAME = "Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01"
OUTPUT_VERSION = 5

GDAL_RASTERIZE_PATH = "/opt/anaconda3/envs/python35/bin/gdal_rasterize"
X_DIMENSION_30S = 43200
Y_DIMENSION_30S = 21600

S3_TABLE_INPUT_PATH = "s3://wri-projects/Aqueduct30/finalData/Y2019M01D14_RH_Aqueduct_Results_V01/output_V04/annual"
TABLE_INPUT_FILE_NAME = "annual_pivot.pkl"

#S3_GEOM_INPUT_PATH = "s3://wri-projects/Aqueduct30/finalData/Y2019M01D14_RH_Aqueduct_Results_V01/output_V04/master_geom"
#GEOM_INPUT_FILE_NAME = "master_geom.shp"

S3_GEOM_INPUT_PATH = "s3://wri-projects/Aqueduct30/rawData/Vizzuality/Y2019M05D21_RH_Simplified_Master_Geom_V01/output_V01"
GEOM_INPUT_FILE_NAME = "y2018m12d06_rh_master_shape_v02_2.gpkg"


ec2_input_path = "/volumes/data/{}/input_V{:02.0f}".format(SCRIPT_NAME,OUTPUT_VERSION) 
ec2_process_path =  "/volumes/data/{}/process_V{:02.0f}".format(SCRIPT_NAME,OUTPUT_VERSION) 
ec2_output_path = "/volumes/data/{}/output_V{:02.0f}".format(SCRIPT_NAME,OUTPUT_VERSION) 

GCS_OUTPUT_PATH = "gs://aqueduct30_v01/{}/".format(SCRIPT_NAME)

print("\nGCS_OUTPUT_PATH: " + GCS_OUTPUT_PATH)
# Out:
# GCS_OUTPUT_PATH: gs://aqueduct30_v01/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/

# %%
import time, datetime, sys
dateString = time.strftime("Y%YM%mD%d")
timeString = time.strftime("UTC %H:%M")
start = datetime.datetime.now()
print(dateString,timeString)
sys.version

# %matplotlib inline
# Out:
# Y2019M05D22 UTC 15:47

# %%
import os
import subprocess
import numpy as np
import pandas as pd
import geopandas as gpd
from google.cloud import bigquery

# %%
# !rm -r {ec2_input_path}
# !rm -r {ec2_process_path}
# !rm -r {ec2_output_path}
# !mkdir -p {ec2_input_path}
# !mkdir -p {ec2_process_path}
# !mkdir -p {ec2_output_path}

# %%
# !aws s3 cp {S3_TABLE_INPUT_PATH}/{TABLE_INPUT_FILE_NAME} {ec2_input_path}
# Out:
# download: s3://wri-projects/Aqueduct30/finalData/Y2019M01D14_RH_Aqueduct_Results_V01/output_V04/annual/annual_pivot.pkl to ../../../../../data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/input_V05/annual_pivot.pkl

# %%
# !aws s3 cp {S3_GEOM_INPUT_PATH} {ec2_input_path} --recursive
# Out:
# download: s3://wri-projects/Aqueduct30/rawData/Vizzuality/Y2019M05D21_RH_Simplified_Master_Geom_V01/output_V01/y2018m12d06_rh_master_shape_v02_2.gpkg to ../../../../../data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/input_V05/y2018m12d06_rh_master_shape_v02_2.gpkg

# %%
table_input_path = "{}/{}".format(ec2_input_path,TABLE_INPUT_FILE_NAME)
geom_input_path = "{}/{}".format(ec2_input_path,GEOM_INPUT_FILE_NAME)

# %%
df_table = pd.read_pickle(table_input_path)

# %%
gdf_geom = gpd.read_file(geom_input_path)

# %%
df_table.head()
# Out:
#    aq30_id  aqid   area_km2  bwd_cat bwd_label  bwd_raw  bwd_score  bws_cat  \
# 0    68095 -9999   0.021614      NaN      None      NaN        NaN      NaN
# 1    68245 -9999   0.018349      NaN      None      NaN        NaN      NaN
# 2    68422 -9999   0.006812      NaN      None      NaN        NaN      NaN
# 3    68408 -9999   0.033232      NaN      None      NaN        NaN      NaN
# 4    68110 -9999  14.558037      NaN      None      NaN        NaN      NaN
#
#   bws_label  bws_raw              ...                w_awr_tex_rrr_cat  \
# 0      None      NaN              ...                              4.0
# 1      None      NaN              ...                              2.0
# 2      None      NaN              ...                              1.0
# 3      None      NaN              ...                              2.0
# 4      None      NaN              ...                              NaN
#
#     w_awr_tex_rrr_label  w_awr_tex_rrr_raw w_awr_tex_rrr_score  \
# 0  Extremely High (4-5)               4.16            4.215654
# 1   Medium - High (2-3)               2.50            2.779638
# 2    Low - Medium (1-2)               1.20            1.828221
# 3   Medium - High (2-3)               1.64            2.177403
# 4                NoData                NaN                 NaN
#
#    w_awr_tex_rrr_weight_fraction  w_awr_tex_tot_cat   w_awr_tex_tot_label  \
# 0                       0.163265                4.0  Extremely High (4-5)
# 1                       0.163265                4.0  Extremely High (4-5)
# 2                       0.163265                2.0   Medium - High (2-3)
# 3                       0.163265                2.0   Medium - High (2-3)
# 4                       0.000000                NaN                NoData
#
#   w_awr_tex_tot_raw  w_awr_tex_tot_score  w_awr_tex_tot_weight_fraction
# 0          4.580000             4.819062                       0.326531
# 1          2.869318             4.082090                       0.326531
# 2          1.858333             2.502638                       0.326531
# 3          1.718333             2.218954                       0.326531
# 4               NaN                  NaN                       0.000000
#
# [5 rows x 267 columns]

# %%
df_table.drop(columns=["aq30_id","pfaf_id","gid_1","aqid"],inplace=True)

# %%
gdf_geom.head()
# Out:
#    aq30_id  aqid     gid_1  pfaf_id             string_id          type  \
# 0        0  3365  EGY.11_1   111011  111011-EGY.11_1-3365       Polygon
# 1        1  3365  EGY.15_1   111011  111011-EGY.15_1-3365       Polygon
# 2        2 -9999  EGY.15_1   111011  111011-EGY.15_1-None  MultiPolygon
# 3        3  3365     -9999   111011      111011-None-3365  MultiPolygon
# 4        4 -9999     -9999   111011      111011-None-None  MultiPolygon
#
#                                             geometry
# 0  (POLYGON ((31.90590570688292 29.85788703615783...
# 1  (POLYGON ((32.37500000014998 30.09166666628367...
# 2  (POLYGON ((32.5295365298621 29.95075831581867,...
# 3  (POLYGON ((32.46194054146073 29.89250514754305...
# 4  (POLYGON ((32.46194054146073 29.89250514754305...

# %%
gdf_merge = gdf_geom.merge(df_table,on="string_id",how="left")

# %%
gdf_merge.head()
# Out:
#    aq30_id  aqid     gid_1  pfaf_id             string_id          type  \
# 0        0  3365  EGY.11_1   111011  111011-EGY.11_1-3365       Polygon
# 1        1  3365  EGY.15_1   111011  111011-EGY.15_1-3365       Polygon
# 2        2 -9999  EGY.15_1   111011  111011-EGY.15_1-None  MultiPolygon
# 3        3  3365     -9999   111011      111011-None-3365  MultiPolygon
# 4        4 -9999     -9999   111011      111011-None-None  MultiPolygon
#
#                                             geometry     area_km2  bwd_cat  \
# 0  (POLYGON ((31.90590570688292 29.85788703615783...     4.223754      4.0
# 1  (POLYGON ((32.37500000014998 30.09166666628367...  1846.012343      4.0
# 2  (POLYGON ((32.5295365298621 29.95075831581867,...    30.526067      4.0
# 3  (POLYGON ((32.46194054146073 29.89250514754305...     0.742712      4.0
# 4  (POLYGON ((32.46194054146073 29.89250514754305...    13.430995      4.0
#
#                bwd_label              ...                w_awr_tex_rrr_cat  \
# 0  Extremely High (>75%)              ...                              2.0
# 1  Extremely High (>75%)              ...                              2.0
# 2  Extremely High (>75%)              ...                              2.0
# 3  Extremely High (>75%)              ...                              1.0
# 4  Extremely High (>75%)              ...                              1.0
#
#    w_awr_tex_rrr_label  w_awr_tex_rrr_raw w_awr_tex_rrr_score  \
# 0  Medium - High (2-3)           1.622678            2.165272
# 1  Medium - High (2-3)           1.622678            2.165272
# 2  Medium - High (2-3)           1.622678            2.165272
# 3   Low - Medium (1-2)           0.445356            1.133763
# 4   Low - Medium (1-2)           0.445356            1.133763
#
#    w_awr_tex_rrr_weight_fraction  w_awr_tex_tot_cat w_awr_tex_tot_label  \
# 0                       0.326531                3.0          High (3-4)
# 1                       0.326531                3.0          High (3-4)
# 2                       0.326531                3.0          High (3-4)
# 3                       0.163265                3.0          High (3-4)
# 4                       0.163265                3.0          High (3-4)
#
#    w_awr_tex_tot_raw w_awr_tex_tot_score  w_awr_tex_tot_weight_fraction
# 0           2.457171            3.614603                       0.877551
# 1           2.457171            3.614603                       0.877551
# 2           2.457171            3.614603                       0.877551
# 3           2.477321            3.649648                       0.551020
# 4           2.477321            3.649648                       0.551020
#
# [5 rows x 269 columns]

# %%
pd.set_option('display.max_rows', 500)

# %%
df_table.dtypes
# Out:
# area_km2                         float64
# bwd_cat                          float64
# bwd_label                         object
# bwd_raw                          float64
# bwd_score                        float64
# bws_cat                          float64
# bws_label                         object
# bws_raw                          float64
# bws_score                        float64
# cc_1                              object
# cep_cat                          float64
# cep_label                         object
# cep_raw                          float64
# cep_score                        float64
# cfr_cat                          float64
# cfr_label                         object
# cfr_raw                          float64
# cfr_score                        float64
# drr_cat                          float64
# drr_label                         object
# drr_raw                          float64
# drr_score                        float64
# engtype_1                         object
# gid_0                             object
# gtd_cat                          float64
# gtd_label                         object
# gtd_raw                          float64
# gtd_score                        float64
# hasc_1                            object
# iav_cat                          float64
# iav_label                         object
# iav_raw                          float64
# iav_score                        float64
# name_0                            object
# name_1                            object
# nl_name_1                         object
# rfr_cat                          float64
# rfr_label                         object
# rfr_raw                          float64
# rfr_score                        float64
# rri_cat                          float64
# rri_label                         object
# rri_raw                          float64
# rri_score                        float64
# sev_cat                          float64
# sev_label                         object
# sev_raw                          float64
# sev_score                        float64
# string_id                         object
# type_1                            object
# ucw_cat                          float64
# ucw_label                         object
# ucw_raw                          float64
# ucw_score                        float64
# udw_cat                          float64
# udw_label                         object
# udw_raw                          float64
# udw_score                        float64
# usa_cat                          float64
# usa_label                         object
# usa_raw                          float64
# usa_score                        float64
# varname_1                         object
# w_awr_agr_qal_cat                float64
# w_awr_agr_qal_label               object
# w_awr_agr_qal_raw                float64
# w_awr_agr_qal_score              float64
# w_awr_agr_qal_weight_fraction    float64
# w_awr_agr_qan_cat                float64
# w_awr_agr_qan_label               object
# w_awr_agr_qan_raw                float64
# w_awr_agr_qan_score              float64
# w_awr_agr_qan_weight_fraction    float64
# w_awr_agr_rrr_cat                float64
# w_awr_agr_rrr_label               object
# w_awr_agr_rrr_raw                float64
# w_awr_agr_rrr_score              float64
# w_awr_agr_rrr_weight_fraction    float64
# w_awr_agr_tot_cat                float64
# w_awr_agr_tot_label               object
# w_awr_agr_tot_raw                float64
# w_awr_agr_tot_score              float64
# w_awr_agr_tot_weight_fraction    float64
# w_awr_che_qal_cat                float64
# w_awr_che_qal_label               object
# w_awr_che_qal_raw                float64
# w_awr_che_qal_score              float64
# w_awr_che_qal_weight_fraction    float64
# w_awr_che_qan_cat                float64
# w_awr_che_qan_label               object
# w_awr_che_qan_raw                float64
# w_awr_che_qan_score              float64
# w_awr_che_qan_weight_fraction    float64
# w_awr_che_rrr_cat                float64
# w_awr_che_rrr_label               object
# w_awr_che_rrr_raw                float64
# w_awr_che_rrr_score              float64
# w_awr_che_rrr_weight_fraction    float64
# w_awr_che_tot_cat                float64
# w_awr_che_tot_label               object
# w_awr_che_tot_raw                float64
# w_awr_che_tot_score              float64
# w_awr_che_tot_weight_fraction    float64
# w_awr_con_qal_cat                float64
# w_awr_con_qal_label               object
# w_awr_con_qal_raw                float64
# w_awr_con_qal_score              float64
# w_awr_con_qal_weight_fraction    float64
# w_awr_con_qan_cat                float64
# w_awr_con_qan_label               object
# w_awr_con_qan_raw                float64
# w_awr_con_qan_score              float64
# w_awr_con_qan_weight_fraction    float64
# w_awr_con_rrr_cat                float64
# w_awr_con_rrr_label               object
# w_awr_con_rrr_raw                float64
# w_awr_con_rrr_score              float64
# w_awr_con_rrr_weight_fraction    float64
# w_awr_con_tot_cat                float64
# w_awr_con_tot_label               object
# w_awr_con_tot_raw                float64
# w_awr_con_tot_score              float64
# w_awr_con_tot_weight_fraction    float64
# w_awr_def_qal_cat                float64
# w_awr_def_qal_label               object
# w_awr_def_qal_raw                float64
# w_awr_def_qal_score              float64
# w_awr_def_qal_weight_fraction    float64
# w_awr_def_qan_cat                float64
# w_awr_def_qan_label               object
# w_awr_def_qan_raw                float64
# w_awr_def_qan_score              float64
# w_awr_def_qan_weight_fraction    float64
# w_awr_def_rrr_cat                float64
# w_awr_def_rrr_label               object
# w_awr_def_rrr_raw                float64
# w_awr_def_rrr_score              float64
# w_awr_def_rrr_weight_fraction    float64
# w_awr_def_tot_cat                float64
# w_awr_def_tot_label               object
# w_awr_def_tot_raw                float64
# w_awr_def_tot_score              float64
# w_awr_def_tot_weight_fraction    float64
# w_awr_elp_qal_cat                float64
# w_awr_elp_qal_label               object
# w_awr_elp_qal_raw                float64
# w_awr_elp_qal_score              float64
# w_awr_elp_qal_weight_fraction    float64
# w_awr_elp_qan_cat                float64
# w_awr_elp_qan_label               object
# w_awr_elp_qan_raw                float64
# w_awr_elp_qan_score              float64
# w_awr_elp_qan_weight_fraction    float64
# w_awr_elp_rrr_cat                float64
# w_awr_elp_rrr_label               object
# w_awr_elp_rrr_raw                float64
# w_awr_elp_rrr_score              float64
# w_awr_elp_rrr_weight_fraction    float64
# w_awr_elp_tot_cat                float64
# w_awr_elp_tot_label               object
# w_awr_elp_tot_raw                float64
# w_awr_elp_tot_score              float64
# w_awr_elp_tot_weight_fraction    float64
# w_awr_fnb_qal_cat                float64
# w_awr_fnb_qal_label               object
# w_awr_fnb_qal_raw                float64
# w_awr_fnb_qal_score              float64
# w_awr_fnb_qal_weight_fraction    float64
# w_awr_fnb_qan_cat                float64
# w_awr_fnb_qan_label               object
# w_awr_fnb_qan_raw                float64
# w_awr_fnb_qan_score              float64
# w_awr_fnb_qan_weight_fraction    float64
# w_awr_fnb_rrr_cat                float64
# w_awr_fnb_rrr_label               object
# w_awr_fnb_rrr_raw                float64
# w_awr_fnb_rrr_score              float64
# w_awr_fnb_rrr_weight_fraction    float64
# w_awr_fnb_tot_cat                float64
# w_awr_fnb_tot_label               object
# w_awr_fnb_tot_raw                float64
# w_awr_fnb_tot_score              float64
# w_awr_fnb_tot_weight_fraction    float64
# w_awr_min_qal_cat                float64
# w_awr_min_qal_label               object
# w_awr_min_qal_raw                float64
# w_awr_min_qal_score              float64
# w_awr_min_qal_weight_fraction    float64
# w_awr_min_qan_cat                float64
# w_awr_min_qan_label               object
# w_awr_min_qan_raw                float64
# w_awr_min_qan_score              float64
# w_awr_min_qan_weight_fraction    float64
# w_awr_min_rrr_cat                float64
# w_awr_min_rrr_label               object
# w_awr_min_rrr_raw                float64
# w_awr_min_rrr_score              float64
# w_awr_min_rrr_weight_fraction    float64
# w_awr_min_tot_cat                float64
# w_awr_min_tot_label               object
# w_awr_min_tot_raw                float64
# w_awr_min_tot_score              float64
# w_awr_min_tot_weight_fraction    float64
# w_awr_ong_qal_cat                float64
# w_awr_ong_qal_label               object
# w_awr_ong_qal_raw                float64
# w_awr_ong_qal_score              float64
# w_awr_ong_qal_weight_fraction    float64
# w_awr_ong_qan_cat                float64
# w_awr_ong_qan_label               object
# w_awr_ong_qan_raw                float64
# w_awr_ong_qan_score              float64
# w_awr_ong_qan_weight_fraction    float64
# w_awr_ong_rrr_cat                float64
# w_awr_ong_rrr_label               object
# w_awr_ong_rrr_raw                float64
# w_awr_ong_rrr_score              float64
# w_awr_ong_rrr_weight_fraction    float64
# w_awr_ong_tot_cat                float64
# w_awr_ong_tot_label               object
# w_awr_ong_tot_raw                float64
# w_awr_ong_tot_score              float64
# w_awr_ong_tot_weight_fraction    float64
# w_awr_smc_qal_cat                float64
# w_awr_smc_qal_label               object
# w_awr_smc_qal_raw                float64
# w_awr_smc_qal_score              float64
# w_awr_smc_qal_weight_fraction    float64
# w_awr_smc_qan_cat                float64
# w_awr_smc_qan_label               object
# w_awr_smc_qan_raw                float64
# w_awr_smc_qan_score              float64
# w_awr_smc_qan_weight_fraction    float64
# w_awr_smc_rrr_cat                float64
# w_awr_smc_rrr_label               object
# w_awr_smc_rrr_raw                float64
# w_awr_smc_rrr_score              float64
# w_awr_smc_rrr_weight_fraction    float64
# w_awr_smc_tot_cat                float64
# w_awr_smc_tot_label               object
# w_awr_smc_tot_raw                float64
# w_awr_smc_tot_score              float64
# w_awr_smc_tot_weight_fraction    float64
# w_awr_tex_qal_cat                float64
# w_awr_tex_qal_label               object
# w_awr_tex_qal_raw                float64
# w_awr_tex_qal_score              float64
# w_awr_tex_qal_weight_fraction    float64
# w_awr_tex_qan_cat                float64
# w_awr_tex_qan_label               object
# w_awr_tex_qan_raw                float64
# w_awr_tex_qan_score              float64
# w_awr_tex_qan_weight_fraction    float64
# w_awr_tex_rrr_cat                float64
# w_awr_tex_rrr_label               object
# w_awr_tex_rrr_raw                float64
# w_awr_tex_rrr_score              float64
# w_awr_tex_rrr_weight_fraction    float64
# w_awr_tex_tot_cat                float64
# w_awr_tex_tot_label               object
# w_awr_tex_tot_raw                float64
# w_awr_tex_tot_score              float64
# w_awr_tex_tot_weight_fraction    float64
# dtype: object

# %%
gdf_selection = gdf_merge[["string_id","w_awr_def_tot_score","w_awr_def_tot_weight_fraction","bws_score","iav_score","sev_score","geometry"]]

# %%
gdf_selection.rename(columns={"w_awr_def_tot_score":"owr_score",
                              "w_awr_def_tot_weight_fraction":"owr_wf"},inplace=True)
# Out:
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
process_path = "{}/{}.shp".format(ec2_process_path,SCRIPT_NAME)

# %%
if TESTING:
    gdf_selection =gdf_selection[0:1000]

# %%
gdf_selection.to_file(driver="ESRI Shapefile",filename=process_path)

# %%
indicators = ["owr_score","owr_wf","bws_score","iav_score","sev_score"]

# %%
for indicator in indicators:
    print(indicator)
    column = indicator
    layer = SCRIPT_NAME
    destination_path_shp = process_path
    destination_path_tif = "{}/{}.tif".format(ec2_output_path,indicator)
    command = "{} -a {} -at -ot Integer64 -of GTiff -te -180 -90 180 90 -ts {} {} -co COMPRESS=DEFLATE -co PREDICTOR=1 -co ZLEVEL=6 -l {} -a_nodata -9999 {} {}".format(GDAL_RASTERIZE_PATH,column,X_DIMENSION_30S,Y_DIMENSION_30S,layer,destination_path_shp,destination_path_tif)
    print(command)
    response = subprocess.check_output(command,shell=True)
# Out:
# owr_score
# /opt/anaconda3/envs/python35/bin/gdal_rasterize -a owr_score -at -ot Integer64 -of GTiff -te -180 -90 180 90 -ts 43200 21600 -co COMPRESS=DEFLATE -co PREDICTOR=1 -co ZLEVEL=6 -l Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01 -a_nodata -9999 /volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/process_V05/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01.shp /volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/output_V05/owr_score.tif
# owr_wf
# /opt/anaconda3/envs/python35/bin/gdal_rasterize -a owr_wf -at -ot Integer64 -of GTiff -te -180 -90 180 90 -ts 43200 21600 -co COMPRESS=DEFLATE -co PREDICTOR=1 -co ZLEVEL=6 -l Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01 -a_nodata -9999 /volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/process_V05/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01.shp /volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/output_V05/owr_wf.tif
# bws_score
# /opt/anaconda3/envs/python35/bin/gdal_rasterize -a bws_score -at -ot Integer64 -of GTiff -te -180 -90 180 90 -ts 43200 21600 -co COMPRESS=DEFLATE -co PREDICTOR=1 -co ZLEVEL=6 -l Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01 -a_nodata -9999 /volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/process_V05/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01.shp /volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/output_V05/bws_score.tif
# iav_score
# /opt/anaconda3/envs/python35/bin/gdal_rasterize -a iav_score -at -ot Integer64 -of GTiff -te -180 -90 180 90 -ts 43200 21600 -co COMPRESS=DEFLATE -co PREDICTOR=1 -co ZLEVEL=6 -l Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01 -a_nodata -9999 /volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/process_V05/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01.shp /volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/output_V05/iav_score.tif
# sev_score
# /opt/anaconda3/envs/python35/bin/gdal_rasterize -a sev_score -at -ot Integer64 -of GTiff -te -180 -90 180 90 -ts 43200 21600 -co COMPRESS=DEFLATE -co PREDICTOR=1 -co ZLEVEL=6 -l Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01 -a_nodata -9999 /volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/process_V05/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01.shp /volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/output_V05/sev_score.tif

# %%
# !gsutil -m cp -r {ec2_output_path} {GCS_OUTPUT_PATH}
# Out:
# Copying file:///volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/output_V05/iav_score.tif [Content-Type=image/tiff]...
# Copying file:///volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/output_V05/bws_score.tif [Content-Type=image/tiff]...
# Copying file:///volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/output_V05/sev_score.tif [Content-Type=image/tiff]...
# Copying file:///volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/output_V05/owr_score.tif [Content-Type=image/tiff]...
# Copying file:///volumes/data/Y2019M05D21_RH_AQ30VS21_Rasterize_AQ30_EE_V01/output_V05/owr_wf.tif [Content-Type=image/tiff]...
# \ [5/5 files][143.6 MiB/143.6 MiB] 100% Done
# Operation completed over 5 objects/143.6 MiB.

# %%
end = datetime.datetime.now()
elapsed = end - start
print(elapsed)
# Out:
# 0:20:34.079593
