# %% [markdown]
# ### Zonal Statistics using EE with PCRGlobWB data and hydroBasin level 6
#
# * Purpose of script: This script will perform a zonal statistics calculation using earth engine, PCRGlobWB data and Hydrobasin level 6 at 30s resolution.
# * Author: Rutger Hofste
# * Kernel used: python27
# * Date created: 20170911

# %%
import time
dateString = time.strftime("Y%YM%mD%d")
timeString = time.strftime("UTC %H:%M")
print(dateString,timeString)
# Out:
# ('Y2017M09D13', 'UTC 20:18')

# %%
import ee
import numpy as np
import subprocess
from retrying import retry
import itertools
import re
from pprint import *

# %%
ee.Initialize()

# %% [markdown]
# ## Settings

# %%
TESTING =1

EE_PATH = "projects/WRI-Aquaduct/PCRGlobWB20V07"

GCS_BUCKET= "aqueduct30_v01"
GCS_OUTPUT_PATH = "Y2017M09D11_RH_zonal_stats_EE_V01/"

HYBASLEVEL = 6

DIMENSION5MIN = "4320x2160"
DIMENSION30S = "43200x21600"
CRS = "EPSG:4326"

VERSION = 10

HYDROBASINS = "projects/WRI-Aquaduct/PCRGlobWB20V07/hybas_lev00_v1c_merged_fiona_30s_V01"

AREA5MIN = "projects/WRI-Aquaduct/PCRGlobWB20V07/area_5min_m2V11" 
AREA30S = "projects/WRI-Aquaduct/PCRGlobWB20V07/area_30s_m2V11"
ONES5MIN ="projects/WRI-Aquaduct/PCRGlobWB20V07/ones_5minV11"
ONES30S = "projects/WRI-Aquaduct/PCRGlobWB20V07/ones_30sV11"

# %%
reducers = ee.Reducer.mean().combine(reducer2= ee.Reducer.count(), sharedInputs= True)
weightedReducers = reducers.splitWeights()

# %%
geometry = ee.Geometry.Polygon(coords=[[-180.0, -90.0], [180,  -90.0], [180, 90], [-180,90]], proj= ee.Projection('EPSG:4326'),geodesic=False )
geometry = ee.Geometry.Polygon(coords=[[-10.0, -10.0], [10,  -10.0], [10, 10], [-10,10]], proj= ee.Projection('EPSG:4326'),geodesic=False )

# %% [markdown]
# ## Functions

# %%
def prepareZonalRaster(image):
    image    = ee.Image(image)
    newImage = ee.Image(image.divide(ee.Number(10).pow(ee.Number(12).subtract(HYBASLEVEL))).floor())
    newImage = newImage.copyProperties(image)
    newImage = ee.Image(newImage).toInt64().select(["b1"],["PfafID"])
    newImage = newImage.set({"exportdescription":"Hybas%0.2d" %(HYBASLEVEL)})     
    return newImage

def readAsset(assetId):
    # this function will read both images and imageCollections 
    if ee.data.getInfo(assetId)["type"] == "Image":
        asset = ee.Image(assetId)
        assetType = "image"
        newAsset = ee.Image(checkUnits(asset))

    elif ee.data.getInfo(assetId)["type"] == "ImageCollection":
        asset = ee.ImageCollection(assetId)
        assetType = "imageCollection"
        newAsset = ee.ImageCollection(asset.map(checkUnits))
        
    else:
        print("error")        
    return {"assetId":assetId,"asset":newAsset,"assetType":assetType}

def addSuffix(fc,suffix):
    namesOld = ee.Feature(fc.first()).toDictionary().keys()
    namesNew = namesOld.map(lambda x:ee.String(x).cat("_").cat(ee.String(suffix)))
    return fc.select(namesOld, namesNew)

def zonalStats(valueImage, weightImage, zonesImage):
    # ee export function is client side. getInfo required
    suffix = ee.Image(valueImage).get("exportdescription").getInfo() 
    scale = zonesImage.projection().nominalScale()
    totalImage = ee.Image(valueImage).addBands(ee.Image(weightImage)).addBands(ee.Image(zonesImage))
    resultsList = ee.List(totalImage.reduceRegion(
        geometry= geometry,
        reducer= weightedReducers.group(groupField= 2, groupName= "PfafID"),
        scale= scale,
        maxPixels= 1e10
        ).get("groups"))
    fc = ee.FeatureCollection(resultsList.map(lambda listItem: ee.Feature(None,listItem)))
    fc2 = addSuffix(fc, suffix)
    fc2 = fc2.copyProperties(valueImage)
    return fc2

def volumeToFlux(image):
    image = ee.Image(image)
    image = image.divide(ee.Image(AREA5MIN)).multiply(1e6).copyProperties(image)
    image = image.set("units","m")
    image = image.set("convertedToFlux", 1)
    return image

def checkUnits(image):
    # function is server side
    image = ee.Image(image)
    condition = ee.Algorithms.IsEqual(image.get("units"),ee.String("millionm3"))
    trueCase = volumeToFlux(image)
    falseCase = image
    outImage = ee.Algorithms.If(condition,trueCase,falseCase)
    return ee.Image(outImage)

def addWeightImage(d):
    dOut = d
    if d['PCRGlobWB'] == 1:
        dOut["weightAsset30s"] = ee.Image(AREA30s)
    else: 
        pprint(d)
        dOut["weightAsset30s"] = ee.Image(ONES30s)
    return dOut

        
#@retry(wait_exponential_multiplier=10000, wait_exponential_max=100000)
def export(fc):
    # Make sure your fc has an attribute called exportdescription.    
    # There is a bug in ee that adds ee_export.csv to your filename. Will remove in next steps
    fc = ee.FeatureCollection(fc)
    description = fc.get("exportdescription").getInfo() + "V%0.2d" %(VERSION)
    fileName = fc.get("exportdescription").getInfo() + "V%0.2d" %(VERSION)
    myExportFC = ee.batch.Export.table.toCloudStorage(collection=fc,
                                                    description= description,
                                                    bucket = GCS_BUCKET,
                                                    fileNamePrefix= GCS_OUTPUT_PATH  + fileName ,
                                                    fileFormat="CSV")
    myExportFC.start()

# %%
command = "earthengine ls %s" %(EE_PATH)

# %%
assetList = subprocess.check_output(command,shell=True).splitlines()

# %% [markdown]
# ## Script
#
# This script consists of several parts:
# 1. Auxiliary data
#     This includes area cell count, avarage cell size
# 1. Supply Data
#     zonal stats for long term average supply (1960-2014)
# 1. Demand Data
#     zonal stats for all combinations of Dom, Ind, Irr, IrrLinear, Liv and WW, WN

# %%
regexList = []

# %%
#auxList = ["zones","area_5min","area_30s","ones_5min","ones_30s"]
auxList = ["zones","area_30s","ones_30s"]

# %%
sectors = ["Dom","Ind","Irr","IrrLinear","Liv"]
parameters = ["WW","WN"]
temporalScales = ["year","month"]
runoffparameters = ["runoff","reducedmeanrunoff"]

# %%
if TESTING:
    sectors = ["Dom"]
    parameters = ["WW"]
    temporalScales = ["year"]
    runoffparameters = ["runoff","reducedmeanrunoff"]

# %%
demandList = []
for r in itertools.product(sectors,parameters, temporalScales): 
    regex = "%s%s_%s" %(r[0],r[1],r[2])
    demandList = demandList + [regex]

# %%
supplyList = []
for r in itertools.product(runoffparameters, temporalScales): 
    regex = "%s_%s" %(r[0],r[1])
    supplyList = supplyList + [regex]

# %%
regexList = regexList + auxList + demandList + supplyList

# %%
d = dict(zip(regexList,[{}]*len(regexList)))

# %%
for regex in regexList:
    # item is also the regular expression
    print(regex)
    if regex == "zones":
        d[regex] = readAsset(HYDROBASINS)
        d[regex]["asset"] = prepareZonalRaster(ee.Image(HYDROBASINS))
    else:
        for assetId in assetList:
            if re.search(regex,assetId):
                d[regex] = readAsset(assetId)
# Out:
# zones
# area_30s
# ones_30s
# DomWW_year
# runoff_year
# reducedmeanrunoff_year

# %%
zonesImage = d["zones"]["asset"]

# %%
for key, nestedDict in d.iteritems():
    if key in auxList:
        print(key," using ones instead of area as weights")
        weightsImage = ee.Image(ONES30S)
        
    else:
        print(key, " using area30s as weight")
        weightsImage = ee.Image(AREA30S)
        
    if nestedDict["assetType"] == "image":
        print("this is an image")
        fcOut = zonalStats(nestedDict["asset"],weightsImage,zonesImage)
        export(fcOut)
    elif nestedDict["assetType"] == "imageCollection":
        print("this is an imageCollection, filter for 2014")
# Out:
# ('runoff_year', ' using area30s as weight')
# this is an imageCollection
# ('DomWW_year', ' using area30s as weight')
# this is an imageCollection
# ('ones_30s', ' using ones instead of area as weights')
# this is an image
# ('zones', ' using ones instead of area as weights')
# this is an image
# ('area_30s', ' using ones instead of area as weights')
# this is an image
# ('reducedmeanrunoff_year', ' using area30s as weight')
# this is an imageCollection

# %%
pprint(fcOut.getInfo())
# Out:
# {u'columns': {},
#  u'features': [{u'geometry': None,
#                 u'id': u'0',
#                 u'properties': {u'PfafID_area_30s_m2': 133303,
#                                 u'count_area_30s_m2': 191,
#                                 u'mean_area_30s_m2': 853898.5258507853},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'1',
#                 u'properties': {u'PfafID_area_30s_m2': 133304,
#                                 u'count_area_30s_m2': 785,
#                                 u'mean_area_30s_m2': 854004.65},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'2',
#                 u'properties': {u'PfafID_area_30s_m2': 133305,
#                                 u'count_area_30s_m2': 588,
#                                 u'mean_area_30s_m2': 854132.9308035715},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'3',
#                 u'properties': {u'PfafID_area_30s_m2': 133306,
#                                 u'count_area_30s_m2': 3943,
#                                 u'mean_area_30s_m2': 854257.4027865839},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'4',
#                 u'properties': {u'PfafID_area_30s_m2': 133307,
#                                 u'count_area_30s_m2': 266,
#                                 u'mean_area_30s_m2': 854431.773731203},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'5',
#                 u'properties': {u'PfafID_area_30s_m2': 133308,
#                                 u'count_area_30s_m2': 7226,
#                                 u'mean_area_30s_m2': 854508.7380985331},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'6',
#                 u'properties': {u'PfafID_area_30s_m2': 133309,
#                                 u'count_area_30s_m2': 350,
#                                 u'mean_area_30s_m2': 854632.8382142857},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'7',
#                 u'properties': {u'PfafID_area_30s_m2': 133410,
#                                 u'count_area_30s_m2': 8648,
#                                 u'mean_area_30s_m2': 854693.420285037},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'8',
#                 u'properties': {u'PfafID_area_30s_m2': 133510,
#                                 u'count_area_30s_m2': 12937,
#                                 u'mean_area_30s_m2': 854764.7315983226},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'9',
#                 u'properties': {u'PfafID_area_30s_m2': 133520,
#                                 u'count_area_30s_m2': 2684,
#                                 u'mean_area_30s_m2': 854684.7191924367},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'10',
#                 u'properties': {u'PfafID_area_30s_m2': 133530,
#                                 u'count_area_30s_m2': 2284,
#                                 u'mean_area_30s_m2': 854590.0186077058},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'11',
#                 u'properties': {u'PfafID_area_30s_m2': 133540,
#                                 u'count_area_30s_m2': 1459,
#                                 u'mean_area_30s_m2': 854497.7499143248},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'12',
#                 u'properties': {u'PfafID_area_30s_m2': 133550,
#                                 u'count_area_30s_m2': 1762,
#                                 u'mean_area_30s_m2': 854340.8649971624},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'13',
#                 u'properties': {u'PfafID_area_30s_m2': 133561,
#                                 u'count_area_30s_m2': 739,
#                                 u'mean_area_30s_m2': 854134.4215155615},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'14',
#                 u'properties': {u'PfafID_area_30s_m2': 133570,
#                                 u'count_area_30s_m2': 1371,
#                                 u'mean_area_30s_m2': 853840.5288110868},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'15',
#                 u'properties': {u'PfafID_area_30s_m2': 133580,
#                                 u'count_area_30s_m2': 279,
#                                 u'mean_area_30s_m2': 853353.9551971327},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'16',
#                 u'properties': {u'PfafID_area_30s_m2': 133590,
#                                 u'count_area_30s_m2': 402,
#                                 u'mean_area_30s_m2': 853299.0309390547},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'17',
#                 u'properties': {u'PfafID_area_30s_m2': 133610,
#                                 u'count_area_30s_m2': 835,
#                                 u'mean_area_30s_m2': 853142.4848802395},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'18',
#                 u'properties': {u'PfafID_area_30s_m2': 133701,
#                                 u'count_area_30s_m2': 1281,
#                                 u'mean_area_30s_m2': 852987.0403981265},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'19',
#                 u'properties': {u'PfafID_area_30s_m2': 133702,
#                                 u'count_area_30s_m2': 827,
#                                 u'mean_area_30s_m2': 852735.6113966142},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'20',
#                 u'properties': {u'PfafID_area_30s_m2': 133703,
#                                 u'count_area_30s_m2': 213,
#                                 u'mean_area_30s_m2': 852774.4794600939},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'21',
#                 u'properties': {u'PfafID_area_30s_m2': 133704,
#                                 u'count_area_30s_m2': 5737,
#                                 u'mean_area_30s_m2': 852026.4722524838},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'22',
#                 u'properties': {u'PfafID_area_30s_m2': 133705,
#                                 u'count_area_30s_m2': 134,
#                                 u'mean_area_30s_m2': 852701.8745335821},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'23',
#                 u'properties': {u'PfafID_area_30s_m2': 133706,
#                                 u'count_area_30s_m2': 4945,
#                                 u'mean_area_30s_m2': 852037.1532103134},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'24',
#                 u'properties': {u'PfafID_area_30s_m2': 133707,
#                                 u'count_area_30s_m2': 9171,
#                                 u'mean_area_30s_m2': 852089.0806005343},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'25',
#                 u'properties': {u'PfafID_area_30s_m2': 133708,
#                                 u'count_area_30s_m2': 2867,
#                                 u'mean_area_30s_m2': 851406.7740887688},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'26',
#                 u'properties': {u'PfafID_area_30s_m2': 133709,
#                                 u'count_area_30s_m2': 4403,
#                                 u'mean_area_30s_m2': 851357.4187059959},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'27',
#                 u'properties': {u'PfafID_area_30s_m2': 133801,
#                                 u'count_area_30s_m2': 7080,
#                                 u'mean_area_30s_m2': 851071.9457627118},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'28',
#                 u'properties': {u'PfafID_area_30s_m2': 133802,
#                                 u'count_area_30s_m2': 8344,
#                                 u'mean_area_30s_m2': 849789.2590633988},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'29',
#                 u'properties': {u'PfafID_area_30s_m2': 133803,
#                                 u'count_area_30s_m2': 4258,
#                                 u'mean_area_30s_m2': 850014.9846905824},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'30',
#                 u'properties': {u'PfafID_area_30s_m2': 133804,
#                                 u'count_area_30s_m2': 19198,
#                                 u'mean_area_30s_m2': 848842.1000104178},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'31',
#                 u'properties': {u'PfafID_area_30s_m2': 133805,
#                                 u'count_area_30s_m2': 6155,
#                                 u'mean_area_30s_m2': 850343.0558387489},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'32',
#                 u'properties': {u'PfafID_area_30s_m2': 133806,
#                                 u'count_area_30s_m2': 3906,
#                                 u'mean_area_30s_m2': 851081.6358966974},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'33',
#                 u'properties': {u'PfafID_area_30s_m2': 133807,
#                                 u'count_area_30s_m2': 8097,
#                                 u'mean_area_30s_m2': 850240.2136362233},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'34',
#                 u'properties': {u'PfafID_area_30s_m2': 133808,
#                                 u'count_area_30s_m2': 2624,
#                                 u'mean_area_30s_m2': 850929.984017721},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'35',
#                 u'properties': {u'PfafID_area_30s_m2': 133809,
#                                 u'count_area_30s_m2': 1785,
#                                 u'mean_area_30s_m2': 851233.1717086835},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'36',
#                 u'properties': {u'PfafID_area_30s_m2': 133900,
#                                 u'count_area_30s_m2': 310,
#                                 u'mean_area_30s_m2': 851999.2576612904},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'37',
#                 u'properties': {u'PfafID_area_30s_m2': 134000,
#                                 u'count_area_30s_m2': 3645,
#                                 u'mean_area_30s_m2': 853770.2949931413},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'38',
#                 u'properties': {u'PfafID_area_30s_m2': 141000,
#                                 u'count_area_30s_m2': 31381,
#                                 u'mean_area_30s_m2': 851541.3110580447},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'39',
#                 u'properties': {u'PfafID_area_30s_m2': 142100,
#                                 u'count_area_30s_m2': 34574,
#                                 u'mean_area_30s_m2': 848882.8937677157},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'40',
#                 u'properties': {u'PfafID_area_30s_m2': 142211,
#                                 u'count_area_30s_m2': 4430,
#                                 u'mean_area_30s_m2': 846917.5448081264},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'41',
#                 u'properties': {u'PfafID_area_30s_m2': 142212,
#                                 u'count_area_30s_m2': 12438,
#                                 u'mean_area_30s_m2': 845111.7272069465},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'42',
#                 u'properties': {u'PfafID_area_30s_m2': 142213,
#                                 u'count_area_30s_m2': 4061,
#                                 u'mean_area_30s_m2': 846793.107178035},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'43',
#                 u'properties': {u'PfafID_area_30s_m2': 142214,
#                                 u'count_area_30s_m2': 11004,
#                                 u'mean_area_30s_m2': 844735.2066805252},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'44',
#                 u'properties': {u'PfafID_area_30s_m2': 142215,
#                                 u'count_area_30s_m2': 4002,
#                                 u'mean_area_30s_m2': 847095.3305222389},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'45',
#                 u'properties': {u'PfafID_area_30s_m2': 142216,
#                                 u'count_area_30s_m2': 2897,
#                                 u'mean_area_30s_m2': 847688.0982050397},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'46',
#                 u'properties': {u'PfafID_area_30s_m2': 142217,
#                                 u'count_area_30s_m2': 3536,
#                                 u'mean_area_30s_m2': 847345.0223239536},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'47',
#                 u'properties': {u'PfafID_area_30s_m2': 142218,
#                                 u'count_area_30s_m2': 2625,
#                                 u'mean_area_30s_m2': 846404.6582142857},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'48',
#                 u'properties': {u'PfafID_area_30s_m2': 142219,
#                                 u'count_area_30s_m2': 286,
#                                 u'mean_area_30s_m2': 847239.1822552447},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'49',
#                 u'properties': {u'PfafID_area_30s_m2': 142220,
#                                 u'count_area_30s_m2': 17718,
#                                 u'mean_area_30s_m2': 848614.9573068349},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'50',
#                 u'properties': {u'PfafID_area_30s_m2': 142230,
#                                 u'count_area_30s_m2': 28453,
#                                 u'mean_area_30s_m2': 845545.9854804415},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'51',
#                 u'properties': {u'PfafID_area_30s_m2': 142240,
#                                 u'count_area_30s_m2': 2067,
#                                 u'mean_area_30s_m2': 847344.7807813255},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'52',
#                 u'properties': {u'PfafID_area_30s_m2': 142250,
#                                 u'count_area_30s_m2': 4834,
#                                 u'mean_area_30s_m2': 843971.7405099297},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'53',
#                 u'properties': {u'PfafID_area_30s_m2': 142272,
#                                 u'count_area_30s_m2': 49,
#                                 u'mean_area_30s_m2': 844390.3545918367},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'54',
#                 u'properties': {u'PfafID_area_30s_m2': 142274,
#                                 u'count_area_30s_m2': 3,
#                                 u'mean_area_30s_m2': 843109.7291666666},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'55',
#                 u'properties': {u'PfafID_area_30s_m2': 142297,
#                                 u'count_area_30s_m2': 134,
#                                 u'mean_area_30s_m2': 842275.8031716418},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'56',
#                 u'properties': {u'PfafID_area_30s_m2': 142298,
#                                 u'count_area_30s_m2': 4303,
#                                 u'mean_area_30s_m2': 843097.0259702533},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'57',
#                 u'properties': {u'PfafID_area_30s_m2': 142299,
#                                 u'count_area_30s_m2': 3714,
#                                 u'mean_area_30s_m2': 842598.3096223748},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'58',
#                 u'properties': {u'PfafID_area_30s_m2': 142310,
#                                 u'count_area_30s_m2': 3102,
#                                 u'mean_area_30s_m2': 846710.6598162475},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'59',
#                 u'properties': {u'PfafID_area_30s_m2': 142320,
#                                 u'count_area_30s_m2': 17909,
#                                 u'mean_area_30s_m2': 844261.1371552013},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'60',
#                 u'properties': {u'PfafID_area_30s_m2': 142330,
#                                 u'count_area_30s_m2': 24533,
#                                 u'mean_area_30s_m2': 845149.6603962011},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'61',
#                 u'properties': {u'PfafID_area_30s_m2': 142341,
#                                 u'count_area_30s_m2': 6485,
#                                 u'mean_area_30s_m2': 843530.9742579028},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'62',
#                 u'properties': {u'PfafID_area_30s_m2': 142342,
#                                 u'count_area_30s_m2': 2134,
#                                 u'mean_area_30s_m2': 842514.2005037488},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'63',
#                 u'properties': {u'PfafID_area_30s_m2': 142343,
#                                 u'count_area_30s_m2': 3288,
#                                 u'mean_area_30s_m2': 842612.7077630778},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'64',
#                 u'properties': {u'PfafID_area_30s_m2': 142344,
#                                 u'count_area_30s_m2': 21,
#                                 u'mean_area_30s_m2': 842187.875},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'65',
#                 u'properties': {u'PfafID_area_30s_m2': 142345,
#                                 u'count_area_30s_m2': 5230,
#                                 u'mean_area_30s_m2': 842566.4728847992},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'66',
#                 u'properties': {u'PfafID_area_30s_m2': 142348,
#                                 u'count_area_30s_m2': 3014,
#                                 u'mean_area_30s_m2': 842566.0418671201},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'67',
#                 u'properties': {u'PfafID_area_30s_m2': 142350,
#                                 u'count_area_30s_m2': 30632,
#                                 u'mean_area_30s_m2': 844923.505229417},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'68',
#                 u'properties': {u'PfafID_area_30s_m2': 142360,
#                                 u'count_area_30s_m2': 11902,
#                                 u'mean_area_30s_m2': 844090.2449220719},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'69',
#                 u'properties': {u'PfafID_area_30s_m2': 142370,
#                                 u'count_area_30s_m2': 2648,
#                                 u'mean_area_30s_m2': 843185.7352955061},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'70',
#                 u'properties': {u'PfafID_area_30s_m2': 142380,
#                                 u'count_area_30s_m2': 8905,
#                                 u'mean_area_30s_m2': 842719.030453397},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'71',
#                 u'properties': {u'PfafID_area_30s_m2': 142391,
#                                 u'count_area_30s_m2': 18,
#                                 u'mean_area_30s_m2': 842631.8368055555},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'72',
#                 u'properties': {u'PfafID_area_30s_m2': 142392,
#                                 u'count_area_30s_m2': 1647,
#                                 u'mean_area_30s_m2': 842354.1341833636},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'73',
#                 u'properties': {u'PfafID_area_30s_m2': 142393,
#                                 u'count_area_30s_m2': 554,
#                                 u'mean_area_30s_m2': 842299.3218637184},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'74',
#                 u'properties': {u'PfafID_area_30s_m2': 142560,
#                                 u'count_area_30s_m2': 176,
#                                 u'mean_area_30s_m2': 842222.7514204546},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'75',
#                 u'properties': {u'PfafID_area_30s_m2': 142886,
#                                 u'count_area_30s_m2': 1892,
#                                 u'mean_area_30s_m2': 842428.9135174418},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'76',
#                 u'properties': {u'PfafID_area_30s_m2': 142889,
#                                 u'count_area_30s_m2': 6218,
#                                 u'mean_area_30s_m2': 843050.5599368768},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'77',
#                 u'properties': {u'PfafID_area_30s_m2': 142896,
#                                 u'count_area_30s_m2': 23,
#                                 u'mean_area_30s_m2': 842167.2663043478},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'78',
#                 u'properties': {u'PfafID_area_30s_m2': 142897,
#                                 u'count_area_30s_m2': 242,
#                                 u'mean_area_30s_m2': 842298.5614669422},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'79',
#                 u'properties': {u'PfafID_area_30s_m2': 142898,
#                                 u'count_area_30s_m2': 1544,
#                                 u'mean_area_30s_m2': 842611.3796146373},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'80',
#                 u'properties': {u'PfafID_area_30s_m2': 142899,
#                                 u'count_area_30s_m2': 2905,
#                                 u'mean_area_30s_m2': 842954.6741179002},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'81',
#                 u'properties': {u'PfafID_area_30s_m2': 142964,
#                                 u'count_area_30s_m2': 8449,
#                                 u'mean_area_30s_m2': 843798.3943440052},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'82',
#                 u'properties': {u'PfafID_area_30s_m2': 142965,
#                                 u'count_area_30s_m2': 609,
#                                 u'mean_area_30s_m2': 842596.9859400657},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'83',
#                 u'properties': {u'PfafID_area_30s_m2': 142966,
#                                 u'count_area_30s_m2': 2467,
#                                 u'mean_area_30s_m2': 843203.1011349817},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'84',
#                 u'properties': {u'PfafID_area_30s_m2': 142967,
#                                 u'count_area_30s_m2': 877,
#                                 u'mean_area_30s_m2': 842357.8695125427},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'85',
#                 u'properties': {u'PfafID_area_30s_m2': 142968,
#                                 u'count_area_30s_m2': 4314,
#                                 u'mean_area_30s_m2': 843780.5342634446},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'86',
#                 u'properties': {u'PfafID_area_30s_m2': 142969,
#                                 u'count_area_30s_m2': 3129,
#                                 u'mean_area_30s_m2': 843515.2329817833},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'87',
#                 u'properties': {u'PfafID_area_30s_m2': 142982,
#                                 u'count_area_30s_m2': 9348,
#                                 u'mean_area_30s_m2': 843657.0837812901},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'88',
#                 u'properties': {u'PfafID_area_30s_m2': 142984,
#                                 u'count_area_30s_m2': 7501,
#                                 u'mean_area_30s_m2': 843403.0176059859},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'89',
#                 u'properties': {u'PfafID_area_30s_m2': 143010,
#                                 u'count_area_30s_m2': 29955,
#                                 u'mean_area_30s_m2': 850694.8730449842},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'90',
#                 u'properties': {u'PfafID_area_30s_m2': 143020,
#                                 u'count_area_30s_m2': 16552,
#                                 u'mean_area_30s_m2': 848305.8312477344},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'91',
#                 u'properties': {u'PfafID_area_30s_m2': 143030,
#                                 u'count_area_30s_m2': 12842,
#                                 u'mean_area_30s_m2': 849104.6209507865},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'92',
#                 u'properties': {u'PfafID_area_30s_m2': 143041,
#                                 u'count_area_30s_m2': 823,
#                                 u'mean_area_30s_m2': 849454.5408566222},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'93',
#                 u'properties': {u'PfafID_area_30s_m2': 143042,
#                                 u'count_area_30s_m2': 26062,
#                                 u'mean_area_30s_m2': 846780.4679538216},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'94',
#                 u'properties': {u'PfafID_area_30s_m2': 143043,
#                                 u'count_area_30s_m2': 1670,
#                                 u'mean_area_30s_m2': 849121.1697979042},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'95',
#                 u'properties': {u'PfafID_area_30s_m2': 143044,
#                                 u'count_area_30s_m2': 5133,
#                                 u'mean_area_30s_m2': 848352.677576466},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'96',
#                 u'properties': {u'PfafID_area_30s_m2': 143045,
#                                 u'count_area_30s_m2': 681,
#                                 u'mean_area_30s_m2': 849138.1283957416},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'97',
#                 u'properties': {u'PfafID_area_30s_m2': 143046,
#                                 u'count_area_30s_m2': 10900,
#                                 u'mean_area_30s_m2': 848588.8238704129},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'98',
#                 u'properties': {u'PfafID_area_30s_m2': 143047,
#                                 u'count_area_30s_m2': 3148,
#                                 u'mean_area_30s_m2': 848420.4118686467},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'99',
#                 u'properties': {u'PfafID_area_30s_m2': 143048,
#                                 u'count_area_30s_m2': 2985,
#                                 u'mean_area_30s_m2': 846821.8613065326},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'100',
#                 u'properties': {u'PfafID_area_30s_m2': 143049,
#                                 u'count_area_30s_m2': 5455,
#                                 u'mean_area_30s_m2': 846997.7065077911},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'101',
#                 u'properties': {u'PfafID_area_30s_m2': 143050,
#                                 u'count_area_30s_m2': 258,
#                                 u'mean_area_30s_m2': 849595.3512596899},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'102',
#                 u'properties': {u'PfafID_area_30s_m2': 143061,
#                                 u'count_area_30s_m2': 4208,
#                                 u'mean_area_30s_m2': 849038.8782675855},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'103',
#                 u'properties': {u'PfafID_area_30s_m2': 143062,
#                                 u'count_area_30s_m2': 8606,
#                                 u'mean_area_30s_m2': 848749.0239295259},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'104',
#                 u'properties': {u'PfafID_area_30s_m2': 143063,
#                                 u'count_area_30s_m2': 1502,
#                                 u'mean_area_30s_m2': 848833.7126331558},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'105',
#                 u'properties': {u'PfafID_area_30s_m2': 143064,
#                                 u'count_area_30s_m2': 9942,
#                                 u'mean_area_30s_m2': 846992.3995297727},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'106',
#                 u'properties': {u'PfafID_area_30s_m2': 143065,
#                                 u'count_area_30s_m2': 3120,
#                                 u'mean_area_30s_m2': 847775.3985977564},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'107',
#                 u'properties': {u'PfafID_area_30s_m2': 143066,
#                                 u'count_area_30s_m2': 13584,
#                                 u'mean_area_30s_m2': 844617.1221933893},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'108',
#                 u'properties': {u'PfafID_area_30s_m2': 143067,
#                                 u'count_area_30s_m2': 12585,
#                                 u'mean_area_30s_m2': 845579.398723679},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'109',
#                 u'properties': {u'PfafID_area_30s_m2': 143068,
#                                 u'count_area_30s_m2': 3982,
#                                 u'mean_area_30s_m2': 843918.8411445253},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'110',
#                 u'properties': {u'PfafID_area_30s_m2': 143069,
#                                 u'count_area_30s_m2': 11222,
#                                 u'mean_area_30s_m2': 843066.0457082071},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'111',
#                 u'properties': {u'PfafID_area_30s_m2': 143070,
#                                 u'count_area_30s_m2': 4678,
#                                 u'mean_area_30s_m2': 848622.6443057931},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'112',
#                 u'properties': {u'PfafID_area_30s_m2': 143080,
#                                 u'count_area_30s_m2': 28328,
#                                 u'mean_area_30s_m2': 846829.1761044726},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'113',
#                 u'properties': {u'PfafID_area_30s_m2': 143090,
#                                 u'count_area_30s_m2': 11372,
#                                 u'mean_area_30s_m2': 849343.536020489},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'114',
#                 u'properties': {u'PfafID_area_30s_m2': 144101,
#                                 u'count_area_30s_m2': 152,
#                                 u'mean_area_30s_m2': 850437.6167763158},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'115',
#                 u'properties': {u'PfafID_area_30s_m2': 144102,
#                                 u'count_area_30s_m2': 3876,
#                                 u'mean_area_30s_m2': 849448.4362100103},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'116',
#                 u'properties': {u'PfafID_area_30s_m2': 144103,
#                                 u'count_area_30s_m2': 5896,
#                                 u'mean_area_30s_m2': 849840.3887911296},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'117',
#                 u'properties': {u'PfafID_area_30s_m2': 144104,
#                                 u'count_area_30s_m2': 14606,
#                                 u'mean_area_30s_m2': 848884.3163982268},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'118',
#                 u'properties': {u'PfafID_area_30s_m2': 144105,
#                                 u'count_area_30s_m2': 5367,
#                                 u'mean_area_30s_m2': 848687.1471958264},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'119',
#                 u'properties': {u'PfafID_area_30s_m2': 144106,
#                                 u'count_area_30s_m2': 3574,
#                                 u'mean_area_30s_m2': 848251.2863738108},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'120',
#                 u'properties': {u'PfafID_area_30s_m2': 144107,
#                                 u'count_area_30s_m2': 1343,
#                                 u'mean_area_30s_m2': 847959.875232688},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'121',
#                 u'properties': {u'PfafID_area_30s_m2': 144108,
#                                 u'count_area_30s_m2': 5240,
#                                 u'mean_area_30s_m2': 847197.3452647901},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'122',
#                 u'properties': {u'PfafID_area_30s_m2': 144109,
#                                 u'count_area_30s_m2': 2019,
#                                 u'mean_area_30s_m2': 847753.434032937},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'123',
#                 u'properties': {u'PfafID_area_30s_m2': 144201,
#                                 u'count_area_30s_m2': 24875,
#                                 u'mean_area_30s_m2': 844653.6853316583},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'124',
#                 u'properties': {u'PfafID_area_30s_m2': 144202,
#                                 u'count_area_30s_m2': 6821,
#                                 u'mean_area_30s_m2': 843052.5455853248},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'125',
#                 u'properties': {u'PfafID_area_30s_m2': 144204,
#                                 u'count_area_30s_m2': 2146,
#                                 u'mean_area_30s_m2': 842474.8249650513},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'126',
#                 u'properties': {u'PfafID_area_30s_m2': 144301,
#                                 u'count_area_30s_m2': 500,
#                                 u'mean_area_30s_m2': 847332.5625},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'127',
#                 u'properties': {u'PfafID_area_30s_m2': 144302,
#                                 u'count_area_30s_m2': 5935,
#                                 u'mean_area_30s_m2': 847612.5056339512},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'128',
#                 u'properties': {u'PfafID_area_30s_m2': 144303,
#                                 u'count_area_30s_m2': 3469,
#                                 u'mean_area_30s_m2': 846791.7688995388},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'129',
#                 u'properties': {u'PfafID_area_30s_m2': 144304,
#                                 u'count_area_30s_m2': 10187,
#                                 u'mean_area_30s_m2': 844768.9267264651},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'130',
#                 u'properties': {u'PfafID_area_30s_m2': 144305,
#                                 u'count_area_30s_m2': 40,
#                                 u'mean_area_30s_m2': 846396.76875},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'131',
#                 u'properties': {u'PfafID_area_30s_m2': 144306,
#                                 u'count_area_30s_m2': 10507,
#                                 u'mean_area_30s_m2': 847147.1148876939},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'132',
#                 u'properties': {u'PfafID_area_30s_m2': 144307,
#                                 u'count_area_30s_m2': 3544,
#                                 u'mean_area_30s_m2': 845982.8324456828},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'133',
#                 u'properties': {u'PfafID_area_30s_m2': 144308,
#                                 u'count_area_30s_m2': 7127,
#                                 u'mean_area_30s_m2': 844250.5364108321},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'134',
#                 u'properties': {u'PfafID_area_30s_m2': 144309,
#                                 u'count_area_30s_m2': 552,
#                                 u'mean_area_30s_m2': 845451.9273097826},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'135',
#                 u'properties': {u'PfafID_area_30s_m2': 144410,
#                                 u'count_area_30s_m2': 5354,
#                                 u'mean_area_30s_m2': 844296.8275821815},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'136',
#                 u'properties': {u'PfafID_area_30s_m2': 144420,
#                                 u'count_area_30s_m2': 7075,
#                                 u'mean_area_30s_m2': 843373.6021378092},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'137',
#                 u'properties': {u'PfafID_area_30s_m2': 144430,
#                                 u'count_area_30s_m2': 9593,
#                                 u'mean_area_30s_m2': 842825.9028784009},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'138',
#                 u'properties': {u'PfafID_area_30s_m2': 144440,
#                                 u'count_area_30s_m2': 675,
#                                 u'mean_area_30s_m2': 842253.2036111112},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'139',
#                 u'properties': {u'PfafID_area_30s_m2': 144450,
#                                 u'count_area_30s_m2': 122,
#                                 u'mean_area_30s_m2': 842240.8084016393},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'140',
#                 u'properties': {u'PfafID_area_30s_m2': 144460,
#                                 u'count_area_30s_m2': 1765,
#                                 u'mean_area_30s_m2': 842426.2719546743},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'141',
#                 u'properties': {u'PfafID_area_30s_m2': 144501,
#                                 u'count_area_30s_m2': 4590,
#                                 u'mean_area_30s_m2': 845885.6670343138},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'142',
#                 u'properties': {u'PfafID_area_30s_m2': 144502,
#                                 u'count_area_30s_m2': 3571,
#                                 u'mean_area_30s_m2': 844498.7269147298},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'143',
#                 u'properties': {u'PfafID_area_30s_m2': 144503,
#                                 u'count_area_30s_m2': 9637,
#                                 u'mean_area_30s_m2': 845697.1654690256},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'144',
#                 u'properties': {u'PfafID_area_30s_m2': 144504,
#                                 u'count_area_30s_m2': 8494,
#                                 u'mean_area_30s_m2': 847060.1226233223},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'145',
#                 u'properties': {u'PfafID_area_30s_m2': 144505,
#                                 u'count_area_30s_m2': 2323,
#                                 u'mean_area_30s_m2': 845946.4597503229},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'146',
#                 u'properties': {u'PfafID_area_30s_m2': 144506,
#                                 u'count_area_30s_m2': 3558,
#                                 u'mean_area_30s_m2': 845698.5505726532},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'147',
#                 u'properties': {u'PfafID_area_30s_m2': 144507,
#                                 u'count_area_30s_m2': 17713,
#                                 u'mean_area_30s_m2': 843899.5348049455},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'148',
#                 u'properties': {u'PfafID_area_30s_m2': 144508,
#                                 u'count_area_30s_m2': 2265,
#                                 u'mean_area_30s_m2': 842481.1828642384},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'149',
#                 u'properties': {u'PfafID_area_30s_m2': 145101,
#                                 u'count_area_30s_m2': 2872,
#                                 u'mean_area_30s_m2': 850555.7244951254},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'150',
#                 u'properties': {u'PfafID_area_30s_m2': 145102,
#                                 u'count_area_30s_m2': 3072,
#                                 u'mean_area_30s_m2': 850365.6821695963},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'151',
#                 u'properties': {u'PfafID_area_30s_m2': 145103,
#                                 u'count_area_30s_m2': 8005,
#                                 u'mean_area_30s_m2': 850970.256948782},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'152',
#                 u'properties': {u'PfafID_area_30s_m2': 145104,
#                                 u'count_area_30s_m2': 27298,
#                                 u'mean_area_30s_m2': 849837.9978432485},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'153',
#                 u'properties': {u'PfafID_area_30s_m2': 145105,
#                                 u'count_area_30s_m2': 1799,
#                                 u'mean_area_30s_m2': 851704.0893551974},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'154',
#                 u'properties': {u'PfafID_area_30s_m2': 145106,
#                                 u'count_area_30s_m2': 9915,
#                                 u'mean_area_30s_m2': 850829.9041792739},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'155',
#                 u'properties': {u'PfafID_area_30s_m2': 145107,
#                                 u'count_area_30s_m2': 1250,
#                                 u'mean_area_30s_m2': 851544.9388},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'156',
#                 u'properties': {u'PfafID_area_30s_m2': 145108,
#                                 u'count_area_30s_m2': 33003,
#                                 u'mean_area_30s_m2': 849760.9724475805},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'157',
#                 u'properties': {u'PfafID_area_30s_m2': 145109,
#                                 u'count_area_30s_m2': 376,
#                                 u'mean_area_30s_m2': 851359.0317486703},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'158',
#                 u'properties': {u'PfafID_area_30s_m2': 145201,
#                                 u'count_area_30s_m2': 21095,
#                                 u'mean_area_30s_m2': 849668.5032709172},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'159',
#                 u'properties': {u'PfafID_area_30s_m2': 145202,
#                                 u'count_area_30s_m2': 8893,
#                                 u'mean_area_30s_m2': 847602.1951956595},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'160',
#                 u'properties': {u'PfafID_area_30s_m2': 145203,
#                                 u'count_area_30s_m2': 291,
#                                 u'mean_area_30s_m2': 847829.094072165},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'161',
#                 u'properties': {u'PfafID_area_30s_m2': 145204,
#                                 u'count_area_30s_m2': 5967,
#                                 u'mean_area_30s_m2': 846558.6166938997},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'162',
#                 u'properties': {u'PfafID_area_30s_m2': 145205,
#                                 u'count_area_30s_m2': 16401,
#                                 u'mean_area_30s_m2': 845919.145928602},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'163',
#                 u'properties': {u'PfafID_area_30s_m2': 145206,
#                                 u'count_area_30s_m2': 6577,
#                                 u'mean_area_30s_m2': 843595.1944085449},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'164',
#                 u'properties': {u'PfafID_area_30s_m2': 145207,
#                                 u'count_area_30s_m2': 13817,
#                                 u'mean_area_30s_m2': 843618.1705191069},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'165',
#                 u'properties': {u'PfafID_area_30s_m2': 145208,
#                                 u'count_area_30s_m2': 889,
#                                 u'mean_area_30s_m2': 842404.7488048369},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'166',
#                 u'properties': {u'PfafID_area_30s_m2': 145209,
#                                 u'count_area_30s_m2': 3465,
#                                 u'mean_area_30s_m2': 842839.093416306},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'167',
#                 u'properties': {u'PfafID_area_30s_m2': 145300,
#                                 u'count_area_30s_m2': 13153,
#                                 u'mean_area_30s_m2': 850360.6417404774},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'168',
#                 u'properties': {u'PfafID_area_30s_m2': 145401,
#                                 u'count_area_30s_m2': 3637,
#                                 u'mean_area_30s_m2': 850766.4414008799},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'169',
#                 u'properties': {u'PfafID_area_30s_m2': 145402,
#                                 u'count_area_30s_m2': 41700,
#                                 u'mean_area_30s_m2': 847494.3134577338},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'170',
#                 u'properties': {u'PfafID_area_30s_m2': 145403,
#                                 u'count_area_30s_m2': 1989,
#                                 u'mean_area_30s_m2': 849966.948497989},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'171',
#                 u'properties': {u'PfafID_area_30s_m2': 145404,
#                                 u'count_area_30s_m2': 2730,
#                                 u'mean_area_30s_m2': 849435.6007554946},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'172',
#                 u'properties': {u'PfafID_area_30s_m2': 145405,
#                                 u'count_area_30s_m2': 2379,
#                                 u'mean_area_30s_m2': 849098.0054119378},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'173',
#                 u'properties': {u'PfafID_area_30s_m2': 145406,
#                                 u'count_area_30s_m2': 25451,
#                                 u'mean_area_30s_m2': 846293.58341519},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'174',
#                 u'properties': {u'PfafID_area_30s_m2': 145407,
#                                 u'count_area_30s_m2': 14897,
#                                 u'mean_area_30s_m2': 846963.3868354367},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'175',
#                 u'properties': {u'PfafID_area_30s_m2': 145408,
#                                 u'count_area_30s_m2': 6112,
#                                 u'mean_area_30s_m2': 844559.1309105039},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'176',
#                 u'properties': {u'PfafID_area_30s_m2': 145409,
#                                 u'count_area_30s_m2': 16166,
#                                 u'mean_area_30s_m2': 843487.4589029445},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'177',
#                 u'properties': {u'PfafID_area_30s_m2': 145500,
#                                 u'count_area_30s_m2': 14736,
#                                 u'mean_area_30s_m2': 850808.4010416666},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'178',
#                 u'properties': {u'PfafID_area_30s_m2': 145601,
#                                 u'count_area_30s_m2': 15801,
#                                 u'mean_area_30s_m2': 850416.4430138916},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'179',
#                 u'properties': {u'PfafID_area_30s_m2': 145602,
#                                 u'count_area_30s_m2': 14987,
#                                 u'mean_area_30s_m2': 848630.6047074131},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'180',
#                 u'properties': {u'PfafID_area_30s_m2': 145603,
#                                 u'count_area_30s_m2': 1646,
#                                 u'mean_area_30s_m2': 849973.7545185297},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'181',
#                 u'properties': {u'PfafID_area_30s_m2': 145604,
#                                 u'count_area_30s_m2': 9840,
#                                 u'mean_area_30s_m2': 848611.83984375},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'182',
#                 u'properties': {u'PfafID_area_30s_m2': 145605,
#                                 u'count_area_30s_m2': 11262,
#                                 u'mean_area_30s_m2': 848301.4253684959},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'183',
#                 u'properties': {u'PfafID_area_30s_m2': 145606,
#                                 u'count_area_30s_m2': 10433,
#                                 u'mean_area_30s_m2': 846674.641282469},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'184',
#                 u'properties': {u'PfafID_area_30s_m2': 145607,
#                                 u'count_area_30s_m2': 4614,
#                                 u'mean_area_30s_m2': 846281.885904313},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'185',
#                 u'properties': {u'PfafID_area_30s_m2': 145608,
#                                 u'count_area_30s_m2': 11820,
#                                 u'mean_area_30s_m2': 844529.3160480119},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'186',
#                 u'properties': {u'PfafID_area_30s_m2': 145609,
#                                 u'count_area_30s_m2': 8075,
#                                 u'mean_area_30s_m2': 845618.0254721362},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'187',
#                 u'properties': {u'PfafID_area_30s_m2': 145710,
#                                 u'count_area_30s_m2': 10130,
#                                 u'mean_area_30s_m2': 851670.4168435341},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'188',
#                 u'properties': {u'PfafID_area_30s_m2': 145720,
#                                 u'count_area_30s_m2': 34669,
#                                 u'mean_area_30s_m2': 850257.2540580202},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'189',
#                 u'properties': {u'PfafID_area_30s_m2': 145731,
#                                 u'count_area_30s_m2': 14788,
#                                 u'mean_area_30s_m2': 851554.59459528},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'190',
#                 u'properties': {u'PfafID_area_30s_m2': 145732,
#                                 u'count_area_30s_m2': 6629,
#                                 u'mean_area_30s_m2': 850726.65883806},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'191',
#                 u'properties': {u'PfafID_area_30s_m2': 145733,
#                                 u'count_area_30s_m2': 632,
#                                 u'mean_area_30s_m2': 851111.3528481013},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'192',
#                 u'properties': {u'PfafID_area_30s_m2': 145734,
#                                 u'count_area_30s_m2': 15003,
#                                 u'mean_area_30s_m2': 849468.5005832167},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'193',
#                 u'properties': {u'PfafID_area_30s_m2': 145735,
#                                 u'count_area_30s_m2': 5232,
#                                 u'mean_area_30s_m2': 850238.7706899847},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'194',
#                 u'properties': {u'PfafID_area_30s_m2': 145736,
#                                 u'count_area_30s_m2': 18905,
#                                 u'mean_area_30s_m2': 848647.4513686856},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'195',
#                 u'properties': {u'PfafID_area_30s_m2': 145737,
#                                 u'count_area_30s_m2': 253,
#                                 u'mean_area_30s_m2': 849926.9157608695},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'196',
#                 u'properties': {u'PfafID_area_30s_m2': 145738,
#                                 u'count_area_30s_m2': 976,
#                                 u'mean_area_30s_m2': 849414.9883452869},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'197',
#                 u'properties': {u'PfafID_area_30s_m2': 145740,
#                                 u'count_area_30s_m2': 18709,
#                                 u'mean_area_30s_m2': 847009.0072090973},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'198',
#                 u'properties': {u'PfafID_area_30s_m2': 145750,
#                                 u'count_area_30s_m2': 5973,
#                                 u'mean_area_30s_m2': 846225.1667294492},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'199',
#                 u'properties': {u'PfafID_area_30s_m2': 145760,
#                                 u'count_area_30s_m2': 4571,
#                                 u'mean_area_30s_m2': 845099.6837809014},
#                 u'type': u'Feature'},
#                {u'geometry': None,
#                 u'id': u'200',
#                 u'properties': {u'PfafID_area_30s_m2': 162480,
#                                 u'count_area_30s_m2': 394,
#                                 u'mean_area_30s_m2': 842304.8032994923},
#                 u'type': u'Feature'}],
#  u'properties': {u'exportdescription': u'area_30s_m2',
#                  u'ingested_by': u'RutgerHofste',
#                  u'script_used': u'Y2017M09D05_RH_create_area_image_EE_V01',
#                  u'spatial_resolution': u'30s',
#                  u'units': u'm2'},
#  u'type': u'FeatureCollection'}
