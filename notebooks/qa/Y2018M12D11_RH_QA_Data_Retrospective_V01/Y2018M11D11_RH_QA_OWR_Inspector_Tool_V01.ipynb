# %%
"""
Inspect Overall Water Risk per sector.

WARNING: Script is extremely quick and dirty and contains inefficiencies. 

Nomenclature

['BWS',
 'BWD',
 'GTD',
 'IAV',
 'SEV',
 'DRR',
 'RFR',
 'CFR',
 'UCW',
 'CEP',
 'UDW',
 'USA',
 'RRI']

['Baseline water stress',
 'Baseline water depletion ',
 'Groundwater table decline ',
 'Interannual variability ',
 'Seasonal variability',
 'Drought risk',
 'Riverine flood risk ',
 'Coastal flood risk ',
 'Untreated collected wastewater',
 'Coastal eutrophication potential',
 'Unimproved/no drinking water ',
 'Unimproved/no sanitation',
 'RepRisk Index (RRI)']

['DEF', 'AGR', 'FNB', 'CHE', 'ELP', 'SMC', 'ONG', 'MIN', 'CON', 'TEX']

['Default',
 'Agriculture',
 'Food & Beverage',
 'Chemicals',
 'Electric Power',
 'Semiconductor',
 'Oil & Gas',
 'Mining',
 'Construction Materials',
 'Textile']

"""


# User Input
INDUSTRY = "def" # one of ['DEF', 'AGR', 'FNB', 'CHE', 'ELP', 'SMC', 'ONG', 'MIN', 'CON', 'TEX']
STRING_ID = '453750-IND.31_1-3383' # Use Shapefile to find string_id

# %%
SCRIPT_NAME = 'Y2018M11D11_RH_QA_OWR_Inspector_Tool_V01'
OUTPUT_VERSION = 2

BQ_PROJECT_ID = "aqueduct30"
BQ_OUTPUT_DATASET_NAME = "aqueduct30v01"
BQ_IN = "y2018m12d11_rh_master_weights_gpd_v01_v02"

BQ_OUTPUT_TABLE_NAME = "{}_v{:02.0f}".format(SCRIPT_NAME,OUTPUT_VERSION).lower()

# %%
import time, datetime, sys
dateString = time.strftime("Y%YM%mD%d")
timeString = time.strftime("UTC %H:%M")
start = datetime.datetime.now()
print(dateString,timeString)
sys.version
# Out:
# Y2019M06D25 UTC 12:58
# '3.5.4 |Anaconda, Inc.| (default, Nov 20 2017, 18:44:38) \n[GCC 7.2.0]'

# %%
import os
import collections
import pandas as pd
import numpy as np
from google.cloud import bigquery

import plotly.plotly as py
import plotly.graph_objs as go


os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/.google.json"
os.environ["GOOGLE_CLOUD_PROJECT"] = "aqueduct30"
client = bigquery.Client(project=BQ_PROJECT_ID)

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
# %matplotlib inline

# %%
sql_nomenclature = """
SELECT
  *
FROM
  `aqueduct30.aqueduct30v01.y2018m12d06_rh_process_weights_bq_v01_v01`
ORDER BY
  id
"""

# %%
df_nomenclature = pd.read_gbq(query=sql_nomenclature,dialect="standard")

# %%
df_nomenclature
# Out:
#       id                         group_full group_short  \
# 0      1            Physical Risk Quantity          QAN
# 1      2            Physical Risk Quantity          QAN
# 2      3            Physical Risk Quantity          QAN
# 3      4            Physical Risk Quantity          QAN
# 4      5            Physical Risk Quantity          QAN
# 5      6            Physical Risk Quantity          QAN
# 6      7            Physical Risk Quantity          QAN
# 7      8            Physical Risk Quantity          QAN
# 8      9             Physical Risk Quality          QAL
# 9     10             Physical Risk Quality          QAL
# 10    11  Regulatory and Reputational Risk          RRR
# 11    12  Regulatory and Reputational Risk          RRR
# 12    13  Regulatory and Reputational Risk          RRR
# 13    14            Physical Risk Quantity          QAN
# 14    15            Physical Risk Quantity          QAN
# 15    16            Physical Risk Quantity          QAN
# 16    17            Physical Risk Quantity          QAN
# 17    18            Physical Risk Quantity          QAN
# 18    19            Physical Risk Quantity          QAN
# 19    20            Physical Risk Quantity          QAN
# 20    21            Physical Risk Quantity          QAN
# 21    22             Physical Risk Quality          QAL
# 22    23             Physical Risk Quality          QAL
# 23    24  Regulatory and Reputational Risk          RRR
# 24    25  Regulatory and Reputational Risk          RRR
# 25    26  Regulatory and Reputational Risk          RRR
# 26    27            Physical Risk Quantity          QAN
# 27    28            Physical Risk Quantity          QAN
# 28    29            Physical Risk Quantity          QAN
# 29    30            Physical Risk Quantity          QAN
# 30    31            Physical Risk Quantity          QAN
# 31    32            Physical Risk Quantity          QAN
# 32    33            Physical Risk Quantity          QAN
# 33    34            Physical Risk Quantity          QAN
# 34    35             Physical Risk Quality          QAL
# 35    36             Physical Risk Quality          QAL
# 36    37  Regulatory and Reputational Risk          RRR
# 37    38  Regulatory and Reputational Risk          RRR
# 38    39  Regulatory and Reputational Risk          RRR
# 39    40            Physical Risk Quantity          QAN
# 40    41            Physical Risk Quantity          QAN
# 41    42            Physical Risk Quantity          QAN
# 42    43            Physical Risk Quantity          QAN
# 43    44            Physical Risk Quantity          QAN
# 44    45            Physical Risk Quantity          QAN
# 45    46            Physical Risk Quantity          QAN
# 46    47            Physical Risk Quantity          QAN
# 47    48             Physical Risk Quality          QAL
# 48    49             Physical Risk Quality          QAL
# 49    50  Regulatory and Reputational Risk          RRR
# 50    51  Regulatory and Reputational Risk          RRR
# 51    52  Regulatory and Reputational Risk          RRR
# 52    53            Physical Risk Quantity          QAN
# 53    54            Physical Risk Quantity          QAN
# 54    55            Physical Risk Quantity          QAN
# 55    56            Physical Risk Quantity          QAN
# 56    57            Physical Risk Quantity          QAN
# 57    58            Physical Risk Quantity          QAN
# 58    59            Physical Risk Quantity          QAN
# 59    60            Physical Risk Quantity          QAN
# 60    61             Physical Risk Quality          QAL
# 61    62             Physical Risk Quality          QAL
# 62    63  Regulatory and Reputational Risk          RRR
# 63    64  Regulatory and Reputational Risk          RRR
# 64    65  Regulatory and Reputational Risk          RRR
# 65    66            Physical Risk Quantity          QAN
# 66    67            Physical Risk Quantity          QAN
# 67    68            Physical Risk Quantity          QAN
# 68    69            Physical Risk Quantity          QAN
# 69    70            Physical Risk Quantity          QAN
# 70    71            Physical Risk Quantity          QAN
# 71    72            Physical Risk Quantity          QAN
# 72    73            Physical Risk Quantity          QAN
# 73    74             Physical Risk Quality          QAL
# 74    75             Physical Risk Quality          QAL
# 75    76  Regulatory and Reputational Risk          RRR
# 76    77  Regulatory and Reputational Risk          RRR
# 77    78  Regulatory and Reputational Risk          RRR
# 78    79            Physical Risk Quantity          QAN
# 79    80            Physical Risk Quantity          QAN
# 80    81            Physical Risk Quantity          QAN
# 81    82            Physical Risk Quantity          QAN
# 82    83            Physical Risk Quantity          QAN
# 83    84            Physical Risk Quantity          QAN
# 84    85            Physical Risk Quantity          QAN
# 85    86            Physical Risk Quantity          QAN
# 86    87             Physical Risk Quality          QAL
# 87    88             Physical Risk Quality          QAL
# 88    89  Regulatory and Reputational Risk          RRR
# 89    90  Regulatory and Reputational Risk          RRR
# 90    91  Regulatory and Reputational Risk          RRR
# 91    92            Physical Risk Quantity          QAN
# 92    93            Physical Risk Quantity          QAN
# 93    94            Physical Risk Quantity          QAN
# 94    95            Physical Risk Quantity          QAN
# 95    96            Physical Risk Quantity          QAN
# 96    97            Physical Risk Quantity          QAN
# 97    98            Physical Risk Quantity          QAN
# 98    99            Physical Risk Quantity          QAN
# 99   100             Physical Risk Quality          QAL
# 100  101             Physical Risk Quality          QAL
# 101  102  Regulatory and Reputational Risk          RRR
# 102  103  Regulatory and Reputational Risk          RRR
# 103  104  Regulatory and Reputational Risk          RRR
# 104  105            Physical Risk Quantity          QAN
# 105  106            Physical Risk Quantity          QAN
# 106  107            Physical Risk Quantity          QAN
# 107  108            Physical Risk Quantity          QAN
# 108  109            Physical Risk Quantity          QAN
# 109  110            Physical Risk Quantity          QAN
# 110  111            Physical Risk Quantity          QAN
# 111  112            Physical Risk Quantity          QAN
# 112  113             Physical Risk Quality          QAL
# 113  114             Physical Risk Quality          QAL
# 114  115  Regulatory and Reputational Risk          RRR
# 115  116  Regulatory and Reputational Risk          RRR
# 116  117  Regulatory and Reputational Risk          RRR
# 117  118            Physical Risk Quantity          QAN
# 118  119            Physical Risk Quantity          QAN
# 119  120            Physical Risk Quantity          QAN
# 120  121            Physical Risk Quantity          QAN
# 121  122            Physical Risk Quantity          QAN
# 122  123            Physical Risk Quantity          QAN
# 123  124            Physical Risk Quantity          QAN
# 124  125            Physical Risk Quantity          QAN
# 125  126             Physical Risk Quality          QAL
# 126  127             Physical Risk Quality          QAL
# 127  128  Regulatory and Reputational Risk          RRR
# 128  129  Regulatory and Reputational Risk          RRR
# 129  130  Regulatory and Reputational Risk          RRR
#
#                        indicator_full indicator_short           industry_full  \
# 0               Baseline water stress             BWS                 Default
# 1           Baseline water depletion              BWD                 Default
# 2          Groundwater table decline              GTD                 Default
# 3            Interannual variability              IAV                 Default
# 4                Seasonal variability             SEV                 Default
# 5                        Drought risk             DRR                 Default
# 6                Riverine flood risk              RFR                 Default
# 7                 Coastal flood risk              CFR                 Default
# 8      Untreated collected wastewater             UCW                 Default
# 9    Coastal eutrophication potential             CEP                 Default
# 10      Unimproved/no drinking water              UDW                 Default
# 11           Unimproved/no sanitation             USA                 Default
# 12                RepRisk Index (RRI)             RRI                 Default
# 13              Baseline water stress             BWS             Agriculture
# 14          Baseline water depletion              BWD             Agriculture
# 15         Groundwater table decline              GTD             Agriculture
# 16           Interannual variability              IAV             Agriculture
# 17               Seasonal variability             SEV             Agriculture
# 18                       Drought risk             DRR             Agriculture
# 19               Riverine flood risk              RFR             Agriculture
# 20                Coastal flood risk              CFR             Agriculture
# 21     Untreated collected wastewater             UCW             Agriculture
# 22   Coastal eutrophication potential             CEP             Agriculture
# 23      Unimproved/no drinking water              UDW             Agriculture
# 24           Unimproved/no sanitation             USA             Agriculture
# 25                RepRisk Index (RRI)             RRI             Agriculture
# 26              Baseline water stress             BWS         Food & Beverage
# 27          Baseline water depletion              BWD         Food & Beverage
# 28         Groundwater table decline              GTD         Food & Beverage
# 29           Interannual variability              IAV         Food & Beverage
# 30               Seasonal variability             SEV         Food & Beverage
# 31                       Drought risk             DRR         Food & Beverage
# 32               Riverine flood risk              RFR         Food & Beverage
# 33                Coastal flood risk              CFR         Food & Beverage
# 34     Untreated collected wastewater             UCW         Food & Beverage
# 35   Coastal eutrophication potential             CEP         Food & Beverage
# 36      Unimproved/no drinking water              UDW         Food & Beverage
# 37           Unimproved/no sanitation             USA         Food & Beverage
# 38                RepRisk Index (RRI)             RRI         Food & Beverage
# 39              Baseline water stress             BWS               Chemicals
# 40          Baseline water depletion              BWD               Chemicals
# 41         Groundwater table decline              GTD               Chemicals
# 42           Interannual variability              IAV               Chemicals
# 43               Seasonal variability             SEV               Chemicals
# 44                       Drought risk             DRR               Chemicals
# 45               Riverine flood risk              RFR               Chemicals
# 46                Coastal flood risk              CFR               Chemicals
# 47     Untreated collected wastewater             UCW               Chemicals
# 48   Coastal eutrophication potential             CEP               Chemicals
# 49      Unimproved/no drinking water              UDW               Chemicals
# 50           Unimproved/no sanitation             USA               Chemicals
# 51                RepRisk Index (RRI)             RRI               Chemicals
# 52              Baseline water stress             BWS          Electric Power
# 53          Baseline water depletion              BWD          Electric Power
# 54         Groundwater table decline              GTD          Electric Power
# 55           Interannual variability              IAV          Electric Power
# 56               Seasonal variability             SEV          Electric Power
# 57                       Drought risk             DRR          Electric Power
# 58               Riverine flood risk              RFR          Electric Power
# 59                Coastal flood risk              CFR          Electric Power
# 60     Untreated collected wastewater             UCW          Electric Power
# 61   Coastal eutrophication potential             CEP          Electric Power
# 62      Unimproved/no drinking water              UDW          Electric Power
# 63           Unimproved/no sanitation             USA          Electric Power
# 64                RepRisk Index (RRI)             RRI          Electric Power
# 65              Baseline water stress             BWS           Semiconductor
# 66          Baseline water depletion              BWD           Semiconductor
# 67         Groundwater table decline              GTD           Semiconductor
# 68           Interannual variability              IAV           Semiconductor
# 69               Seasonal variability             SEV           Semiconductor
# 70                       Drought risk             DRR           Semiconductor
# 71               Riverine flood risk              RFR           Semiconductor
# 72                Coastal flood risk              CFR           Semiconductor
# 73     Untreated collected wastewater             UCW           Semiconductor
# 74   Coastal eutrophication potential             CEP           Semiconductor
# 75      Unimproved/no drinking water              UDW           Semiconductor
# 76           Unimproved/no sanitation             USA           Semiconductor
# 77                RepRisk Index (RRI)             RRI           Semiconductor
# 78              Baseline water stress             BWS               Oil & Gas
# 79          Baseline water depletion              BWD               Oil & Gas
# 80         Groundwater table decline              GTD               Oil & Gas
# 81           Interannual variability              IAV               Oil & Gas
# 82               Seasonal variability             SEV               Oil & Gas
# 83                       Drought risk             DRR               Oil & Gas
# 84               Riverine flood risk              RFR               Oil & Gas
# 85                Coastal flood risk              CFR               Oil & Gas
# 86     Untreated collected wastewater             UCW               Oil & Gas
# 87   Coastal eutrophication potential             CEP               Oil & Gas
# 88      Unimproved/no drinking water              UDW               Oil & Gas
# 89           Unimproved/no sanitation             USA               Oil & Gas
# 90                RepRisk Index (RRI)             RRI               Oil & Gas
# 91              Baseline water stress             BWS                  Mining
# 92          Baseline water depletion              BWD                  Mining
# 93         Groundwater table decline              GTD                  Mining
# 94           Interannual variability              IAV                  Mining
# 95               Seasonal variability             SEV                  Mining
# 96                       Drought risk             DRR                  Mining
# 97               Riverine flood risk              RFR                  Mining
# 98                Coastal flood risk              CFR                  Mining
# 99     Untreated collected wastewater             UCW                  Mining
# 100  Coastal eutrophication potential             CEP                  Mining
# 101     Unimproved/no drinking water              UDW                  Mining
# 102          Unimproved/no sanitation             USA                  Mining
# 103               RepRisk Index (RRI)             RRI                  Mining
# 104             Baseline water stress             BWS  Construction Materials
# 105         Baseline water depletion              BWD  Construction Materials
# 106        Groundwater table decline              GTD  Construction Materials
# 107          Interannual variability              IAV  Construction Materials
# 108              Seasonal variability             SEV  Construction Materials
# 109                      Drought risk             DRR  Construction Materials
# 110              Riverine flood risk              RFR  Construction Materials
# 111               Coastal flood risk              CFR  Construction Materials
# 112    Untreated collected wastewater             UCW  Construction Materials
# 113  Coastal eutrophication potential             CEP  Construction Materials
# 114     Unimproved/no drinking water              UDW  Construction Materials
# 115          Unimproved/no sanitation             USA  Construction Materials
# 116               RepRisk Index (RRI)             RRI  Construction Materials
# 117             Baseline water stress             BWS                 Textile
# 118         Baseline water depletion              BWD                 Textile
# 119        Groundwater table decline              GTD                 Textile
# 120          Interannual variability              IAV                 Textile
# 121              Seasonal variability             SEV                 Textile
# 122                      Drought risk             DRR                 Textile
# 123              Riverine flood risk              RFR                 Textile
# 124               Coastal flood risk              CFR                 Textile
# 125    Untreated collected wastewater             UCW                 Textile
# 126  Coastal eutrophication potential             CEP                 Textile
# 127     Unimproved/no drinking water              UDW                 Textile
# 128          Unimproved/no sanitation             USA                 Textile
# 129               RepRisk Index (RRI)             RRI                 Textile
#
#     industry_short  weight_abs weight_label  \
# 0              DEF        4.00    Very High
# 1              DEF        4.00    Very High
# 2              DEF        4.00    Very High
# 3              DEF        0.50          Low
# 4              DEF        0.50          Low
# 5              DEF        2.00         High
# 6              DEF        1.00      Medium
# 7              DEF        1.00      Medium
# 8              DEF        2.00         High
# 9              DEF        1.00      Medium
# 10             DEF        2.00         High
# 11             DEF        2.00         High
# 12             DEF        0.50          Low
# 13             AGR        4.00    Very High
# 14             AGR        4.00    Very High
# 15             AGR        4.00    Very High
# 16             AGR        2.00         High
# 17             AGR        0.50          Low
# 18             AGR        4.00    Very High
# 19             AGR        1.00      Medium
# 20             AGR        1.00      Medium
# 21             AGR        1.00      Medium
# 22             AGR        4.00    Very High
# 23             AGR        2.00         High
# 24             AGR        2.00         High
# 25             AGR        0.25     Very Low
# 26             FNB        4.00    Very High
# 27             FNB        4.00    Very High
# 28             FNB        4.00    Very High
# 29             FNB        1.00      Medium
# 30             FNB        0.50          Low
# 31             FNB        2.00         High
# 32             FNB        0.50          Low
# 33             FNB        0.50          Low
# 34             FNB        2.00         High
# 35             FNB        2.00         High
# 36             FNB        1.00      Medium
# 37             FNB        1.00      Medium
# 38             FNB        2.00         High
# 39             CHE        2.00         High
# 40             CHE        2.00         High
# 41             CHE        2.00         High
# 42             CHE        1.00      Medium
# 43             CHE        1.00      Medium
# 44             CHE        2.00         High
# 45             CHE        4.00    Very High
# 46             CHE        4.00    Very High
# 47             CHE        2.00         High
# 48             CHE        0.25     Very Low
# 49             CHE        2.00         High
# 50             CHE        2.00         High
# 51             CHE        2.00         High
# 52             ELP        4.00    Very High
# 53             ELP        4.00    Very High
# 54             ELP        0.50          Low
# 55             ELP        1.00      Medium
# 56             ELP        2.00         High
# 57             ELP        4.00    Very High
# 58             ELP        2.00         High
# 59             ELP        4.00    Very High
# 60             ELP        0.25     Very Low
# 61             ELP        1.00      Medium
# 62             ELP        0.25     Very Low
# 63             ELP        0.25     Very Low
# 64             ELP        0.25     Very Low
# 65             SMC        2.00         High
# 66             SMC        2.00         High
# 67             SMC        2.00         High
# 68             SMC        1.00      Medium
# 69             SMC        1.00      Medium
# 70             SMC        1.00      Medium
# 71             SMC        1.00      Medium
# 72             SMC        1.00      Medium
# 73             SMC        4.00    Very High
# 74             SMC        2.00         High
# 75             SMC        1.00      Medium
# 76             SMC        1.00      Medium
# 77             SMC        2.00         High
# 78             ONG        1.00      Medium
# 79             ONG        1.00      Medium
# 80             ONG        1.00      Medium
# 81             ONG        0.50          Low
# 82             ONG        0.50          Low
# 83             ONG        0.50          Low
# 84             ONG        1.00      Medium
# 85             ONG        4.00    Very High
# 86             ONG        0.25     Very Low
# 87             ONG        0.00   No weight
# 88             ONG        4.00    Very High
# 89             ONG        4.00    Very High
# 90             ONG        4.00    Very High
# 91             MIN        2.00         High
# 92             MIN        2.00         High
# 93             MIN        2.00         High
# 94             MIN        1.00      Medium
# 95             MIN        1.00      Medium
# 96             MIN        4.00    Very High
# 97             MIN        4.00    Very High
# 98             MIN        4.00    Very High
# 99             MIN        0.50          Low
# 100            MIN        0.25     Very Low
# 101            MIN        4.00    Very High
# 102            MIN        4.00    Very High
# 103            MIN        4.00    Very High
# 104            CON        2.00         High
# 105            CON        2.00         High
# 106            CON        2.00         High
# 107            CON        0.50          Low
# 108            CON        0.50          Low
# 109            CON        1.00      Medium
# 110            CON        1.00      Medium
# 111            CON        1.00      Medium
# 112            CON        1.00      Medium
# 113            CON        0.50          Low
# 114            CON        1.00      Medium
# 115            CON        1.00      Medium
# 116            CON        0.50          Low
# 117            TEX        2.00         High
# 118            TEX        2.00         High
# 119            TEX        2.00         High
# 120            TEX        1.00      Medium
# 121            TEX        0.50          Low
# 122            TEX        1.00      Medium
# 123            TEX        1.00      Medium
# 124            TEX        2.00         High
# 125            TEX        4.00    Very High
# 126            TEX        1.00      Medium
# 127            TEX        2.00         High
# 128            TEX        2.00         High
# 129            TEX        4.00    Very High
#
#                           weight_interpretation  weight_fraction
# 0    Represents very high risk to the industry          0.163265
# 1    Represents very high risk to the industry          0.163265
# 2    Represents very high risk to the industry          0.163265
# 3          Represents low risk to the industry          0.020408
# 4          Represents low risk to the industry          0.020408
# 5          Represents low risk to the industry          0.081633
# 6       Represents medium risk to the industry          0.040816
# 7       Represents medium risk to the industry          0.040816
# 8         Represents high risk to the industry          0.081633
# 9       Represents medium risk to the industry          0.040816
# 10        Represents high risk to the industry          0.081633
# 11        Represents high risk to the industry          0.081633
# 12         Represents low risk to the industry          0.020408
# 13   Represents very high risk to the industry          0.134454
# 14   Represents very high risk to the industry          0.134454
# 15   Represents very high risk to the industry          0.134454
# 16        Represents high risk to the industry          0.067227
# 17         Represents low risk to the industry          0.016807
# 18   Represents very high risk to the industry          0.134454
# 19      Represents medium risk to the industry          0.033613
# 20      Represents medium risk to the industry          0.033613
# 21      Represents medium risk to the industry          0.033613
# 22   Represents very high risk to the industry          0.134454
# 23        Represents high risk to the industry          0.067227
# 24        Represents high risk to the industry          0.067227
# 25     Represents very low risk to the industry         0.008403
# 26   Represents very high risk to the industry          0.163265
# 27   Represents very high risk to the industry          0.163265
# 28   Represents very high risk to the industry          0.163265
# 29      Represents medium risk to the industry          0.040816
# 30         Represents low risk to the industry          0.020408
# 31        Represents high risk to the industry          0.081633
# 32         Represents low risk to the industry          0.020408
# 33         Represents low risk to the industry          0.020408
# 34        Represents high risk to the industry          0.081633
# 35        Represents high risk to the industry          0.081633
# 36      Represents medium risk to the industry          0.040816
# 37      Represents medium risk to the industry          0.040816
# 38        Represents high risk to the industry          0.081633
# 39        Represents high risk to the industry          0.076190
# 40        Represents high risk to the industry          0.076190
# 41        Represents high risk to the industry          0.076190
# 42      Represents medium risk to the industry          0.038095
# 43      Represents medium risk to the industry          0.038095
# 44        Represents high risk to the industry          0.076190
# 45   Represents very high risk to the industry          0.152381
# 46   Represents very high risk to the industry          0.152381
# 47        Represents high risk to the industry          0.076190
# 48     Represents very low risk to the industry         0.009524
# 49        Represents high risk to the industry          0.076190
# 50        Represents high risk to the industry          0.076190
# 51        Represents high risk to the industry          0.076190
# 52   Represents very high risk to the industry          0.170213
# 53   Represents very high risk to the industry          0.170213
# 54         Represents low risk to the industry          0.021277
# 55      Represents medium risk to the industry          0.042553
# 56        Represents high risk to the industry          0.085106
# 57   Represents very high risk to the industry          0.170213
# 58        Represents high risk to the industry          0.085106
# 59   Represents very high risk to the industry          0.170213
# 60     Represents very low risk to the industry         0.010638
# 61      Represents medium risk to the industry          0.042553
# 62     Represents very low risk to the industry         0.010638
# 63     Represents very low risk to the industry         0.010638
# 64     Represents very low risk to the industry         0.010638
# 65        Represents high risk to the industry          0.095238
# 66        Represents high risk to the industry          0.095238
# 67        Represents high risk to the industry          0.095238
# 68      Represents medium risk to the industry          0.047619
# 69      Represents medium risk to the industry          0.047619
# 70      Represents medium risk to the industry          0.047619
# 71      Represents medium risk to the industry          0.047619
# 72      Represents medium risk to the industry          0.047619
# 73   Represents very high risk to the industry          0.190476
# 74        Represents high risk to the industry          0.095238
# 75      Represents medium risk to the industry          0.047619
# 76      Represents medium risk to the industry          0.047619
# 77        Represents high risk to the industry          0.095238
# 78      Represents medium risk to the industry          0.045977
# 79      Represents medium risk to the industry          0.045977
# 80      Represents medium risk to the industry          0.045977
# 81         Represents low risk to the industry          0.022989
# 82         Represents low risk to the industry          0.022989
# 83         Represents low risk to the industry          0.022989
# 84      Represents medium risk to the industry          0.045977
# 85   Represents very high risk to the industry          0.183908
# 86     Represents very low risk to the industry         0.011494
# 87                                Not relevant          0.000000
# 88   Represents very high risk to the industry          0.183908
# 89   Represents very high risk to the industry          0.183908
# 90   Represents very high risk to the industry          0.183908
# 91        Represents high risk to the industry          0.061069
# 92        Represents high risk to the industry          0.061069
# 93        Represents high risk to the industry          0.061069
# 94      Represents medium risk to the industry          0.030534
# 95      Represents medium risk to the industry          0.030534
# 96   Represents very high risk to the industry          0.122137
# 97   Represents very high risk to the industry          0.122137
# 98   Represents very high risk to the industry          0.122137
# 99         Represents low risk to the industry          0.015267
# 100    Represents very low risk to the industry         0.007634
# 101  Represents very high risk to the industry          0.122137
# 102  Represents very high risk to the industry          0.122137
# 103  Represents very high risk to the industry          0.122137
# 104       Represents high risk to the industry          0.142857
# 105       Represents high risk to the industry          0.142857
# 106       Represents high risk to the industry          0.142857
# 107        Represents low risk to the industry          0.035714
# 108        Represents low risk to the industry          0.035714
# 109     Represents medium risk to the industry          0.071429
# 110     Represents medium risk to the industry          0.071429
# 111     Represents medium risk to the industry          0.071429
# 112     Represents medium risk to the industry          0.071429
# 113        Represents low risk to the industry          0.035714
# 114     Represents medium risk to the industry          0.071429
# 115     Represents medium risk to the industry          0.071429
# 116        Represents low risk to the industry          0.035714
# 117       Represents high risk to the industry          0.081633
# 118       Represents high risk to the industry          0.081633
# 119       Represents high risk to the industry          0.081633
# 120     Represents medium risk to the industry          0.040816
# 121        Represents low risk to the industry          0.020408
# 122     Represents medium risk to the industry          0.040816
# 123     Represents medium risk to the industry          0.040816
# 124       Represents high risk to the industry          0.081633
# 125  Represents very high risk to the industry          0.163265
# 126     Represents medium risk to the industry          0.040816
# 127       Represents high risk to the industry          0.081633
# 128       Represents high risk to the industry          0.081633
# 129  Represents very high risk to the industry          0.163265

# %%
indicators = list(df_nomenclature["indicator_short"].unique())
industries = list(df_nomenclature["industry_short"].unique())
indicators_full = list(df_nomenclature["indicator_full"].unique())
industries_full = list(df_nomenclature["industry_full"].unique())

# %%
indicators
# Out:
# ['BWS',
#  'BWD',
#  'GTD',
#  'IAV',
#  'SEV',
#  'DRR',
#  'RFR',
#  'CFR',
#  'UCW',
#  'CEP',
#  'UDW',
#  'USA',
#  'RRI']

# %%
indicators_full
# Out:
# ['Baseline water stress',
#  'Baseline water depletion ',
#  'Groundwater table decline ',
#  'Interannual variability ',
#  'Seasonal variability',
#  'Drought risk',
#  'Riverine flood risk ',
#  'Coastal flood risk ',
#  'Untreated collected wastewater',
#  'Coastal eutrophication potential',
#  'Unimproved/no drinking water ',
#  'Unimproved/no sanitation',
#  'RepRisk Index (RRI)']

# %%
industries
# Out:
# ['DEF', 'AGR', 'FNB', 'CHE', 'ELP', 'SMC', 'ONG', 'MIN', 'CON', 'TEX']

# %%
industries_full
# Out:
# ['Default',
#  'Agriculture',
#  'Food & Beverage',
#  'Chemicals',
#  'Electric Power',
#  'Semiconductor',
#  'Oil & Gas',
#  'Mining',
#  'Construction Materials',
#  'Textile']

# %%
def get_hex_color(score):
    if score < 1:
        color = "#FFFF99"
    elif score < 2:
        color = "#FFE600"
    elif score < 3:
        color = "#FF9900"
    elif score < 4:
        color = "#FF1900"
    elif score <= 5:
        color = "#990000"
    else:
        color = "#4E4E4E"
    return color
    

def build_query(indicators,industry,string_id):
    sql = """
    SELECT
      aq30_id,
      string_id,
      pfaf_id,
      gid_1,
      aqid,
      area_km2,
      name_1,
      gid_0,
      name_0,
      delta_id,
    """
    for indicator in indicators:
        sql += "{}_score,".format(indicator)
        sql += "{}_{}_weight,".format(indicator,INDUSTRY)
        sql += "{}_{}_weightedscore,".format(indicator,INDUSTRY)
        
    sql += "{}_weight_sum,".format(INDUSTRY)
    sql += "{}_weightedscore_sum,".format(INDUSTRY)
    sql += "owr_{}_score".format(INDUSTRY)    

    sql += """
    FROM
      `{}.{}.{}`
    WHERE string_id = '{}'
    """.format(BQ_PROJECT_ID,BQ_OUTPUT_DATASET_NAME,BQ_IN,STRING_ID)
    return sql

sql = build_query(indicators,INDUSTRY,STRING_ID)
print(sql)
df_in = pd.read_gbq(query=sql,dialect="standard")

xs = []
ws = []
ss = []
for indicator in indicators:
    xs.append("{}".format(indicator))
    w = df_in.iloc[0]["{}_{}_weight".format(indicator,INDUSTRY)]
    s = df_in.iloc[0]["{}_score".format(indicator)]
    ws.append(w)
    ss.append(s)
    
df = pd.DataFrame({"x":xs,"weight":ws,"score":ss})
df = df.dropna()
df["cumweight"] = df["weight"].cumsum(axis=0)
df["offset"] = df["cumweight"] - (df["weight"]*0.5)
df["color"] = df["score"].apply(get_hex_color)

bar = go.Bar(name="Risk per indicator",
             x=df['offset'], # assign x as the dataframe column 'x'
             y=df['score'],
             width=df["weight"],
             text = df["x"],
             marker = {"color":list(df["color"])}
             )

owr_score = df_in.iloc[0]["owr_{}_score".format(INDUSTRY)]

line = go.Scatter(name = 'OWR {}'.format(INDUSTRY),
                  x = [0,df["cumweight"].max()],
                  y = [owr_score,owr_score],
                  line = {"dash":"dot",
                          "color":get_hex_color(owr_score)})
layout = go.Layout(
    barmode='stack',
    autosize=True,
    title='Risk Overview for {}'.format(STRING_ID),
    xaxis= {"title":"Weight for {}".format(INDUSTRY)},
    yaxis= {"title":"Score [0-5]"}
)
data = [bar, line]
fig = go.Figure(data=data, layout=layout)
# Out:
#     SELECT
#       aq30_id,
#       string_id,
#       pfaf_id,
#       gid_1,
#       aqid,
#       area_km2,
#       name_1,
#       gid_0,
#       name_0,
#       delta_id,
#     BWS_score,BWS_def_weight,BWS_def_weightedscore,BWD_score,BWD_def_weight,BWD_def_weightedscore,GTD_score,GTD_def_weight,GTD_def_weightedscore,IAV_score,IAV_def_weight,IAV_def_weightedscore,SEV_score,SEV_def_weight,SEV_def_weightedscore,DRR_score,DRR_def_weight,DRR_def_weightedscore,RFR_score,RFR_def_weight,RFR_def_weightedscore,CFR_score,CFR_def_weight,CFR_def_weightedscore,UCW_score,UCW_def_weight,UCW_def_weightedscore,CEP_score,CEP_def_weight,CEP_def_weightedscore,UDW_score,UDW_def_weight,UDW_def_weightedscore,USA_score,USA_def_weight,USA_def_weightedscore,RRI_score,RRI_def_weight,RRI_def_weightedscore,def_weight_sum,def_weightedscore_sum,owr_def_score
#     FROM
#       `aqueduct30.aqueduct30v01.y2018m12d11_rh_master_weights_gpd_v02_v10`
#     WHERE string_id = '453750-IND.31_1-3383'
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/pandas_gbq/gbq.py in run_query(self, query, **kwargs)
#     496         try:
# --> 497             rows_iter = query_reply.result()
#     498         except self.http_error as ex:
#
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/google/cloud/bigquery/job.py in result(self, timeout, retry)
#    2761         """
# -> 2762         super(QueryJob, self).result(timeout=timeout)
#    2763         # Return an iterator instead of returning the job.
#
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/google/cloud/bigquery/job.py in result(self, timeout, retry)
#     702         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 703         return super(_AsyncJob, self).result(timeout=timeout)
#     704
#
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/google/api_core/future/polling.py in result(self, timeout)
#     126             # Pylint doesn't recognize that this is valid in this case.
# --> 127             raise self._exception
#     128
#
# BadRequest: 400 Unrecognized name: aq30_id at [3:7]
#
# During handling of the above exception, another exception occurred:
#
# GenericGBQException                       Traceback (most recent call last)
# <ipython-input-18-71228c5f8c35> in <module>()
#      47 sql = build_query(indicators,INDUSTRY,STRING_ID)
#      48 print(sql)
# ---> 49 df_in = pd.read_gbq(query=sql,dialect="standard")
#      50
#      51 xs = []
#
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/pandas/io/gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, verbose, private_key, dialect, **kwargs)
#      97         private_key=private_key,
#      98         dialect=dialect,
# ---> 99         **kwargs)
#     100
#     101
#
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/pandas_gbq/gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, verbose, private_key)
#     925     )
#     926
# --> 927     final_df = connector.run_query(query, configuration=configuration)
#     928
#     929     # Reindex the DataFrame on the provided column
#
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/pandas_gbq/gbq.py in run_query(self, query, **kwargs)
#     497             rows_iter = query_reply.result()
#     498         except self.http_error as ex:
# --> 499             self.process_http_error(ex)
#     500
#     501         schema_fields = [field.to_api_repr() for field in rows_iter.schema]
#
# /opt/anaconda3/envs/python35/lib/python3.5/site-packages/pandas_gbq/gbq.py in process_http_error(ex)
#     402         # <https://cloud.google.com/bigquery/troubleshooting-errors>`__
#     403
# --> 404         raise GenericGBQException("Reason: {0}".format(ex))
#     405
#     406     def run_query(self, query, **kwargs):
#
# GenericGBQException: Reason: 400 Unrecognized name: aq30_id at [3:7]

# %%
# plot Online

# %%
url = py.plot(fig, filename='pandas-bar-chart-layout')

# %%
url
# Out:
# 'https://plot.ly/~rutgerhofste/4'

# %%
# Plot offline

# %%
py.iplot(fig, filename='pandas-bar-chart-layout')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~rutgerhofste/4.embed" height="525px" width="100%"></iframe>
